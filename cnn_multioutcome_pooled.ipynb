# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import copy
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# image and longitudinal outcome path
OUTCOME_CSV_PATH = '/content/drive/MyDrive/patients_742_selected.csv'
IMAGING_PKL_PATH = "/content/drive/MyDrive/x_with_coord.pkl"

PATIENT_ID_COL = 'id'
TIME_COL = 'Years_bl'
OUTCOME_COLS = ['MMSE', 'CDRSB', 'LDELTOTAL']
STATIC_TABULAR_COLS = ['AGE', 'GENDER', 'PTEDUCAT']

N_SPLITS = 5
RANDOM_STATE = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device: {DEVICE}")
print("-" * 30 + "\n")


print("--- step 2: image loading and pre-processing ---")
imaging_df = pd.read_pickle(IMAGING_PKL_PATH)
df = imaging_df.copy()
block = 2
signal_cols = df.columns[3:]

df["Xb"] = df.x // block
df["Yb"] = df.y // block
df["Zb"] = df.z // block

print("Mean‑pooling …")
pooled = df.groupby(["Xb", "Yb", "Zb"])[signal_cols].mean()

pooled = pooled.reset_index()
display(pooled)
# Out:
# device: cuda
# ------------------------------
#
# --- step 2: image loading and pre-processing ---
# Mean‑pooling …
#         Xb  Yb  Zb  002_S_0729_2006-07-17_5.csv  002_S_0782_2006-08-14_3.csv  \
# 0        1  37  44                    -2.792912                    -2.378889
# 1        1  37  45                    -2.808298                    -2.378889
# 2        1  37  46                    -2.789328                    -2.378889
# 3        1  38  43                    -2.791528                    -2.375753
# 4        1  38  44                    -0.863732                    -2.348688
# ...     ..  ..  ..                          ...                          ...
# 239163  77  49  50                    -2.728616                    -2.360885
# 239164  77  49  51                    -2.726615                    -2.380032
# 239165  77  49  52                    -2.722288                    -2.413499
# 239166  77  51  40                    -2.762474                    -2.382130
# 239167  77  52  40                    -2.764746                    -2.379925
#
#         002_S_0954_2006-10-10_7.csv  002_S_1070_2006-11-28_11.csv  \
# 0                         -1.773856                     -2.335286
# 1                         -1.773856                     -2.329250
# 2                         -1.773856                     -2.329084
# 3                         -1.773856                     -2.517997
# 4                         -1.773856                     -2.496181
# ...                             ...                           ...
# 239163                    -1.773856                     -2.321014
# 239164                    -1.773856                     -2.313229
# 239165                    -1.773856                     -2.313831
# 239166                    -1.773856                     -2.328615
# 239167                    -1.773856                     -2.328613
#
#         002_S_1155_2006-12-14_9.csv  002_S_1268_2007-02-14_11.csv  \
# 0                          0.596719                     -1.765281
# 1                          0.901965                     -1.765281
# 2                          0.651638                     -1.765281
# 3                          0.632981                     -1.765281
# 4                          1.103007                     -1.765281
# ...                             ...                           ...
# 239163                    -2.579449                     -1.765281
# 239164                    -2.566476                     -1.765281
# 239165                    -2.569669                     -1.765281
# 239166                    -2.588504                     -1.765231
# 239167                    -2.588504                     -1.765160
#
#         002_S_2010_2010-06-24_11.csv  ...  941_S_2060_2010-09-08_733.csv  \
# 0                          -2.833100  ...                      -1.701152
# 1                          -2.829968  ...                      -1.701152
# 2                          -2.832926  ...                      -1.701152
# 3                          -2.769821  ...                      -1.701152
# 4                          -2.746532  ...                      -1.701152
# ...                              ...  ...                            ...
# 239163                     -2.817723  ...                      -1.761741
# 239164                     -2.826856  ...                      -1.780595
# 239165                     -2.828936  ...                      -1.737624
# 239166                     -2.810227  ...                      -1.701075
# 239167                     -2.821986  ...                      -1.700793
#
#         941_S_4036_2011-05-10_735.csv  941_S_4187_2011-06-22_734.csv  \
# 0                            0.875000                       0.201460
# 1                            0.155349                       0.600329
# 2                           -1.182283                       0.757916
# 3                            1.011001                       0.763914
# 4                            0.858369                       0.688716
# ...                               ...                            ...
# 239163                      -2.519014                      -2.863345
# 239164                      -2.517990                      -2.874205
# 239165                      -2.516753                      -2.876511
# 239166                      -2.520640                      -2.848475
# 239167                      -2.530971                      -2.855019
#
#         941_S_4377_2012-01-04_740.csv  941_S_4420_2012-03-28_739.csv  \
# 0                           -2.583830                      -2.595766
# 1                           -2.571290                      -2.511538
# 2                           -2.688458                      -2.369983
# 3                           -0.858805                      -2.498166
# 4                           -1.114168                      -2.000347
# ...                               ...                            ...
# 239163                      -2.497635                      -2.421602
# 239164                      -2.528827                      -2.411746
# 239165                      -2.547080                      -2.399212
# 239166                      -2.551446                      -2.426327
# 239167                      -2.567371                      -2.411177
#
#         941_S_4764_2012-06-01_742.csv  941_S_6017_2017-05-17_822.csv  \
# 0                           -1.767830                      -2.355316
# 1                           -1.328341                      -2.355316
# 2                           -2.284303                      -2.355316
# 3                           -2.478895                      -2.352305
# 4                           -0.240278                      -2.330434
# ...                               ...                            ...
# 239163                      -2.173714                      -2.367502
# 239164                      -2.184370                      -2.366173
# 239165                      -2.199603                      -2.369792
# 239166                      -2.171802                      -2.352401
# 239167                      -2.176203                      -2.339786
#
#         941_S_6052_2017-07-20_825.csv  941_S_6068_2017-08-21_831.csv  \
# 0                            0.226981                       1.646702
# 1                            0.690027                       1.329351
# 2                           -0.780878                       1.504705
# 3                            1.436756                       1.877898
# 4                            1.394198                       1.328678
# ...                               ...                            ...
# 239163                      -2.477654                      -2.565042
# 239164                      -2.471008                      -2.574568
# 239165                      -2.468890                      -2.563396
# 239166                      -2.462863                      -2.548314
# 239167                      -2.462120                      -2.616969
#
#         941_S_6345_2018-05-10_839.csv
# 0                           -2.352754
# 1                           -2.352754
# 2                           -2.352754
# 3                           -2.345762
# 4                           -2.335502
# ...                               ...
# 239163                      -2.344331
# 239164                      -2.326821
# 239165                      -2.334988
# 239166                      -2.340197
# 239167                      -2.317459
#
# [239168 rows x 745 columns]

# %%
imaging_df = pooled

# Infer image dimensions from coordinates
coord_cols = ['Xb', 'Yb', 'Zb']
x_coords_all, y_coords_all, z_coords_all = imaging_df['Xb'].values, imaging_df['Yb'].values, imaging_df['Zb'].values
x_unique_sorted, y_unique_sorted, z_unique_sorted = np.sort(np.unique(x_coords_all)), np.sort(np.unique(y_coords_all)), np.sort(np.unique(z_coords_all))
dim_x, dim_y, dim_z = len(x_unique_sorted), len(y_unique_sorted), len(z_unique_sorted)
print(f"3d image dimension: (X: {dim_x}, Y: {dim_y}, Z: {dim_z})")

# Create coordinate-to-index maps
x_map, y_map, z_map = {val: i for i, val in enumerate(x_unique_sorted)}, {val: i for i, val in enumerate(y_unique_sorted)}, {val: i for i, val in enumerate(z_unique_sorted)}
x_indices, y_indices, z_indices = np.array([x_map[val] for val in x_coords_all]), np.array([y_map[val] for val in y_coords_all]), np.array([z_map[val] for val in z_coords_all])

# Reshape voxel data into 3D images
patient_id_cols = imaging_df.columns[3:]
num_patients = len(patient_id_cols)
all_patient_images = np.zeros((num_patients, dim_x, dim_y, dim_z), dtype=np.float32)

for i, patient_col_name in enumerate(patient_id_cols):
    all_patient_images[i, x_indices, y_indices, z_indices] = imaging_df[patient_col_name].values

# Add channel dimension for PyTorch -> (N, 1, X, Y, Z)
X_data_images = np.expand_dims(all_patient_images, axis=1)
print(f"image shape: {X_data_images.shape}")

# Create a mapping DataFrame from the image data
imaging_ids_df = pd.DataFrame({
    'imaging_patient_id': patient_id_cols,
    PATIENT_ID_COL: np.arange(1, num_patients + 1), # patient ID starting from1
    'image_idx': np.arange(num_patients)
})
print("-" * 30 + "\n")
# Out:
# 3d image dimension: (X: 77, Y: 92, Z: 74)
# image shape: (742, 1, 77, 92, 74)
# ------------------------------

# %%
print("--- step 3: merge longitudinal and image ---")
outcome_df = pd.read_csv(OUTCOME_CSV_PATH)
merged_df = pd.merge(imaging_ids_df, outcome_df, on=PATIENT_ID_COL, how='inner')
print(f" {len(merged_df)} data in total")
unique_patient_ids = merged_df[PATIENT_ID_COL].unique()
print(f"{len(unique_patient_ids)} patients in total")
print("-" * 30 + "\n")
# Out:
# --- step 3: merge longitudinal and image ---
#  3826 data in total
# 742 patients in total
# ------------------------------

# %%
merged_df
# Out:
#                  imaging_patient_id   id  image_idx  MMSE  CDRSB  LDELTOTAL  \
# 0       002_S_0729_2006-07-17_5.csv    1          0  27.0    0.5        1.0
# 1       002_S_0729_2006-07-17_5.csv    1          0  27.0    0.5        NaN
# 2       002_S_0782_2006-08-14_3.csv    2          1  29.0    0.5        8.0
# 3       002_S_0782_2006-08-14_3.csv    2          1  30.0    1.0        NaN
# 4       002_S_0782_2006-08-14_3.csv    2          1  28.0    1.0        6.0
# ...                             ...  ...        ...   ...    ...        ...
# 3821  941_S_6052_2017-07-20_825.csv  740        739  27.0    2.5        7.0
# 3822  941_S_6068_2017-08-21_831.csv  741        740  27.0    3.0        1.0
# 3823  941_S_6068_2017-08-21_831.csv  741        740  25.0    4.0        0.0
# 3824  941_S_6068_2017-08-21_831.csv  741        740  26.0    3.5        1.0
# 3825  941_S_6345_2018-05-10_839.csv  742        741  28.0    2.0        8.0
#
#       Years_bl   AGE  GENDER  PTEDUCAT  APOE4
# 0     0.000000  65.1       1        16      1
# 1     0.558522  65.1       1        16      1
# 2     0.000000  81.6       0        16      0
# 3     0.594114  81.6       0        16      0
# 4     1.078710  81.6       0        16      0
# ...        ...   ...     ...       ...    ...
# 3821  0.928131  88.1       1        16      1
# 3822  0.000000  75.7       0        12      1
# 3823  0.955510  75.7       0        12      1
# 3824  1.968510  75.7       0        12      1
# 3825  0.000000  79.3       0        12      1
#
# [3826 rows x 11 columns]

# %%
class LongitudinalPatientDataset(Dataset):
    def __init__(self, df, patient_ids, all_images, tabular_cols, outcome_cols, scalers=None):
        self.df = df
        self.patient_ids = patient_ids
        self.all_images = all_images
        self.tabular_cols = tabular_cols
        self.outcome_cols = outcome_cols
        self.scalers = scalers

    def __len__(self):
        return len(self.patient_ids)

    def __getitem__(self, idx):
        patient_id = self.patient_ids[idx]
        patient_df = self.df[self.df[PATIENT_ID_COL] == patient_id].copy()

        # image loading
        image_idx = patient_df['image_idx'].iloc[0]
        image_tensor = torch.from_numpy(self.all_images[image_idx].astype(np.float32))
        min_val, max_val = torch.min(image_tensor), torch.max(image_tensor)
        image_tensor = (image_tensor - min_val) / (max_val - min_val) if (max_val - min_val) > 1e-6 else torch.zeros_like(image_tensor)

        # linear covariates
        tabular_vals_1d = patient_df[self.tabular_cols].iloc[0].values
        tabular_vals_2d = tabular_vals_1d.reshape(1, -1)

        if self.scalers and 'tabular' in self.scalers:
            tabular_vals_2d = self.scalers['tabular'].transform(tabular_vals_2d)

        tabular_tensor = torch.tensor(tabular_vals_2d.astype(np.float32)).squeeze(0)

        # longitudinal_data
        longitudinal_data = {}
        patient_outcome_df = patient_df[[TIME_COL] + self.outcome_cols]
        for outcome in self.outcome_cols:
            times = torch.tensor(patient_outcome_df[TIME_COL].values, dtype=torch.float32)
            values = patient_outcome_df[[outcome]].values
            if self.scalers and 'outcomes' in self.scalers and outcome in self.scalers['outcomes']:
                values = self.scalers['outcomes'][outcome].transform(values)
            values = torch.tensor(values.flatten(), dtype=torch.float32)
            longitudinal_data[outcome] = (times, values)

        return {'image': image_tensor, 'tabular': tabular_tensor, 'longitudinal': longitudinal_data}



class MultiOutcomeCNN(nn.Module):
    def __init__(self, num_tabular_features, num_outcomes=3):
        super(MultiOutcomeCNN, self).__init__()
        output_dim = num_outcomes * 2

        # cnn
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 32, 3, 1, 1), nn.BatchNorm3d(32), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(32, 64, 3, 1, 1), nn.BatchNorm3d(64), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(64, 128, 3, 1, 1), nn.BatchNorm3d(128), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(128, 256, 3, 1, 1), nn.BatchNorm3d(256), nn.ReLU(True), nn.MaxPool3d(2, 2)
        )
        self.pooling = nn.AdaptiveAvgPool3d((1, 1, 1))
        self.flatten = nn.Flatten()

        # fc
        self.image_processor = nn.Sequential(
            nn.Linear(256, 64), nn.ReLU(True), nn.Dropout(p=0.3),
            nn.Linear(64, output_dim) # output dim 6
        )

        self.tabular_processor = nn.Linear(num_tabular_features, output_dim, bias=True)

        self.apply(self._initialize_weights)

    def _initialize_weights(self, m):
        if isinstance(m, (nn.Conv3d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm3d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

    def forward(self, x_img, x_tab):
        img_features = self.flatten(self.pooling(self.encoder(x_img)))
        params_from_image = self.image_processor(img_features)
        params_from_tabular = self.tabular_processor(x_tab)
        # add up linear and non-linear
        final_params = params_from_image + params_from_tabular
        return final_params


class LongitudinalLossUnsimplified(nn.Module):
    def __init__(self, outcome_cols):
        super().__init__()
        self.outcome_cols = outcome_cols
        self.k_dim = 2  # each outcome has 2 output

    def forward(self, f_pred_batch, y_long_batch):
        batch_loss = 0.0
        for i in range(len(y_long_batch)):
            f_pred_patient = f_pred_batch[i]
            patient_data = y_long_batch[i]['longitudinal']
            patient_loss_sum = 0.0

            for j, outcome_name in enumerate(self.outcome_cols):
                f_j = f_pred_patient[j * self.k_dim : (j + 1) * self.k_dim]
                a_j, b_j = f_j[0], f_j[1]

                times, values = patient_data[outcome_name]
                times, values = times.to(DEVICE), values.to(DEVICE)


                # 1. how many k for each ij(mij)
                num_valid_obs = (~torch.isnan(values)).sum().item()

                if num_valid_obs == 0:
                    continue

                w_ij = 1.0 / num_valid_obs


                sum_of_squared_errors = 0.0

                for k in range(len(times)):
                    y_ijk = values[k]

                    if torch.isnan(y_ijk):
                        continue

                    T_ijk = times[k]
                    predicted_value = a_j + b_j * T_ijk
                    squared_error = (y_ijk - predicted_value)**2
                    sum_of_squared_errors += squared_error

                patient_loss_sum += w_ij * sum_of_squared_errors

            batch_loss += patient_loss_sum

        return batch_loss / len(y_long_batch)

# %%
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
fold_results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(unique_patient_ids)):
    print(f"\n========== fold {fold+1}/{N_SPLITS} ==========")

    # 1. split based on subjecy
    train_ids = unique_patient_ids[train_idx]
    val_ids = unique_patient_ids[val_idx]
    # train_df 和 val_df now unscaled
    train_df = merged_df[merged_df[PATIENT_ID_COL].isin(train_ids)].copy()
    val_df = merged_df[merged_df[PATIENT_ID_COL].isin(val_ids)].copy()

    # linear covariate scaler
    tabular_scaler = StandardScaler()
    tabular_scaler.fit(train_df[STATIC_TABULAR_COLS]) # 只fit

    # y scalers
    outcome_scalers = {}
    for col in OUTCOME_COLS:
        scaler = StandardScaler()
        scaler.fit(train_df[[col]].dropna())
        outcome_scalers[col] = scaler

    # 3.create Dataset and DataLoader
    all_scalers = {'tabular': tabular_scaler, 'outcomes': outcome_scalers}
    train_dataset = LongitudinalPatientDataset(train_df, train_ids, X_data_images, STATIC_TABULAR_COLS, OUTCOME_COLS, all_scalers)
    val_dataset = LongitudinalPatientDataset(val_df, val_ids, X_data_images, STATIC_TABULAR_COLS, OUTCOME_COLS, all_scalers)

    def collate_fn(batch):
        images = torch.stack([item['image'] for item in batch])
        tabulars = torch.stack([item['tabular'] for item in batch])
        longitudinals = [item for item in batch]
        return {'image': images, 'tabular': tabulars, 'longitudinal': longitudinals}

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, collate_fn=collate_fn, num_workers=2, pin_memory=True)

    """model = MultiOutcomeCNN(num_tabular_features=len(STATIC_TABULAR_COLS), num_outcomes=len(OUTCOME_COLS)).to(DEVICE)
    PATH_TO_WEIGHTS = "best_model.pth" # <--- CHANGE THIS TO YOUR FILE PATH
    model.load_state_dict(torch.load(PATH_TO_WEIGHTS, map_location=DEVICE))
    # 4. Set up the criterion as before
    criterion = LongitudinalLossUnsimplified(outcome_cols=OUTCOME_COLS)
    optimizer = optim.AdamW(model.parameters(), lr=5e-6, weight_decay=1e-5)"""


    model = MultiOutcomeCNN(num_tabular_features=len(STATIC_TABULAR_COLS), num_outcomes=len(OUTCOME_COLS)).to(DEVICE)
    criterion = LongitudinalLossUnsimplified(outcome_cols=OUTCOME_COLS)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    #optimizer = optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-4)

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=20, min_lr=1e-8)

    # 5.training and validation
    best_val_loss = float('inf')
    best_val_r2 = {outcome: -float('inf') for outcome in OUTCOME_COLS}
    best_train_r2 = {outcome: -float('inf') for outcome in OUTCOME_COLS}
    epochs_no_improve = 0
    num_epochs = 500
    early_stopping_patience = 100

    for epoch in range(num_epochs):
        print(f"--- Epoch [{epoch+1:03d}/{num_epochs}] ---")
        model.train()
        train_loss_sum = 0
        train_r2_data = {outcome: {'true': [], 'pred_params': [], 'times': []} for outcome in OUTCOME_COLS}

        for batch in train_loader:
            images, tabulars, longitudinals = batch['image'].to(DEVICE), batch['tabular'].to(DEVICE), batch['longitudinal']
            optimizer.zero_grad()
            f_pred = model(images, tabulars)
            loss = criterion(f_pred, longitudinals)
            loss.backward()
            optimizer.step()
            train_loss_sum += loss.item()

            for i in range(len(longitudinals)):
                f_pred_patient = f_pred[i].detach()
                for j, outcome in enumerate(OUTCOME_COLS):
                    times, values = longitudinals[i]['longitudinal'][outcome]
                    mask = ~torch.isnan(values)
                    if mask.sum() > 0:
                        train_r2_data[outcome]['true'].extend(values[mask].cpu().numpy())
                        train_r2_data[outcome]['times'].extend(times[mask].cpu().numpy())
                        params_j = f_pred_patient[j*2:(j+1)*2]
                        train_r2_data[outcome]['pred_params'].extend([params_j.cpu()] * mask.sum())

        model.eval()
        val_loss_sum = 0
        val_r2_data = {outcome: {'true': [], 'pred_params': [], 'times': []} for outcome in OUTCOME_COLS}
        with torch.no_grad():
            for batch in val_loader:
                images, tabulars, longitudinals = batch['image'].to(DEVICE), batch['tabular'].to(DEVICE), batch['longitudinal']
                f_pred = model(images, tabulars)
                loss = criterion(f_pred, longitudinals)
                val_loss_sum += loss.item()
                for i in range(len(longitudinals)):
                    f_pred_patient = f_pred[i]
                    for j, outcome in enumerate(OUTCOME_COLS):
                        times, values = longitudinals[i]['longitudinal'][outcome]
                        mask = ~torch.isnan(values)
                        if mask.sum() > 0:
                            val_r2_data[outcome]['true'].extend(values[mask].cpu().numpy())
                            val_r2_data[outcome]['times'].extend(times[mask].cpu().numpy())
                            params_j = f_pred_patient[j*2:(j+1)*2]
                            val_r2_data[outcome]['pred_params'].extend([params_j.cpu()] * mask.sum())

        avg_train_loss = train_loss_sum / len(train_loader)
        avg_val_loss = val_loss_sum / len(val_loader)
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Loss -> Train: {avg_train_loss:.6f}, Val: {avg_val_loss:.6f} | LR: {current_lr:.1e}")

        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names")

            current_train_r2 = {}
            print("  R² (Train) -> ", end="")
            for outcome, data in train_r2_data.items():
                if len(data['true']) > 1:
                    y_pred = [p[0] + p[1] * t for p, t in zip(data['pred_params'], data['times'])]
                    y_true_unscaled = outcome_scalers[outcome].inverse_transform(np.array(data['true']).reshape(-1, 1))
                    y_pred_unscaled = outcome_scalers[outcome].inverse_transform(np.array(y_pred).reshape(-1, 1))
                    r2 = r2_score(y_true_unscaled, y_pred_unscaled)
                    current_train_r2[outcome] = r2
                    print(f"{outcome}: {r2:.4f}; ", end="")
            print()

            current_val_r2 = {}
            print("  R² (Val)   -> ", end="")
            for outcome, data in val_r2_data.items():
                if len(data['true']) > 1:
                    y_pred = [p[0] + p[1] * t for p, t in zip(data['pred_params'], data['times'])]
                    y_true_unscaled = outcome_scalers[outcome].inverse_transform(np.array(data['true']).reshape(-1, 1))
                    y_pred_unscaled = outcome_scalers[outcome].inverse_transform(np.array(y_pred).reshape(-1, 1))
                    r2 = r2_score(y_true_unscaled, y_pred_unscaled)
                    current_val_r2[outcome] = r2
                    print(f"{outcome}: {r2:.4f}; ", end="")
            print()

        scheduler.step(avg_val_loss)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_val_r2 = current_val_r2
            best_train_r2 = current_train_r2
            epochs_no_improve = 0
            torch.save(model.state_dict(), f"best_model_fold_{fold+1}.pth")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= early_stopping_patience:
                print(f"\n提前停止于周期 {epoch+1}.")
                break

    fold_results.append({'loss': best_val_loss, 'val_r2': best_val_r2, 'train_r2': best_train_r2})
    print(f"\n折叠 {fold+1} 完成。最佳验证损失: {best_val_loss:.6f}")
    print(f"对应的验证集R²: {best_val_r2}")
    print(f"对应的训练集R²: {best_train_r2}")

print("\n" + "="*30)
print("--- 交叉验证结果总结 ---")
print("="*30)
avg_loss = np.mean([res['loss'] for res in fold_results])
std_loss = np.std([res['loss'] for res in fold_results])
print(f"平均最佳验证损失: {avg_loss:.6f} ± {std_loss:.6f}")

for outcome in OUTCOME_COLS:
    val_r2_scores = [res['val_r2'].get(outcome, np.nan) for res in fold_results]
    train_r2_scores = [res['train_r2'].get(outcome, np.nan) for res in fold_results]
    print(f"  - {outcome} 平均 Val R²:   {np.nanmean(val_r2_scores):.4f} ± {np.nanstd(val_r2_scores):.4f}")
    print(f"  - {outcome} 平均 Train R²: {np.nanmean(train_r2_scores):.4f} ± {np.nanstd(train_r2_scores):.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   R² (Val)   -> MMSE: 0.0950; CDRSB: 0.0359; LDELTOTAL: 0.2768;
# --- Epoch [331/500] ---
# Loss -> Train: 2.432549, Val: 3.165931 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1272; CDRSB: 0.0954; LDELTOTAL: 0.2597;
#   R² (Val)   -> MMSE: 0.0905; CDRSB: 0.0362; LDELTOTAL: 0.2858;
# --- Epoch [332/500] ---
# Loss -> Train: 2.439197, Val: 3.172142 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1135; CDRSB: 0.1021; LDELTOTAL: 0.2653;
#   R² (Val)   -> MMSE: 0.0944; CDRSB: 0.0369; LDELTOTAL: 0.2801;
# --- Epoch [333/500] ---
# Loss -> Train: 2.379273, Val: 3.171383 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1404; CDRSB: 0.1267; LDELTOTAL: 0.2762;
#   R² (Val)   -> MMSE: 0.0943; CDRSB: 0.0343; LDELTOTAL: 0.2802;
# --- Epoch [334/500] ---
# Loss -> Train: 2.413634, Val: 3.169448 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1305; CDRSB: 0.0942; LDELTOTAL: 0.2762;
#   R² (Val)   -> MMSE: 0.0869; CDRSB: 0.0355; LDELTOTAL: 0.2873;
# --- Epoch [335/500] ---
# Loss -> Train: 2.383397, Val: 3.167295 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1394; CDRSB: 0.1075; LDELTOTAL: 0.2665;
#   R² (Val)   -> MMSE: 0.0940; CDRSB: 0.0327; LDELTOTAL: 0.2818;
# --- Epoch [336/500] ---
# Loss -> Train: 2.434175, Val: 3.162109 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1365; CDRSB: 0.0605; LDELTOTAL: 0.2548;
#   R² (Val)   -> MMSE: 0.0937; CDRSB: 0.0323; LDELTOTAL: 0.2863;
# --- Epoch [337/500] ---
# Loss -> Train: 2.435442, Val: 3.162872 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1221; CDRSB: 0.0862; LDELTOTAL: 0.2579;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0361; LDELTOTAL: 0.2854;
# --- Epoch [338/500] ---
# Loss -> Train: 2.414596, Val: 3.178648 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1383; CDRSB: 0.0894; LDELTOTAL: 0.2673;
#   R² (Val)   -> MMSE: 0.0937; CDRSB: 0.0364; LDELTOTAL: 0.2773;
# --- Epoch [339/500] ---
# Loss -> Train: 2.402568, Val: 3.172603 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1354; CDRSB: 0.0962; LDELTOTAL: 0.2666;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0378; LDELTOTAL: 0.2811;
# --- Epoch [340/500] ---
# Loss -> Train: 2.439390, Val: 3.167083 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1331; CDRSB: 0.0841; LDELTOTAL: 0.2627;
#   R² (Val)   -> MMSE: 0.0931; CDRSB: 0.0296; LDELTOTAL: 0.2811;
# --- Epoch [341/500] ---
# Loss -> Train: 2.499585, Val: 3.170025 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1106; CDRSB: 0.0572; LDELTOTAL: 0.2448;
#   R² (Val)   -> MMSE: 0.0940; CDRSB: 0.0375; LDELTOTAL: 0.2822;
# --- Epoch [342/500] ---
# Loss -> Train: 2.453181, Val: 3.168055 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1143; CDRSB: 0.0956; LDELTOTAL: 0.2599;
#   R² (Val)   -> MMSE: 0.0915; CDRSB: 0.0351; LDELTOTAL: 0.2847;
# --- Epoch [343/500] ---
# Loss -> Train: 2.388651, Val: 3.163305 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1408; CDRSB: 0.1196; LDELTOTAL: 0.2782;
#   R² (Val)   -> MMSE: 0.0920; CDRSB: 0.0354; LDELTOTAL: 0.2878;
# --- Epoch [344/500] ---
# Loss -> Train: 2.470216, Val: 3.167832 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1293; CDRSB: 0.0761; LDELTOTAL: 0.2519;
#   R² (Val)   -> MMSE: 0.0940; CDRSB: 0.0358; LDELTOTAL: 0.2826;
# --- Epoch [345/500] ---
# Loss -> Train: 2.424266, Val: 3.163764 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1177; CDRSB: 0.1190; LDELTOTAL: 0.2785;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0343; LDELTOTAL: 0.2857;
# --- Epoch [346/500] ---
# Loss -> Train: 2.466749, Val: 3.166664 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1378; CDRSB: 0.1071; LDELTOTAL: 0.2722;
#   R² (Val)   -> MMSE: 0.0924; CDRSB: 0.0357; LDELTOTAL: 0.2838;
# --- Epoch [347/500] ---
# Loss -> Train: 2.458392, Val: 3.169024 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1146; CDRSB: 0.0758; LDELTOTAL: 0.2447;
#   R² (Val)   -> MMSE: 0.0914; CDRSB: 0.0380; LDELTOTAL: 0.2851;
# --- Epoch [348/500] ---
# Loss -> Train: 2.428919, Val: 3.165962 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1258; CDRSB: 0.0875; LDELTOTAL: 0.2658;
#   R² (Val)   -> MMSE: 0.0894; CDRSB: 0.0335; LDELTOTAL: 0.2854;
# --- Epoch [349/500] ---
# Loss -> Train: 2.396618, Val: 3.171907 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1411; CDRSB: 0.1112; LDELTOTAL: 0.2720;
#   R² (Val)   -> MMSE: 0.0859; CDRSB: 0.0362; LDELTOTAL: 0.2870;
# --- Epoch [350/500] ---
# Loss -> Train: 2.421346, Val: 3.166122 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1137; CDRSB: 0.1079; LDELTOTAL: 0.2663;
#   R² (Val)   -> MMSE: 0.0894; CDRSB: 0.0365; LDELTOTAL: 0.2874;
# --- Epoch [351/500] ---
# Loss -> Train: 2.394851, Val: 3.171312 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1463; CDRSB: 0.0921; LDELTOTAL: 0.2650;
#   R² (Val)   -> MMSE: 0.0904; CDRSB: 0.0378; LDELTOTAL: 0.2839;
# --- Epoch [352/500] ---
# Loss -> Train: 2.441147, Val: 3.168697 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1291; CDRSB: 0.0701; LDELTOTAL: 0.2627;
#   R² (Val)   -> MMSE: 0.0931; CDRSB: 0.0344; LDELTOTAL: 0.2826;
# --- Epoch [353/500] ---
# Loss -> Train: 2.412897, Val: 3.164782 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1304; CDRSB: 0.0932; LDELTOTAL: 0.2617;
#   R² (Val)   -> MMSE: 0.0939; CDRSB: 0.0358; LDELTOTAL: 0.2849;
# --- Epoch [354/500] ---
# Loss -> Train: 2.420919, Val: 3.172248 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1196; CDRSB: 0.1112; LDELTOTAL: 0.2582;
#   R² (Val)   -> MMSE: 0.0956; CDRSB: 0.0324; LDELTOTAL: 0.2776;
# --- Epoch [355/500] ---
# Loss -> Train: 2.419267, Val: 3.162041 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1196; CDRSB: 0.0649; LDELTOTAL: 0.2465;
#   R² (Val)   -> MMSE: 0.0920; CDRSB: 0.0332; LDELTOTAL: 0.2881;
# --- Epoch [356/500] ---
# Loss -> Train: 2.474443, Val: 3.176718 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1147; CDRSB: 0.0580; LDELTOTAL: 0.2537;
#   R² (Val)   -> MMSE: 0.0916; CDRSB: 0.0378; LDELTOTAL: 0.2808;
# --- Epoch [357/500] ---
# Loss -> Train: 2.457869, Val: 3.166701 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1220; CDRSB: 0.0840; LDELTOTAL: 0.2645;
#   R² (Val)   -> MMSE: 0.0917; CDRSB: 0.0361; LDELTOTAL: 0.2849;
# --- Epoch [358/500] ---
# Loss -> Train: 2.413654, Val: 3.171800 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1247; CDRSB: 0.0801; LDELTOTAL: 0.2696;
#   R² (Val)   -> MMSE: 0.0915; CDRSB: 0.0373; LDELTOTAL: 0.2831;
# --- Epoch [359/500] ---
# Loss -> Train: 2.399303, Val: 3.170401 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1472; CDRSB: 0.1108; LDELTOTAL: 0.2847;
#   R² (Val)   -> MMSE: 0.0888; CDRSB: 0.0359; LDELTOTAL: 0.2869;
# --- Epoch [360/500] ---
# Loss -> Train: 2.491178, Val: 3.167387 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1094; CDRSB: 0.0438; LDELTOTAL: 0.2509;
#   R² (Val)   -> MMSE: 0.0896; CDRSB: 0.0351; LDELTOTAL: 0.2869;
# --- Epoch [361/500] ---
# Loss -> Train: 2.458781, Val: 3.179030 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1283; CDRSB: 0.0691; LDELTOTAL: 0.2618;
#   R² (Val)   -> MMSE: 0.0937; CDRSB: 0.0354; LDELTOTAL: 0.2759;
# --- Epoch [362/500] ---
# Loss -> Train: 2.440204, Val: 3.164276 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1166; CDRSB: 0.0655; LDELTOTAL: 0.2606;
#   R² (Val)   -> MMSE: 0.0945; CDRSB: 0.0359; LDELTOTAL: 0.2861;
# --- Epoch [363/500] ---
# Loss -> Train: 2.477661, Val: 3.174857 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1187; CDRSB: 0.0898; LDELTOTAL: 0.2628;
#   R² (Val)   -> MMSE: 0.0944; CDRSB: 0.0377; LDELTOTAL: 0.2797;
# --- Epoch [364/500] ---
# Loss -> Train: 2.392570, Val: 3.169077 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1440; CDRSB: 0.1011; LDELTOTAL: 0.2825;
#   R² (Val)   -> MMSE: 0.0935; CDRSB: 0.0323; LDELTOTAL: 0.2829;
# --- Epoch [365/500] ---
# Loss -> Train: 2.417353, Val: 3.167448 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1272; CDRSB: 0.0988; LDELTOTAL: 0.2756;
#   R² (Val)   -> MMSE: 0.0932; CDRSB: 0.0368; LDELTOTAL: 0.2841;
# --- Epoch [366/500] ---
# Loss -> Train: 2.475777, Val: 3.165427 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1076; CDRSB: 0.1130; LDELTOTAL: 0.2609;
#   R² (Val)   -> MMSE: 0.0928; CDRSB: 0.0333; LDELTOTAL: 0.2851;
# --- Epoch [367/500] ---
# Loss -> Train: 2.405295, Val: 3.177094 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1277; CDRSB: 0.0995; LDELTOTAL: 0.2767;
#   R² (Val)   -> MMSE: 0.0918; CDRSB: 0.0381; LDELTOTAL: 0.2819;
# --- Epoch [368/500] ---
# Loss -> Train: 2.414708, Val: 3.177625 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1257; CDRSB: 0.1207; LDELTOTAL: 0.2576;
#   R² (Val)   -> MMSE: 0.0918; CDRSB: 0.0376; LDELTOTAL: 0.2803;
# --- Epoch [369/500] ---
# Loss -> Train: 2.448537, Val: 3.166311 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1090; CDRSB: 0.0823; LDELTOTAL: 0.2539;
#   R² (Val)   -> MMSE: 0.0906; CDRSB: 0.0364; LDELTOTAL: 0.2860;
# --- Epoch [370/500] ---
# Loss -> Train: 2.461443, Val: 3.174406 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1089; CDRSB: 0.0716; LDELTOTAL: 0.2398;
#   R² (Val)   -> MMSE: 0.0950; CDRSB: 0.0350; LDELTOTAL: 0.2775;
# --- Epoch [371/500] ---
# Loss -> Train: 2.362695, Val: 3.169990 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1492; CDRSB: 0.0997; LDELTOTAL: 0.2719;
#   R² (Val)   -> MMSE: 0.0903; CDRSB: 0.0370; LDELTOTAL: 0.2847;
# --- Epoch [372/500] ---
# Loss -> Train: 2.468160, Val: 3.173153 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1439; CDRSB: 0.0921; LDELTOTAL: 0.2688;
#   R² (Val)   -> MMSE: 0.0928; CDRSB: 0.0395; LDELTOTAL: 0.2818;
# --- Epoch [373/500] ---
# Loss -> Train: 2.439885, Val: 3.165499 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1318; CDRSB: 0.0702; LDELTOTAL: 0.2482;
#   R² (Val)   -> MMSE: 0.0918; CDRSB: 0.0379; LDELTOTAL: 0.2877;
# --- Epoch [374/500] ---
# Loss -> Train: 2.445490, Val: 3.168492 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1146; CDRSB: 0.0572; LDELTOTAL: 0.2612;
#   R² (Val)   -> MMSE: 0.0917; CDRSB: 0.0370; LDELTOTAL: 0.2841;
# --- Epoch [375/500] ---
# Loss -> Train: 2.417110, Val: 3.166409 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1254; CDRSB: 0.0837; LDELTOTAL: 0.2577;
#   R² (Val)   -> MMSE: 0.0921; CDRSB: 0.0363; LDELTOTAL: 0.2844;
# --- Epoch [376/500] ---
# Loss -> Train: 2.398693, Val: 3.171057 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1324; CDRSB: 0.1348; LDELTOTAL: 0.2682;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0350; LDELTOTAL: 0.2807;
# --- Epoch [377/500] ---
# Loss -> Train: 2.397043, Val: 3.176213 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1458; CDRSB: 0.1185; LDELTOTAL: 0.2687;
#   R² (Val)   -> MMSE: 0.0912; CDRSB: 0.0368; LDELTOTAL: 0.2812;
# --- Epoch [378/500] ---
# Loss -> Train: 2.570165, Val: 3.165211 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0963; CDRSB: 0.0800; LDELTOTAL: 0.2446;
#   R² (Val)   -> MMSE: 0.0929; CDRSB: 0.0351; LDELTOTAL: 0.2840;
# --- Epoch [379/500] ---
# Loss -> Train: 2.413939, Val: 3.163268 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1295; CDRSB: 0.0811; LDELTOTAL: 0.2573;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: 0.0335; LDELTOTAL: 0.2861;
# --- Epoch [380/500] ---
# Loss -> Train: 2.514738, Val: 3.168705 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1166; CDRSB: 0.0453; LDELTOTAL: 0.2499;
#   R² (Val)   -> MMSE: 0.0904; CDRSB: 0.0358; LDELTOTAL: 0.2862;
# --- Epoch [381/500] ---
# Loss -> Train: 2.437959, Val: 3.163246 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1106; CDRSB: 0.1276; LDELTOTAL: 0.2727;
#   R² (Val)   -> MMSE: 0.0933; CDRSB: 0.0337; LDELTOTAL: 0.2871;
# --- Epoch [382/500] ---
# Loss -> Train: 2.420718, Val: 3.165636 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1228; CDRSB: 0.1039; LDELTOTAL: 0.2627;
#   R² (Val)   -> MMSE: 0.0905; CDRSB: 0.0349; LDELTOTAL: 0.2865;
# --- Epoch [383/500] ---
# Loss -> Train: 2.418409, Val: 3.174724 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1230; CDRSB: 0.0816; LDELTOTAL: 0.2670;
#   R² (Val)   -> MMSE: 0.0910; CDRSB: 0.0383; LDELTOTAL: 0.2828;
# --- Epoch [384/500] ---
# Loss -> Train: 2.407049, Val: 3.173216 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1465; CDRSB: 0.1011; LDELTOTAL: 0.2732;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: 0.0354; LDELTOTAL: 0.2815;
# --- Epoch [385/500] ---
# Loss -> Train: 2.394599, Val: 3.166416 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1416; CDRSB: 0.1130; LDELTOTAL: 0.2654;
#   R² (Val)   -> MMSE: 0.0949; CDRSB: 0.0339; LDELTOTAL: 0.2841;
# --- Epoch [386/500] ---
# Loss -> Train: 2.438530, Val: 3.165753 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1418; CDRSB: 0.0818; LDELTOTAL: 0.2643;
#   R² (Val)   -> MMSE: 0.0955; CDRSB: 0.0327; LDELTOTAL: 0.2818;
# --- Epoch [387/500] ---
# Loss -> Train: 2.420498, Val: 3.165961 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1223; CDRSB: 0.0943; LDELTOTAL: 0.2711;
#   R² (Val)   -> MMSE: 0.0959; CDRSB: 0.0340; LDELTOTAL: 0.2836;
# --- Epoch [388/500] ---
# Loss -> Train: 2.500345, Val: 3.177121 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1484; CDRSB: 0.0839; LDELTOTAL: 0.2793;
#   R² (Val)   -> MMSE: 0.0931; CDRSB: 0.0391; LDELTOTAL: 0.2793;
# --- Epoch [389/500] ---
# Loss -> Train: 2.440601, Val: 3.169668 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1206; CDRSB: 0.1028; LDELTOTAL: 0.2633;
#   R² (Val)   -> MMSE: 0.0848; CDRSB: 0.0326; LDELTOTAL: 0.2874;
# --- Epoch [390/500] ---
# Loss -> Train: 2.414562, Val: 3.167742 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1399; CDRSB: 0.0868; LDELTOTAL: 0.2665;
#   R² (Val)   -> MMSE: 0.0922; CDRSB: 0.0386; LDELTOTAL: 0.2853;
# --- Epoch [391/500] ---
# Loss -> Train: 2.434040, Val: 3.170841 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1220; CDRSB: 0.0887; LDELTOTAL: 0.2423;
#   R² (Val)   -> MMSE: 0.0894; CDRSB: 0.0368; LDELTOTAL: 0.2850;
# --- Epoch [392/500] ---
# Loss -> Train: 2.492106, Val: 3.167373 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1290; CDRSB: 0.0762; LDELTOTAL: 0.2631;
#   R² (Val)   -> MMSE: 0.0911; CDRSB: 0.0341; LDELTOTAL: 0.2856;
# --- Epoch [393/500] ---
# Loss -> Train: 2.446161, Val: 3.174665 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1310; CDRSB: 0.0961; LDELTOTAL: 0.2551;
#   R² (Val)   -> MMSE: 0.0956; CDRSB: 0.0326; LDELTOTAL: 0.2768;
# --- Epoch [394/500] ---
# Loss -> Train: 2.426511, Val: 3.163144 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1184; CDRSB: 0.0958; LDELTOTAL: 0.2651;
#   R² (Val)   -> MMSE: 0.0891; CDRSB: 0.0331; LDELTOTAL: 0.2893;
# --- Epoch [395/500] ---
# Loss -> Train: 2.399964, Val: 3.170602 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1267; CDRSB: 0.1140; LDELTOTAL: 0.2695;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0376; LDELTOTAL: 0.2833;
# --- Epoch [396/500] ---
# Loss -> Train: 2.463935, Val: 3.177848 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0938; CDRSB: 0.0547; LDELTOTAL: 0.2402;
#   R² (Val)   -> MMSE: 0.0944; CDRSB: 0.0372; LDELTOTAL: 0.2769;
# --- Epoch [397/500] ---
# Loss -> Train: 2.408198, Val: 3.167323 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1428; CDRSB: 0.1231; LDELTOTAL: 0.2786;
#   R² (Val)   -> MMSE: 0.0937; CDRSB: 0.0341; LDELTOTAL: 0.2824;
# --- Epoch [398/500] ---
# Loss -> Train: 2.461196, Val: 3.169448 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1157; CDRSB: 0.1015; LDELTOTAL: 0.2693;
#   R² (Val)   -> MMSE: 0.0911; CDRSB: 0.0326; LDELTOTAL: 0.2816;
# --- Epoch [399/500] ---
# Loss -> Train: 2.505894, Val: 3.173520 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1106; CDRSB: 0.0722; LDELTOTAL: 0.2547;
#   R² (Val)   -> MMSE: 0.0943; CDRSB: 0.0362; LDELTOTAL: 0.2800;
# --- Epoch [400/500] ---
# Loss -> Train: 2.478866, Val: 3.165169 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1041; CDRSB: 0.1001; LDELTOTAL: 0.2324;
#   R² (Val)   -> MMSE: 0.0948; CDRSB: 0.0347; LDELTOTAL: 0.2822;
# --- Epoch [401/500] ---
# Loss -> Train: 2.412264, Val: 3.165563 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1381; CDRSB: 0.0889; LDELTOTAL: 0.2607;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: 0.0334; LDELTOTAL: 0.2856;
# --- Epoch [402/500] ---
# Loss -> Train: 2.389263, Val: 3.180468 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1382; CDRSB: 0.1093; LDELTOTAL: 0.2662;
#   R² (Val)   -> MMSE: 0.0950; CDRSB: 0.0358; LDELTOTAL: 0.2746;
# --- Epoch [403/500] ---
# Loss -> Train: 2.462309, Val: 3.169388 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1262; CDRSB: 0.0963; LDELTOTAL: 0.2602;
#   R² (Val)   -> MMSE: 0.0919; CDRSB: 0.0363; LDELTOTAL: 0.2837;
# --- Epoch [404/500] ---
# Loss -> Train: 2.429393, Val: 3.166855 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1311; CDRSB: 0.0930; LDELTOTAL: 0.2764;
#   R² (Val)   -> MMSE: 0.0952; CDRSB: 0.0361; LDELTOTAL: 0.2816;
# --- Epoch [405/500] ---
# Loss -> Train: 2.448124, Val: 3.169529 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1234; CDRSB: 0.0895; LDELTOTAL: 0.2491;
#   R² (Val)   -> MMSE: 0.0919; CDRSB: 0.0321; LDELTOTAL: 0.2812;
# --- Epoch [406/500] ---
# Loss -> Train: 2.403578, Val: 3.171375 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1332; CDRSB: 0.0933; LDELTOTAL: 0.2736;
#   R² (Val)   -> MMSE: 0.0963; CDRSB: 0.0351; LDELTOTAL: 0.2794;
# --- Epoch [407/500] ---
# Loss -> Train: 2.401879, Val: 3.173329 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1350; CDRSB: 0.0694; LDELTOTAL: 0.2614;
#   R² (Val)   -> MMSE: 0.0913; CDRSB: 0.0383; LDELTOTAL: 0.2843;
# --- Epoch [408/500] ---
# Loss -> Train: 2.417752, Val: 3.166051 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1208; CDRSB: 0.1054; LDELTOTAL: 0.2659;
#   R² (Val)   -> MMSE: 0.0916; CDRSB: 0.0361; LDELTOTAL: 0.2859;
# --- Epoch [409/500] ---
# Loss -> Train: 2.441479, Val: 3.172268 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1146; CDRSB: 0.1014; LDELTOTAL: 0.2581;
#   R² (Val)   -> MMSE: 0.0943; CDRSB: 0.0372; LDELTOTAL: 0.2802;
# --- Epoch [410/500] ---
# Loss -> Train: 2.502834, Val: 3.169732 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1175; CDRSB: 0.0903; LDELTOTAL: 0.2593;
#   R² (Val)   -> MMSE: 0.0927; CDRSB: 0.0382; LDELTOTAL: 0.2840;
# --- Epoch [411/500] ---
# Loss -> Train: 2.395950, Val: 3.172155 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1391; CDRSB: 0.1078; LDELTOTAL: 0.2737;
#   R² (Val)   -> MMSE: 0.0907; CDRSB: 0.0380; LDELTOTAL: 0.2843;
# --- Epoch [412/500] ---
# Loss -> Train: 2.430953, Val: 3.174503 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1394; CDRSB: 0.1133; LDELTOTAL: 0.2649;
#   R² (Val)   -> MMSE: 0.0928; CDRSB: 0.0366; LDELTOTAL: 0.2800;
# --- Epoch [413/500] ---
# Loss -> Train: 2.407814, Val: 3.165464 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1359; CDRSB: 0.0906; LDELTOTAL: 0.2844;
#   R² (Val)   -> MMSE: 0.0914; CDRSB: 0.0347; LDELTOTAL: 0.2872;
# --- Epoch [414/500] ---
# Loss -> Train: 2.452191, Val: 3.160187 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1175; CDRSB: 0.0889; LDELTOTAL: 0.2635;
#   R² (Val)   -> MMSE: 0.0952; CDRSB: 0.0346; LDELTOTAL: 0.2860;
# --- Epoch [415/500] ---
# Loss -> Train: 2.454702, Val: 3.182111 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1314; CDRSB: 0.0825; LDELTOTAL: 0.2477;
#   R² (Val)   -> MMSE: 0.0940; CDRSB: 0.0372; LDELTOTAL: 0.2759;
# --- Epoch [416/500] ---
# Loss -> Train: 2.462819, Val: 3.165894 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1115; CDRSB: 0.0699; LDELTOTAL: 0.2626;
#   R² (Val)   -> MMSE: 0.0903; CDRSB: 0.0344; LDELTOTAL: 0.2861;
# --- Epoch [417/500] ---
# Loss -> Train: 2.461626, Val: 3.171068 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1085; CDRSB: 0.0746; LDELTOTAL: 0.2348;
#   R² (Val)   -> MMSE: 0.0950; CDRSB: 0.0354; LDELTOTAL: 0.2790;
# --- Epoch [418/500] ---
# Loss -> Train: 2.445492, Val: 3.171811 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1179; CDRSB: 0.0862; LDELTOTAL: 0.2660;
#   R² (Val)   -> MMSE: 0.0913; CDRSB: 0.0351; LDELTOTAL: 0.2819;
# --- Epoch [419/500] ---
# Loss -> Train: 2.467167, Val: 3.173039 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1255; CDRSB: 0.1011; LDELTOTAL: 0.2763;
#   R² (Val)   -> MMSE: 0.0938; CDRSB: 0.0367; LDELTOTAL: 0.2798;
# --- Epoch [420/500] ---
# Loss -> Train: 2.421972, Val: 3.171460 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1423; CDRSB: 0.0672; LDELTOTAL: 0.2638;
#   R² (Val)   -> MMSE: 0.0915; CDRSB: 0.0382; LDELTOTAL: 0.2840;
# --- Epoch [421/500] ---
# Loss -> Train: 2.421624, Val: 3.167796 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1266; CDRSB: 0.0836; LDELTOTAL: 0.2813;
#   R² (Val)   -> MMSE: 0.0966; CDRSB: 0.0342; LDELTOTAL: 0.2806;
# --- Epoch [422/500] ---
# Loss -> Train: 2.404605, Val: 3.165071 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1268; CDRSB: 0.1025; LDELTOTAL: 0.2692;
#   R² (Val)   -> MMSE: 0.0935; CDRSB: 0.0341; LDELTOTAL: 0.2836;
# --- Epoch [423/500] ---
# Loss -> Train: 2.399137, Val: 3.172291 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1382; CDRSB: 0.1013; LDELTOTAL: 0.2623;
#   R² (Val)   -> MMSE: 0.0908; CDRSB: 0.0373; LDELTOTAL: 0.2835;
# --- Epoch [424/500] ---
# Loss -> Train: 2.410807, Val: 3.169601 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1301; CDRSB: 0.1137; LDELTOTAL: 0.2733;
#   R² (Val)   -> MMSE: 0.0948; CDRSB: 0.0352; LDELTOTAL: 0.2812;
#
# 提前停止于周期 424.
#
# 折叠 2 完成。最佳验证损失: 3.159650
# 对应的验证集R²: {'MMSE': 0.09361833333969116, 'CDRSB': 0.03459572792053223, 'LDELTOTAL': 0.28795528411865234}
# 对应的训练集R²: {'MMSE': 0.11653393507003784, 'CDRSB': 0.06084686517715454, 'LDELTOTAL': 0.2470850944519043}
#
# ========== fold 3/5 ==========
# --- Epoch [001/500] ---
# Loss -> Train: 43.529100, Val: 27.333323 | LR: 1.0e-03
#   R² (Train) -> MMSE: -43.8688; CDRSB: -10.2086; LDELTOTAL: -9.3553;
#   R² (Val)   -> MMSE: -32.4382; CDRSB: -3.8859; LDELTOTAL: -2.9401;
# --- Epoch [002/500] ---
# Loss -> Train: 31.032904, Val: 24.490997 | LR: 1.0e-03
#   R² (Train) -> MMSE: -34.4237; CDRSB: -5.1135; LDELTOTAL: -3.1633;
#   R² (Val)   -> MMSE: -28.7586; CDRSB: -3.2839; LDELTOTAL: -2.3211;
# --- Epoch [003/500] ---
# Loss -> Train: 28.916832, Val: 23.899956 | LR: 1.0e-03
#   R² (Train) -> MMSE: -32.6103; CDRSB: -4.5366; LDELTOTAL: -2.4031;
#   R² (Val)   -> MMSE: -28.9030; CDRSB: -3.3783; LDELTOTAL: -2.2558;
# --- Epoch [004/500] ---
# Loss -> Train: 26.381838, Val: 20.899863 | LR: 1.0e-03
#   R² (Train) -> MMSE: -28.7743; CDRSB: -4.1504; LDELTOTAL: -2.1628;
#   R² (Val)   -> MMSE: -24.1651; CDRSB: -2.8002; LDELTOTAL: -1.6397;
# --- Epoch [005/500] ---
# Loss -> Train: 24.482547, Val: 18.440661 | LR: 1.0e-03
#   R² (Train) -> MMSE: -26.4466; CDRSB: -3.7179; LDELTOTAL: -1.7023;
#   R² (Val)   -> MMSE: -19.5702; CDRSB: -2.7660; LDELTOTAL: -1.4632;
# --- Epoch [006/500] ---
# Loss -> Train: 22.828974, Val: 17.816621 | LR: 1.0e-03
#   R² (Train) -> MMSE: -25.6300; CDRSB: -3.2052; LDELTOTAL: -1.3646;
#   R² (Val)   -> MMSE: -20.6492; CDRSB: -2.2475; LDELTOTAL: -1.0474;
# --- Epoch [007/500] ---
# Loss -> Train: 21.097123, Val: 16.592169 | LR: 1.0e-03
#   R² (Train) -> MMSE: -23.1978; CDRSB: -2.9285; LDELTOTAL: -1.1150;
#   R² (Val)   -> MMSE: -19.3646; CDRSB: -2.0550; LDELTOTAL: -0.9517;
# --- Epoch [008/500] ---
# Loss -> Train: 19.081184, Val: 14.737028 | LR: 1.0e-03
#   R² (Train) -> MMSE: -20.7687; CDRSB: -2.6699; LDELTOTAL: -0.8912;
#   R² (Val)   -> MMSE: -16.4365; CDRSB: -1.7453; LDELTOTAL: -0.7558;
# --- Epoch [009/500] ---
# Loss -> Train: 17.881142, Val: 13.563744 | LR: 1.0e-03
#   R² (Train) -> MMSE: -19.8949; CDRSB: -2.3613; LDELTOTAL: -0.7444;
#   R² (Val)   -> MMSE: -15.0566; CDRSB: -1.6436; LDELTOTAL: -0.6077;
# --- Epoch [010/500] ---
# Loss -> Train: 16.527297, Val: 14.082613 | LR: 1.0e-03
#   R² (Train) -> MMSE: -18.1475; CDRSB: -2.0650; LDELTOTAL: -0.5491;
#   R² (Val)   -> MMSE: -16.3784; CDRSB: -1.8346; LDELTOTAL: -0.7294;
# --- Epoch [011/500] ---
# Loss -> Train: 15.627212, Val: 15.156308 | LR: 1.0e-03
#   R² (Train) -> MMSE: -16.4585; CDRSB: -1.8940; LDELTOTAL: -0.4230;
#   R² (Val)   -> MMSE: -17.2605; CDRSB: -1.9518; LDELTOTAL: -1.0272;
# --- Epoch [012/500] ---
# Loss -> Train: 13.813810, Val: 10.488898 | LR: 1.0e-03
#   R² (Train) -> MMSE: -14.4825; CDRSB: -1.6597; LDELTOTAL: -0.3927;
#   R² (Val)   -> MMSE: -11.2619; CDRSB: -1.1667; LDELTOTAL: -0.3639;
# --- Epoch [013/500] ---
# Loss -> Train: 13.300252, Val: 11.301339 | LR: 1.0e-03
#   R² (Train) -> MMSE: -14.0922; CDRSB: -1.5480; LDELTOTAL: -0.3042;
#   R² (Val)   -> MMSE: -11.8909; CDRSB: -1.4208; LDELTOTAL: -0.5549;
# --- Epoch [014/500] ---
# Loss -> Train: 12.106776, Val: 9.204494 | LR: 1.0e-03
#   R² (Train) -> MMSE: -12.2399; CDRSB: -1.3261; LDELTOTAL: -0.2134;
#   R² (Val)   -> MMSE: -9.7498; CDRSB: -0.9876; LDELTOTAL: -0.3680;
# --- Epoch [015/500] ---
# Loss -> Train: 11.226281, Val: 8.480744 | LR: 1.0e-03
#   R² (Train) -> MMSE: -11.4007; CDRSB: -1.2734; LDELTOTAL: -0.2344;
#   R² (Val)   -> MMSE: -8.7081; CDRSB: -0.8425; LDELTOTAL: -0.1573;
# --- Epoch [016/500] ---
# Loss -> Train: 10.310947, Val: 8.433067 | LR: 1.0e-03
#   R² (Train) -> MMSE: -10.1975; CDRSB: -1.0392; LDELTOTAL: -0.1313;
#   R² (Val)   -> MMSE: -8.8833; CDRSB: -0.8304; LDELTOTAL: -0.1536;
# --- Epoch [017/500] ---
# Loss -> Train: 9.687789, Val: 7.503266 | LR: 1.0e-03
#   R² (Train) -> MMSE: -9.3293; CDRSB: -0.9658; LDELTOTAL: -0.0743;
#   R² (Val)   -> MMSE: -7.5173; CDRSB: -0.6251; LDELTOTAL: -0.1541;
# --- Epoch [018/500] ---
# Loss -> Train: 8.972189, Val: 7.245176 | LR: 1.0e-03
#   R² (Train) -> MMSE: -8.6052; CDRSB: -0.8686; LDELTOTAL: -0.0373;
#   R² (Val)   -> MMSE: -7.1485; CDRSB: -0.6017; LDELTOTAL: -0.1587;
# --- Epoch [019/500] ---
# Loss -> Train: 8.650857, Val: 7.187886 | LR: 1.0e-03
#   R² (Train) -> MMSE: -7.7799; CDRSB: -0.7772; LDELTOTAL: -0.0121;
#   R² (Val)   -> MMSE: -7.6030; CDRSB: -0.5713; LDELTOTAL: -0.0625;
# --- Epoch [020/500] ---
# Loss -> Train: 7.956802, Val: 6.347892 | LR: 1.0e-03
#   R² (Train) -> MMSE: -7.0562; CDRSB: -0.6462; LDELTOTAL: 0.0184;
#   R² (Val)   -> MMSE: -6.2492; CDRSB: -0.4416; LDELTOTAL: -0.0315;
# --- Epoch [021/500] ---
# Loss -> Train: 7.240480, Val: 6.022156 | LR: 1.0e-03
#   R² (Train) -> MMSE: -6.2854; CDRSB: -0.5749; LDELTOTAL: 0.0709;
#   R² (Val)   -> MMSE: -6.1962; CDRSB: -0.4208; LDELTOTAL: 0.0056;
# --- Epoch [022/500] ---
# Loss -> Train: 6.885411, Val: 6.210898 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.8116; CDRSB: -0.4864; LDELTOTAL: 0.0813;
#   R² (Val)   -> MMSE: -5.3606; CDRSB: -0.4782; LDELTOTAL: -0.1296;
# --- Epoch [023/500] ---
# Loss -> Train: 6.506774, Val: 6.634550 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.2990; CDRSB: -0.4750; LDELTOTAL: 0.0949;
#   R² (Val)   -> MMSE: -6.1543; CDRSB: -0.6375; LDELTOTAL: -0.0251;
# --- Epoch [024/500] ---
# Loss -> Train: 6.118471, Val: 4.810106 | LR: 1.0e-03
#   R² (Train) -> MMSE: -4.7606; CDRSB: -0.3902; LDELTOTAL: 0.1225;
#   R² (Val)   -> MMSE: -4.0077; CDRSB: -0.2831; LDELTOTAL: 0.0517;
# --- Epoch [025/500] ---
# Loss -> Train: 5.708033, Val: 4.565134 | LR: 1.0e-03
#   R² (Train) -> MMSE: -4.1642; CDRSB: -0.3449; LDELTOTAL: 0.1437;
#   R² (Val)   -> MMSE: -3.4811; CDRSB: -0.2327; LDELTOTAL: 0.0541;
# --- Epoch [026/500] ---
# Loss -> Train: 5.342743, Val: 4.336869 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.6712; CDRSB: -0.2994; LDELTOTAL: 0.1612;
#   R² (Val)   -> MMSE: -3.2951; CDRSB: -0.1705; LDELTOTAL: 0.0710;
# --- Epoch [027/500] ---
# Loss -> Train: 5.198992, Val: 4.162440 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.4144; CDRSB: -0.2651; LDELTOTAL: 0.1305;
#   R² (Val)   -> MMSE: -3.1327; CDRSB: -0.1761; LDELTOTAL: 0.0806;
# --- Epoch [028/500] ---
# Loss -> Train: 4.862822, Val: 3.958921 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.1271; CDRSB: -0.2298; LDELTOTAL: 0.1758;
#   R² (Val)   -> MMSE: -2.7687; CDRSB: -0.1434; LDELTOTAL: 0.1053;
# --- Epoch [029/500] ---
# Loss -> Train: 4.610227, Val: 3.726172 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.7371; CDRSB: -0.2000; LDELTOTAL: 0.1806;
#   R² (Val)   -> MMSE: -2.3267; CDRSB: -0.0980; LDELTOTAL: 0.0828;
# --- Epoch [030/500] ---
# Loss -> Train: 4.472434, Val: 3.635964 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.4415; CDRSB: -0.1435; LDELTOTAL: 0.1901;
#   R² (Val)   -> MMSE: -2.1903; CDRSB: -0.0684; LDELTOTAL: 0.0874;
# --- Epoch [031/500] ---
# Loss -> Train: 4.221392, Val: 3.576427 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.2027; CDRSB: -0.1341; LDELTOTAL: 0.1971;
#   R² (Val)   -> MMSE: -1.9777; CDRSB: -0.0621; LDELTOTAL: 0.0791;
# --- Epoch [032/500] ---
# Loss -> Train: 4.007583, Val: 3.305008 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.8408; CDRSB: -0.1106; LDELTOTAL: 0.1940;
#   R² (Val)   -> MMSE: -1.7855; CDRSB: -0.0544; LDELTOTAL: 0.1220;
# --- Epoch [033/500] ---
# Loss -> Train: 3.832392, Val: 3.218790 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.6160; CDRSB: -0.0817; LDELTOTAL: 0.2064;
#   R² (Val)   -> MMSE: -1.6346; CDRSB: -0.0460; LDELTOTAL: 0.1078;
# --- Epoch [034/500] ---
# Loss -> Train: 3.758652, Val: 3.091664 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.5389; CDRSB: -0.0754; LDELTOTAL: 0.2015;
#   R² (Val)   -> MMSE: -1.3697; CDRSB: -0.0190; LDELTOTAL: 0.1199;
# --- Epoch [035/500] ---
# Loss -> Train: 3.536544, Val: 2.964671 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.2129; CDRSB: -0.0611; LDELTOTAL: 0.2108;
#   R² (Val)   -> MMSE: -1.1680; CDRSB: 0.0010; LDELTOTAL: 0.1235;
# --- Epoch [036/500] ---
# Loss -> Train: 3.494681, Val: 2.944629 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.1883; CDRSB: -0.0487; LDELTOTAL: 0.2061;
#   R² (Val)   -> MMSE: -1.2047; CDRSB: -0.0074; LDELTOTAL: 0.1413;
# --- Epoch [037/500] ---
# Loss -> Train: 3.354842, Val: 2.904859 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.9965; CDRSB: -0.0127; LDELTOTAL: 0.2162;
#   R² (Val)   -> MMSE: -1.1887; CDRSB: -0.0300; LDELTOTAL: 0.1110;
# --- Epoch [038/500] ---
# Loss -> Train: 3.305649, Val: 2.763333 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.9465; CDRSB: -0.0105; LDELTOTAL: 0.2157;
#   R² (Val)   -> MMSE: -0.8132; CDRSB: 0.0298; LDELTOTAL: 0.1333;
# --- Epoch [039/500] ---
# Loss -> Train: 3.198444, Val: 2.745439 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.8032; CDRSB: -0.0267; LDELTOTAL: 0.2184;
#   R² (Val)   -> MMSE: -0.7558; CDRSB: 0.0266; LDELTOTAL: 0.1265;
# --- Epoch [040/500] ---
# Loss -> Train: 3.123297, Val: 2.642970 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.6722; CDRSB: -0.0173; LDELTOTAL: 0.2214;
#   R² (Val)   -> MMSE: -0.7048; CDRSB: 0.0189; LDELTOTAL: 0.1388;
# --- Epoch [041/500] ---
# Loss -> Train: 3.045423, Val: 2.632300 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.6056; CDRSB: 0.0032; LDELTOTAL: 0.2253;
#   R² (Val)   -> MMSE: -0.6930; CDRSB: -0.0033; LDELTOTAL: 0.1295;
# --- Epoch [042/500] ---
# Loss -> Train: 2.974168, Val: 2.641357 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.5377; CDRSB: 0.0057; LDELTOTAL: 0.2349;
#   R² (Val)   -> MMSE: -0.6252; CDRSB: 0.0283; LDELTOTAL: 0.1379;
# --- Epoch [043/500] ---
# Loss -> Train: 3.004354, Val: 2.560109 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.4687; CDRSB: 0.0069; LDELTOTAL: 0.2210;
#   R² (Val)   -> MMSE: -0.5632; CDRSB: 0.0200; LDELTOTAL: 0.1506;
# --- Epoch [044/500] ---
# Loss -> Train: 2.934590, Val: 2.535072 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3991; CDRSB: 0.0107; LDELTOTAL: 0.2270;
#   R² (Val)   -> MMSE: -0.4605; CDRSB: 0.0347; LDELTOTAL: 0.1380;
# --- Epoch [045/500] ---
# Loss -> Train: 2.847227, Val: 3.557571 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3310; CDRSB: 0.0177; LDELTOTAL: 0.2205;
#   R² (Val)   -> MMSE: -1.4492; CDRSB: -0.3146; LDELTOTAL: -0.2840;
# --- Epoch [046/500] ---
# Loss -> Train: 2.833742, Val: 2.488620 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2950; CDRSB: 0.0232; LDELTOTAL: 0.2159;
#   R² (Val)   -> MMSE: -0.3625; CDRSB: 0.0448; LDELTOTAL: 0.1427;
# --- Epoch [047/500] ---
# Loss -> Train: 2.782171, Val: 2.417287 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2389; CDRSB: 0.0285; LDELTOTAL: 0.2288;
#   R² (Val)   -> MMSE: -0.2902; CDRSB: 0.0339; LDELTOTAL: 0.1309;
# --- Epoch [048/500] ---
# Loss -> Train: 2.769408, Val: 2.417678 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2020; CDRSB: 0.0064; LDELTOTAL: 0.2135;
#   R² (Val)   -> MMSE: -0.2508; CDRSB: 0.0530; LDELTOTAL: 0.1351;
# --- Epoch [049/500] ---
# Loss -> Train: 2.724419, Val: 2.422860 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1573; CDRSB: 0.0194; LDELTOTAL: 0.2370;
#   R² (Val)   -> MMSE: -0.3555; CDRSB: 0.0118; LDELTOTAL: 0.1098;
# --- Epoch [050/500] ---
# Loss -> Train: 2.717744, Val: 2.359402 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1360; CDRSB: 0.0188; LDELTOTAL: 0.2154;
#   R² (Val)   -> MMSE: -0.1765; CDRSB: 0.0556; LDELTOTAL: 0.1537;
# --- Epoch [051/500] ---
# Loss -> Train: 2.676820, Val: 2.349713 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0979; CDRSB: 0.0305; LDELTOTAL: 0.2367;
#   R² (Val)   -> MMSE: -0.2117; CDRSB: 0.0401; LDELTOTAL: 0.1541;
# --- Epoch [052/500] ---
# Loss -> Train: 2.655351, Val: 2.371584 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0714; CDRSB: 0.0232; LDELTOTAL: 0.2325;
#   R² (Val)   -> MMSE: -0.1773; CDRSB: 0.0371; LDELTOTAL: 0.1395;
# --- Epoch [053/500] ---
# Loss -> Train: 2.652602, Val: 2.355246 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0629; CDRSB: 0.0167; LDELTOTAL: 0.2303;
#   R² (Val)   -> MMSE: -0.1075; CDRSB: 0.0543; LDELTOTAL: 0.1539;
# --- Epoch [054/500] ---
# Loss -> Train: 2.638615, Val: 2.308655 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0355; CDRSB: 0.0227; LDELTOTAL: 0.2348;
#   R² (Val)   -> MMSE: -0.1283; CDRSB: 0.0353; LDELTOTAL: 0.1481;
# --- Epoch [055/500] ---
# Loss -> Train: 2.626240, Val: 2.412983 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0130; CDRSB: 0.0382; LDELTOTAL: 0.2379;
#   R² (Val)   -> MMSE: -0.1166; CDRSB: 0.0491; LDELTOTAL: 0.1191;
# --- Epoch [056/500] ---
# Loss -> Train: 2.659298, Val: 2.325815 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0120; CDRSB: 0.0229; LDELTOTAL: 0.2274;
#   R² (Val)   -> MMSE: -0.1467; CDRSB: 0.0203; LDELTOTAL: 0.1220;
# --- Epoch [057/500] ---
# Loss -> Train: 2.624047, Val: 2.277214 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0023; CDRSB: 0.0276; LDELTOTAL: 0.2192;
#   R² (Val)   -> MMSE: -0.0627; CDRSB: 0.0535; LDELTOTAL: 0.1532;
# --- Epoch [058/500] ---
# Loss -> Train: 2.576941, Val: 2.468823 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0167; CDRSB: 0.0376; LDELTOTAL: 0.2330;
#   R² (Val)   -> MMSE: -0.3107; CDRSB: -0.0559; LDELTOTAL: 0.0537;
# --- Epoch [059/500] ---
# Loss -> Train: 2.600801, Val: 2.625209 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0209; CDRSB: 0.0392; LDELTOTAL: 0.2416;
#   R² (Val)   -> MMSE: -0.4273; CDRSB: -0.1679; LDELTOTAL: -0.0532;
# --- Epoch [060/500] ---
# Loss -> Train: 2.600897, Val: 2.271426 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0081; CDRSB: 0.0213; LDELTOTAL: 0.2186;
#   R² (Val)   -> MMSE: 0.0136; CDRSB: 0.0745; LDELTOTAL: 0.1556;
# --- Epoch [061/500] ---
# Loss -> Train: 2.603420, Val: 2.296943 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0286; CDRSB: 0.0208; LDELTOTAL: 0.2258;
#   R² (Val)   -> MMSE: -0.1085; CDRSB: 0.0285; LDELTOTAL: 0.1275;
# --- Epoch [062/500] ---
# Loss -> Train: 2.540091, Val: 2.252274 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0482; CDRSB: 0.0298; LDELTOTAL: 0.2350;
#   R² (Val)   -> MMSE: 0.0272; CDRSB: 0.0741; LDELTOTAL: 0.1510;
# --- Epoch [063/500] ---
# Loss -> Train: 2.559212, Val: 2.396977 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0538; CDRSB: 0.0253; LDELTOTAL: 0.2394;
#   R² (Val)   -> MMSE: -0.0254; CDRSB: 0.0510; LDELTOTAL: 0.0991;
# --- Epoch [064/500] ---
# Loss -> Train: 2.541082, Val: 2.928274 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0559; CDRSB: 0.0353; LDELTOTAL: 0.2344;
#   R² (Val)   -> MMSE: -0.1708; CDRSB: -0.0497; LDELTOTAL: -0.1767;
# --- Epoch [065/500] ---
# Loss -> Train: 2.507650, Val: 2.342467 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0860; CDRSB: 0.0472; LDELTOTAL: 0.2374;
#   R² (Val)   -> MMSE: 0.0251; CDRSB: 0.0588; LDELTOTAL: 0.1305;
# --- Epoch [066/500] ---
# Loss -> Train: 2.551904, Val: 2.484095 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0502; CDRSB: 0.0348; LDELTOTAL: 0.2286;
#   R² (Val)   -> MMSE: -0.0352; CDRSB: 0.0294; LDELTOTAL: 0.0994;
# --- Epoch [067/500] ---
# Loss -> Train: 2.547340, Val: 2.285524 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0665; CDRSB: 0.0309; LDELTOTAL: 0.2305;
#   R² (Val)   -> MMSE: 0.0072; CDRSB: 0.0514; LDELTOTAL: 0.1444;
# --- Epoch [068/500] ---
# Loss -> Train: 2.551775, Val: 2.272123 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0715; CDRSB: 0.0269; LDELTOTAL: 0.2191;
#   R² (Val)   -> MMSE: -0.0066; CDRSB: 0.0499; LDELTOTAL: 0.1423;
# --- Epoch [069/500] ---
# Loss -> Train: 2.561980, Val: 2.241414 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0519; CDRSB: 0.0293; LDELTOTAL: 0.2337;
#   R² (Val)   -> MMSE: -0.0171; CDRSB: 0.0423; LDELTOTAL: 0.1374;
# --- Epoch [070/500] ---
# Loss -> Train: 2.536750, Val: 2.263386 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0639; CDRSB: 0.0445; LDELTOTAL: 0.2369;
#   R² (Val)   -> MMSE: 0.0235; CDRSB: 0.0718; LDELTOTAL: 0.1419;
# --- Epoch [071/500] ---
# Loss -> Train: 2.539847, Val: 2.680585 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0769; CDRSB: 0.0257; LDELTOTAL: 0.2381;
#   R² (Val)   -> MMSE: -0.1100; CDRSB: -0.0011; LDELTOTAL: 0.0038;
# --- Epoch [072/500] ---
# Loss -> Train: 2.490958, Val: 6.586714 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0903; CDRSB: 0.0448; LDELTOTAL: 0.2429;
#   R² (Val)   -> MMSE: -1.4313; CDRSB: -2.7329; LDELTOTAL: -2.0075;
# --- Epoch [073/500] ---
# Loss -> Train: 2.567606, Val: 2.408950 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0902; CDRSB: 0.0327; LDELTOTAL: 0.2529;
#   R² (Val)   -> MMSE: -0.1684; CDRSB: -0.0478; LDELTOTAL: 0.0385;
# --- Epoch [074/500] ---
# Loss -> Train: 2.544037, Val: 2.253325 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0621; CDRSB: 0.0283; LDELTOTAL: 0.2189;
#   R² (Val)   -> MMSE: -0.0463; CDRSB: 0.0153; LDELTOTAL: 0.1109;
# --- Epoch [075/500] ---
# Loss -> Train: 2.559205, Val: 2.278535 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0702; CDRSB: 0.0283; LDELTOTAL: 0.2170;
#   R² (Val)   -> MMSE: -0.0585; CDRSB: -0.0105; LDELTOTAL: 0.1242;
# --- Epoch [076/500] ---
# Loss -> Train: 2.501043, Val: 2.188566 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0867; CDRSB: 0.0408; LDELTOTAL: 0.2534;
#   R² (Val)   -> MMSE: 0.0353; CDRSB: 0.0595; LDELTOTAL: 0.1546;
# --- Epoch [077/500] ---
# Loss -> Train: 2.523506, Val: 2.289909 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0704; CDRSB: 0.0310; LDELTOTAL: 0.2281;
#   R² (Val)   -> MMSE: 0.0128; CDRSB: 0.0668; LDELTOTAL: 0.1496;
# --- Epoch [078/500] ---
# Loss -> Train: 2.550435, Val: 2.724982 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0826; CDRSB: 0.0466; LDELTOTAL: 0.2277;
#   R² (Val)   -> MMSE: -0.0846; CDRSB: -0.0389; LDELTOTAL: -0.0404;
# --- Epoch [079/500] ---
# Loss -> Train: 2.607823, Val: 2.275274 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0101; CDRSB: 0.0066; LDELTOTAL: 0.1938;
#   R² (Val)   -> MMSE: 0.0079; CDRSB: 0.0519; LDELTOTAL: 0.1474;
# --- Epoch [080/500] ---
# Loss -> Train: 2.532884, Val: 2.303474 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0712; CDRSB: 0.0299; LDELTOTAL: 0.2138;
#   R² (Val)   -> MMSE: -0.0420; CDRSB: -0.0205; LDELTOTAL: 0.1265;
# --- Epoch [081/500] ---
# Loss -> Train: 2.519727, Val: 2.216892 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0891; CDRSB: 0.0302; LDELTOTAL: 0.2205;
#   R² (Val)   -> MMSE: 0.0265; CDRSB: 0.0524; LDELTOTAL: 0.1480;
# --- Epoch [082/500] ---
# Loss -> Train: 2.535353, Val: 2.564237 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0842; CDRSB: 0.0121; LDELTOTAL: 0.2173;
#   R² (Val)   -> MMSE: -0.0492; CDRSB: 0.0229; LDELTOTAL: 0.0778;
# --- Epoch [083/500] ---
# Loss -> Train: 2.526912, Val: 2.271816 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0783; CDRSB: 0.0424; LDELTOTAL: 0.2366;
#   R² (Val)   -> MMSE: -0.0769; CDRSB: 0.0024; LDELTOTAL: 0.1191;
# --- Epoch [084/500] ---
# Loss -> Train: 2.514361, Val: 2.524258 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1033; CDRSB: 0.0278; LDELTOTAL: 0.2429;
#   R² (Val)   -> MMSE: -0.3258; CDRSB: -0.0530; LDELTOTAL: -0.0147;
# --- Epoch [085/500] ---
# Loss -> Train: 2.517833, Val: 2.299551 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0887; CDRSB: 0.0286; LDELTOTAL: 0.2277;
#   R² (Val)   -> MMSE: 0.0166; CDRSB: 0.0543; LDELTOTAL: 0.1587;
# --- Epoch [086/500] ---
# Loss -> Train: 2.521753, Val: 2.887899 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0842; CDRSB: 0.0383; LDELTOTAL: 0.2294;
#   R² (Val)   -> MMSE: -0.6119; CDRSB: -0.1682; LDELTOTAL: -0.2480;
# --- Epoch [087/500] ---
# Loss -> Train: 2.675752, Val: 2.217977 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0753; CDRSB: 0.0282; LDELTOTAL: 0.2319;
#   R² (Val)   -> MMSE: 0.0444; CDRSB: 0.0707; LDELTOTAL: 0.1597;
# --- Epoch [088/500] ---
# Loss -> Train: 2.502876, Val: 2.218126 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0910; CDRSB: 0.0238; LDELTOTAL: 0.2264;
#   R² (Val)   -> MMSE: 0.0737; CDRSB: 0.0717; LDELTOTAL: 0.1851;
# --- Epoch [089/500] ---
# Loss -> Train: 2.539767, Val: 2.617264 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0820; CDRSB: 0.0108; LDELTOTAL: 0.2277;
#   R² (Val)   -> MMSE: -0.0641; CDRSB: 0.0291; LDELTOTAL: 0.0107;
# --- Epoch [090/500] ---
# Loss -> Train: 2.505603, Val: 2.411581 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0803; CDRSB: 0.0257; LDELTOTAL: 0.2417;
#   R² (Val)   -> MMSE: 0.0175; CDRSB: 0.0558; LDELTOTAL: 0.0590;
# --- Epoch [091/500] ---
# Loss -> Train: 2.471903, Val: 2.527652 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1024; CDRSB: 0.0344; LDELTOTAL: 0.2479;
#   R² (Val)   -> MMSE: -0.0313; CDRSB: 0.0387; LDELTOTAL: 0.0781;
# --- Epoch [092/500] ---
# Loss -> Train: 2.517184, Val: 2.288976 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0905; CDRSB: 0.0399; LDELTOTAL: 0.2455;
#   R² (Val)   -> MMSE: 0.0291; CDRSB: 0.0684; LDELTOTAL: 0.1472;
# --- Epoch [093/500] ---
# Loss -> Train: 2.483612, Val: 2.430680 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1101; CDRSB: 0.0269; LDELTOTAL: 0.2383;
#   R² (Val)   -> MMSE: -0.0364; CDRSB: 0.0335; LDELTOTAL: 0.1006;
# --- Epoch [094/500] ---
# Loss -> Train: 2.499659, Val: 2.401884 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0871; CDRSB: 0.0324; LDELTOTAL: 0.2402;
#   R² (Val)   -> MMSE: -0.1643; CDRSB: -0.0376; LDELTOTAL: -0.0122;
# --- Epoch [095/500] ---
# Loss -> Train: 2.506251, Val: 2.174134 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0968; CDRSB: 0.0367; LDELTOTAL: 0.2449;
#   R² (Val)   -> MMSE: 0.0719; CDRSB: 0.0762; LDELTOTAL: 0.1717;
# --- Epoch [096/500] ---
# Loss -> Train: 2.485465, Val: 3.565805 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0987; CDRSB: 0.0478; LDELTOTAL: 0.2416;
#   R² (Val)   -> MMSE: -0.3208; CDRSB: -0.3795; LDELTOTAL: -0.3172;
# --- Epoch [097/500] ---
# Loss -> Train: 2.515538, Val: 3.463985 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0872; CDRSB: 0.0396; LDELTOTAL: 0.2449;
#   R² (Val)   -> MMSE: -0.2562; CDRSB: -0.2536; LDELTOTAL: -0.4518;
# --- Epoch [098/500] ---
# Loss -> Train: 2.526642, Val: 2.293806 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0775; CDRSB: 0.0466; LDELTOTAL: 0.2185;
#   R² (Val)   -> MMSE: 0.0449; CDRSB: 0.0786; LDELTOTAL: 0.1644;
# --- Epoch [099/500] ---
# Loss -> Train: 2.481394, Val: 2.386022 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0883; CDRSB: 0.0320; LDELTOTAL: 0.2370;
#   R² (Val)   -> MMSE: -0.0348; CDRSB: 0.0343; LDELTOTAL: 0.0923;
# --- Epoch [100/500] ---
# Loss -> Train: 2.482699, Val: 2.570562 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0875; CDRSB: 0.0357; LDELTOTAL: 0.2531;
#   R² (Val)   -> MMSE: -0.2485; CDRSB: -0.0948; LDELTOTAL: -0.0541;
# --- Epoch [101/500] ---
# Loss -> Train: 2.553588, Val: 2.284006 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0658; CDRSB: 0.0278; LDELTOTAL: 0.2097;
#   R² (Val)   -> MMSE: 0.0115; CDRSB: 0.0636; LDELTOTAL: 0.1582;
# --- Epoch [102/500] ---
# Loss -> Train: 2.474373, Val: 4.436403 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1023; CDRSB: 0.0462; LDELTOTAL: 0.2512;
#   R² (Val)   -> MMSE: -0.4113; CDRSB: -0.4960; LDELTOTAL: -0.8430;
# --- Epoch [103/500] ---
# Loss -> Train: 2.494339, Val: 2.194160 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0955; CDRSB: 0.0348; LDELTOTAL: 0.2571;
#   R² (Val)   -> MMSE: 0.0883; CDRSB: 0.0649; LDELTOTAL: 0.1917;
# --- Epoch [104/500] ---
# Loss -> Train: 2.518162, Val: 2.399772 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0751; CDRSB: 0.0342; LDELTOTAL: 0.2340;
#   R² (Val)   -> MMSE: -0.1069; CDRSB: -0.0178; LDELTOTAL: 0.0339;
# --- Epoch [105/500] ---
# Loss -> Train: 2.494260, Val: 2.259303 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0822; CDRSB: 0.0412; LDELTOTAL: 0.2523;
#   R² (Val)   -> MMSE: 0.0019; CDRSB: 0.0357; LDELTOTAL: 0.1329;
# --- Epoch [106/500] ---
# Loss -> Train: 2.483185, Val: 2.385125 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1111; CDRSB: 0.0377; LDELTOTAL: 0.2640;
#   R² (Val)   -> MMSE: 0.0141; CDRSB: 0.0483; LDELTOTAL: 0.1319;
# --- Epoch [107/500] ---
# Loss -> Train: 2.473115, Val: 3.016109 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0863; CDRSB: 0.0376; LDELTOTAL: 0.2548;
#   R² (Val)   -> MMSE: -0.1336; CDRSB: -0.1233; LDELTOTAL: -0.2129;
# --- Epoch [108/500] ---
# Loss -> Train: 2.464739, Val: 2.291239 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0854; CDRSB: 0.0495; LDELTOTAL: 0.2685;
#   R² (Val)   -> MMSE: 0.0212; CDRSB: 0.0755; LDELTOTAL: 0.1479;
# --- Epoch [109/500] ---
# Loss -> Train: 2.503374, Val: 2.513772 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0814; CDRSB: 0.0305; LDELTOTAL: 0.2421;
#   R² (Val)   -> MMSE: 0.0051; CDRSB: -0.0030; LDELTOTAL: 0.0336;
# --- Epoch [110/500] ---
# Loss -> Train: 2.502626, Val: 3.020819 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0880; CDRSB: 0.0171; LDELTOTAL: 0.2313;
#   R² (Val)   -> MMSE: -0.1527; CDRSB: -0.1145; LDELTOTAL: -0.0800;
# --- Epoch [111/500] ---
# Loss -> Train: 2.661485, Val: 2.632709 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0794; CDRSB: 0.0389; LDELTOTAL: 0.2478;
#   R² (Val)   -> MMSE: -0.2491; CDRSB: -0.1017; LDELTOTAL: -0.1301;
# --- Epoch [112/500] ---
# Loss -> Train: 2.531149, Val: 2.237578 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0773; CDRSB: 0.0057; LDELTOTAL: 0.2344;
#   R² (Val)   -> MMSE: 0.0042; CDRSB: 0.0235; LDELTOTAL: 0.1381;
# --- Epoch [113/500] ---
# Loss -> Train: 2.499048, Val: 3.849433 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0941; CDRSB: 0.0262; LDELTOTAL: 0.2502;
#   R² (Val)   -> MMSE: -0.5079; CDRSB: -0.1312; LDELTOTAL: -0.4782;
# --- Epoch [114/500] ---
# Loss -> Train: 2.449630, Val: 2.210039 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1068; CDRSB: 0.0546; LDELTOTAL: 0.2723;
#   R² (Val)   -> MMSE: 0.1013; CDRSB: 0.0914; LDELTOTAL: 0.1574;
# --- Epoch [115/500] ---
# Loss -> Train: 2.478778, Val: 3.893476 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0956; CDRSB: 0.0290; LDELTOTAL: 0.2428;
#   R² (Val)   -> MMSE: -0.4551; CDRSB: -0.2103; LDELTOTAL: -0.4716;
# --- Epoch [116/500] ---
# Loss -> Train: 2.477026, Val: 2.651313 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1026; CDRSB: 0.0432; LDELTOTAL: 0.2521;
#   R² (Val)   -> MMSE: -0.0699; CDRSB: 0.0091; LDELTOTAL: 0.0238;
# --- Epoch [117/500] ---
# Loss -> Train: 2.440991, Val: 2.175660 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1086; CDRSB: 0.0560; LDELTOTAL: 0.2727;
#   R² (Val)   -> MMSE: 0.0826; CDRSB: 0.0813; LDELTOTAL: 0.1738;
# --- Epoch [118/500] ---
# Loss -> Train: 2.418365, Val: 2.277353 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1017; CDRSB: 0.0688; LDELTOTAL: 0.2718;
#   R² (Val)   -> MMSE: -0.0897; CDRSB: 0.0003; LDELTOTAL: 0.0722;
# --- Epoch [119/500] ---
# Loss -> Train: 2.399965, Val: 2.171032 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1156; CDRSB: 0.0613; LDELTOTAL: 0.2876;
#   R² (Val)   -> MMSE: 0.0936; CDRSB: 0.0875; LDELTOTAL: 0.1742;
# --- Epoch [120/500] ---
# Loss -> Train: 2.414028, Val: 2.144187 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1063; CDRSB: 0.0768; LDELTOTAL: 0.2785;
#   R² (Val)   -> MMSE: 0.0358; CDRSB: 0.0600; LDELTOTAL: 0.1646;
# --- Epoch [121/500] ---
# Loss -> Train: 2.398835, Val: 2.125421 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1189; CDRSB: 0.0677; LDELTOTAL: 0.2833;
#   R² (Val)   -> MMSE: 0.0644; CDRSB: 0.0764; LDELTOTAL: 0.1823;
# --- Epoch [122/500] ---
# Loss -> Train: 2.403092, Val: 2.312419 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1180; CDRSB: 0.0597; LDELTOTAL: 0.2838;
#   R² (Val)   -> MMSE: 0.0627; CDRSB: 0.0711; LDELTOTAL: 0.1337;
# --- Epoch [123/500] ---
# Loss -> Train: 2.422346, Val: 2.127816 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1126; CDRSB: 0.0635; LDELTOTAL: 0.2852;
#   R² (Val)   -> MMSE: 0.0999; CDRSB: 0.0926; LDELTOTAL: 0.1888;
# --- Epoch [124/500] ---
# Loss -> Train: 2.395936, Val: 2.177236 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1145; CDRSB: 0.0895; LDELTOTAL: 0.2863;
#   R² (Val)   -> MMSE: -0.0045; CDRSB: 0.0431; LDELTOTAL: 0.1291;
# --- Epoch [125/500] ---
# Loss -> Train: 2.358990, Val: 2.308841 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1304; CDRSB: 0.0921; LDELTOTAL: 0.3240;
#   R² (Val)   -> MMSE: 0.0628; CDRSB: 0.0719; LDELTOTAL: 0.1242;
# --- Epoch [126/500] ---
# Loss -> Train: 2.373288, Val: 2.137341 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1263; CDRSB: 0.0822; LDELTOTAL: 0.3051;
#   R² (Val)   -> MMSE: 0.1057; CDRSB: 0.0927; LDELTOTAL: 0.1855;
# --- Epoch [127/500] ---
# Loss -> Train: 2.355581, Val: 2.110040 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1284; CDRSB: 0.0990; LDELTOTAL: 0.3275;
#   R² (Val)   -> MMSE: 0.0923; CDRSB: 0.0844; LDELTOTAL: 0.1877;
# --- Epoch [128/500] ---
# Loss -> Train: 2.383268, Val: 2.136094 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1282; CDRSB: 0.0808; LDELTOTAL: 0.3071;
#   R² (Val)   -> MMSE: 0.0634; CDRSB: 0.0651; LDELTOTAL: 0.1642;
# --- Epoch [129/500] ---
# Loss -> Train: 2.401920, Val: 2.131002 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1240; CDRSB: 0.1001; LDELTOTAL: 0.3104;
#   R² (Val)   -> MMSE: 0.0761; CDRSB: 0.0835; LDELTOTAL: 0.1946;
# --- Epoch [130/500] ---
# Loss -> Train: 2.405226, Val: 2.118418 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1035; CDRSB: 0.0733; LDELTOTAL: 0.2917;
#   R² (Val)   -> MMSE: 0.0728; CDRSB: 0.0794; LDELTOTAL: 0.2046;
# --- Epoch [131/500] ---
# Loss -> Train: 2.381859, Val: 2.119409 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1078; CDRSB: 0.1004; LDELTOTAL: 0.3059;
#   R² (Val)   -> MMSE: 0.0676; CDRSB: 0.0619; LDELTOTAL: 0.1811;
# --- Epoch [132/500] ---
# Loss -> Train: 2.364644, Val: 2.113098 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1359; CDRSB: 0.0633; LDELTOTAL: 0.3080;
#   R² (Val)   -> MMSE: 0.1110; CDRSB: 0.0950; LDELTOTAL: 0.1954;
# --- Epoch [133/500] ---
# Loss -> Train: 2.347878, Val: 2.338632 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1293; CDRSB: 0.0999; LDELTOTAL: 0.3317;
#   R² (Val)   -> MMSE: -0.0932; CDRSB: -0.0591; LDELTOTAL: 0.0338;
# --- Epoch [134/500] ---
# Loss -> Train: 2.339560, Val: 2.331129 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.1402; CDRSB: 0.1014; LDELTOTAL: 0.3031;
#   R² (Val)   -> MMSE: -0.1347; CDRSB: -0.0748; LDELTOTAL: 0.0164;
# --- Epoch [135/500] ---
# ...
#   R² (Train) -> MMSE: 0.4316; CDRSB: 0.3931; LDELTOTAL: 0.4696;
#   R² (Val)   -> MMSE: -0.1631; CDRSB: -0.1096; LDELTOTAL: 0.2209;
# --- Epoch [150/500] ---
# Loss -> Train: 1.668643, Val: 2.313749 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.3835; CDRSB: 0.3084; LDELTOTAL: 0.4890;
#   R² (Val)   -> MMSE: -0.1202; CDRSB: -0.0921; LDELTOTAL: 0.2202;
# --- Epoch [151/500] ---
# Loss -> Train: 1.583657, Val: 2.333214 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4498; CDRSB: 0.4110; LDELTOTAL: 0.4559;
#   R² (Val)   -> MMSE: -0.1594; CDRSB: -0.1258; LDELTOTAL: 0.2159;
# --- Epoch [152/500] ---
# Loss -> Train: 1.511109, Val: 2.391240 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4838; CDRSB: 0.4023; LDELTOTAL: 0.5106;
#   R² (Val)   -> MMSE: -0.2334; CDRSB: -0.1969; LDELTOTAL: 0.1881;
# --- Epoch [153/500] ---
# Loss -> Train: 1.546055, Val: 2.341430 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4657; CDRSB: 0.4030; LDELTOTAL: 0.4838;
#   R² (Val)   -> MMSE: -0.1728; CDRSB: -0.1335; LDELTOTAL: 0.2120;
# --- Epoch [154/500] ---
# Loss -> Train: 1.563208, Val: 2.306176 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4324; CDRSB: 0.4010; LDELTOTAL: 0.4852;
#   R² (Val)   -> MMSE: -0.1068; CDRSB: -0.0688; LDELTOTAL: 0.2322;
# --- Epoch [155/500] ---
# Loss -> Train: 1.570490, Val: 2.322827 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4190; CDRSB: 0.4171; LDELTOTAL: 0.4894;
#   R² (Val)   -> MMSE: -0.1375; CDRSB: -0.1049; LDELTOTAL: 0.2200;
# --- Epoch [156/500] ---
# Loss -> Train: 1.552499, Val: 2.281751 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4507; CDRSB: 0.4158; LDELTOTAL: 0.4927;
#   R² (Val)   -> MMSE: -0.0720; CDRSB: -0.0453; LDELTOTAL: 0.2507;
# --- Epoch [157/500] ---
# Loss -> Train: 1.525050, Val: 2.375021 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4998; CDRSB: 0.3777; LDELTOTAL: 0.4875;
#   R² (Val)   -> MMSE: -0.1868; CDRSB: -0.1565; LDELTOTAL: 0.1809;
# --- Epoch [158/500] ---
# Loss -> Train: 1.529490, Val: 2.385422 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4510; CDRSB: 0.4262; LDELTOTAL: 0.5159;
#   R² (Val)   -> MMSE: -0.1979; CDRSB: -0.1661; LDELTOTAL: 0.1711;
# --- Epoch [159/500] ---
# Loss -> Train: 1.599901, Val: 2.382976 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4627; CDRSB: 0.3369; LDELTOTAL: 0.4777;
#   R² (Val)   -> MMSE: -0.2146; CDRSB: -0.1646; LDELTOTAL: 0.1805;
# --- Epoch [160/500] ---
# Loss -> Train: 1.542276, Val: 2.294526 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4490; CDRSB: 0.4414; LDELTOTAL: 0.4829;
#   R² (Val)   -> MMSE: -0.1044; CDRSB: -0.0687; LDELTOTAL: 0.2403;
# --- Epoch [161/500] ---
# Loss -> Train: 1.503837, Val: 2.348241 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4586; CDRSB: 0.4321; LDELTOTAL: 0.5172;
#   R² (Val)   -> MMSE: -0.1727; CDRSB: -0.1275; LDELTOTAL: 0.2015;
# --- Epoch [162/500] ---
# Loss -> Train: 1.581406, Val: 2.399111 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.3808; CDRSB: 0.4438; LDELTOTAL: 0.4890;
#   R² (Val)   -> MMSE: -0.2224; CDRSB: -0.1947; LDELTOTAL: 0.1716;
# --- Epoch [163/500] ---
# Loss -> Train: 1.630744, Val: 2.336642 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.3528; CDRSB: 0.3593; LDELTOTAL: 0.5273;
#   R² (Val)   -> MMSE: -0.1605; CDRSB: -0.1334; LDELTOTAL: 0.2084;
# --- Epoch [164/500] ---
# Loss -> Train: 1.493559, Val: 2.319274 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.4696; CDRSB: 0.4365; LDELTOTAL: 0.5182;
#   R² (Val)   -> MMSE: -0.1320; CDRSB: -0.1042; LDELTOTAL: 0.2190;
# --- Epoch [165/500] ---
# Loss -> Train: 1.525589, Val: 2.319760 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4553; CDRSB: 0.4184; LDELTOTAL: 0.4925;
#   R² (Val)   -> MMSE: -0.1363; CDRSB: -0.1027; LDELTOTAL: 0.2168;
# --- Epoch [166/500] ---
# Loss -> Train: 1.540698, Val: 2.353458 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4712; CDRSB: 0.4082; LDELTOTAL: 0.4834;
#   R² (Val)   -> MMSE: -0.1732; CDRSB: -0.1441; LDELTOTAL: 0.1960;
# --- Epoch [167/500] ---
# Loss -> Train: 1.529538, Val: 2.334011 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4851; CDRSB: 0.4130; LDELTOTAL: 0.5178;
#   R² (Val)   -> MMSE: -0.1523; CDRSB: -0.1219; LDELTOTAL: 0.2084;
# --- Epoch [168/500] ---
# Loss -> Train: 1.515821, Val: 2.334479 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4873; CDRSB: 0.4154; LDELTOTAL: 0.4686;
#   R² (Val)   -> MMSE: -0.1577; CDRSB: -0.1231; LDELTOTAL: 0.2102;
# --- Epoch [169/500] ---
# Loss -> Train: 1.545333, Val: 2.350793 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4414; CDRSB: 0.4109; LDELTOTAL: 0.4887;
#   R² (Val)   -> MMSE: -0.1754; CDRSB: -0.1432; LDELTOTAL: 0.2001;
# --- Epoch [170/500] ---
# Loss -> Train: 1.585003, Val: 2.349013 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4240; CDRSB: 0.3879; LDELTOTAL: 0.4731;
#   R² (Val)   -> MMSE: -0.1728; CDRSB: -0.1408; LDELTOTAL: 0.2004;
# --- Epoch [171/500] ---
# Loss -> Train: 1.524625, Val: 2.357715 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4836; CDRSB: 0.3982; LDELTOTAL: 0.5228;
#   R² (Val)   -> MMSE: -0.1817; CDRSB: -0.1494; LDELTOTAL: 0.1949;
# --- Epoch [172/500] ---
# Loss -> Train: 1.510116, Val: 2.356528 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4597; CDRSB: 0.3978; LDELTOTAL: 0.5338;
#   R² (Val)   -> MMSE: -0.1837; CDRSB: -0.1519; LDELTOTAL: 0.1964;
# --- Epoch [173/500] ---
# Loss -> Train: 1.516449, Val: 2.334632 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4680; CDRSB: 0.4246; LDELTOTAL: 0.5089;
#   R² (Val)   -> MMSE: -0.1584; CDRSB: -0.1219; LDELTOTAL: 0.2105;
# --- Epoch [174/500] ---
# Loss -> Train: 1.506236, Val: 2.373967 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4580; CDRSB: 0.4253; LDELTOTAL: 0.5104;
#   R² (Val)   -> MMSE: -0.2046; CDRSB: -0.1714; LDELTOTAL: 0.1872;
# --- Epoch [175/500] ---
# Loss -> Train: 1.608500, Val: 2.340653 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4632; CDRSB: 0.3538; LDELTOTAL: 0.5005;
#   R² (Val)   -> MMSE: -0.1655; CDRSB: -0.1338; LDELTOTAL: 0.2085;
# --- Epoch [176/500] ---
# Loss -> Train: 1.554659, Val: 2.368225 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4691; CDRSB: 0.4071; LDELTOTAL: 0.4887;
#   R² (Val)   -> MMSE: -0.1977; CDRSB: -0.1637; LDELTOTAL: 0.1903;
# --- Epoch [177/500] ---
# Loss -> Train: 1.539183, Val: 2.364187 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4907; CDRSB: 0.3707; LDELTOTAL: 0.5056;
#   R² (Val)   -> MMSE: -0.1918; CDRSB: -0.1590; LDELTOTAL: 0.1902;
# --- Epoch [178/500] ---
# Loss -> Train: 1.505948, Val: 2.343153 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4955; CDRSB: 0.4303; LDELTOTAL: 0.4982;
#   R² (Val)   -> MMSE: -0.1633; CDRSB: -0.1339; LDELTOTAL: 0.2031;
# --- Epoch [179/500] ---
# Loss -> Train: 1.499421, Val: 2.343715 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4864; CDRSB: 0.4103; LDELTOTAL: 0.4991;
#   R² (Val)   -> MMSE: -0.1634; CDRSB: -0.1325; LDELTOTAL: 0.1989;
# --- Epoch [180/500] ---
# Loss -> Train: 1.588959, Val: 2.348958 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4619; CDRSB: 0.3903; LDELTOTAL: 0.4610;
#   R² (Val)   -> MMSE: -0.1679; CDRSB: -0.1379; LDELTOTAL: 0.1970;
# --- Epoch [181/500] ---
# Loss -> Train: 1.549317, Val: 2.361330 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4470; CDRSB: 0.3956; LDELTOTAL: 0.4981;
#   R² (Val)   -> MMSE: -0.1831; CDRSB: -0.1515; LDELTOTAL: 0.1893;
# --- Epoch [182/500] ---
# Loss -> Train: 1.561664, Val: 2.310891 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4698; CDRSB: 0.4058; LDELTOTAL: 0.5050;
#   R² (Val)   -> MMSE: -0.1212; CDRSB: -0.0909; LDELTOTAL: 0.2268;
# --- Epoch [183/500] ---
# Loss -> Train: 1.653970, Val: 2.339161 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.3807; CDRSB: 0.3495; LDELTOTAL: 0.4793;
#   R² (Val)   -> MMSE: -0.1592; CDRSB: -0.1268; LDELTOTAL: 0.2070;
# --- Epoch [184/500] ---
# Loss -> Train: 1.556289, Val: 2.322844 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4724; CDRSB: 0.4114; LDELTOTAL: 0.4891;
#   R² (Val)   -> MMSE: -0.1387; CDRSB: -0.1054; LDELTOTAL: 0.2164;
# --- Epoch [185/500] ---
# Loss -> Train: 1.524209, Val: 2.377038 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.4453; CDRSB: 0.4435; LDELTOTAL: 0.5080;
#   R² (Val)   -> MMSE: -0.2084; CDRSB: -0.1770; LDELTOTAL: 0.1832;
# --- Epoch [186/500] ---
# Loss -> Train: 1.495675, Val: 2.339427 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4692; CDRSB: 0.4187; LDELTOTAL: 0.5159;
#   R² (Val)   -> MMSE: -0.1626; CDRSB: -0.1285; LDELTOTAL: 0.2068;
# --- Epoch [187/500] ---
# Loss -> Train: 1.480773, Val: 2.367429 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4971; CDRSB: 0.4229; LDELTOTAL: 0.5129;
#   R² (Val)   -> MMSE: -0.1972; CDRSB: -0.1636; LDELTOTAL: 0.1889;
# --- Epoch [188/500] ---
# Loss -> Train: 1.495446, Val: 2.394421 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4556; CDRSB: 0.4620; LDELTOTAL: 0.4981;
#   R² (Val)   -> MMSE: -0.2264; CDRSB: -0.1964; LDELTOTAL: 0.1707;
# --- Epoch [189/500] ---
# Loss -> Train: 1.499933, Val: 2.325144 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.5168; CDRSB: 0.4136; LDELTOTAL: 0.5073;
#   R² (Val)   -> MMSE: -0.1418; CDRSB: -0.1128; LDELTOTAL: 0.2144;
# --- Epoch [190/500] ---
# Loss -> Train: 1.512949, Val: 2.370936 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4694; CDRSB: 0.4095; LDELTOTAL: 0.5195;
#   R² (Val)   -> MMSE: -0.2000; CDRSB: -0.1667; LDELTOTAL: 0.1862;
# --- Epoch [191/500] ---
# Loss -> Train: 1.535650, Val: 2.313948 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4492; CDRSB: 0.4069; LDELTOTAL: 0.5126;
#   R² (Val)   -> MMSE: -0.1265; CDRSB: -0.0992; LDELTOTAL: 0.2223;
# --- Epoch [192/500] ---
# Loss -> Train: 1.635077, Val: 2.390326 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.3877; CDRSB: 0.3939; LDELTOTAL: 0.4719;
#   R² (Val)   -> MMSE: -0.2214; CDRSB: -0.1884; LDELTOTAL: 0.1735;
# --- Epoch [193/500] ---
# Loss -> Train: 1.471270, Val: 2.353570 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4789; CDRSB: 0.4255; LDELTOTAL: 0.5350;
#   R² (Val)   -> MMSE: -0.1808; CDRSB: -0.1464; LDELTOTAL: 0.1978;
# --- Epoch [194/500] ---
# Loss -> Train: 1.553934, Val: 2.348619 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4987; CDRSB: 0.3223; LDELTOTAL: 0.5161;
#   R² (Val)   -> MMSE: -0.1765; CDRSB: -0.1447; LDELTOTAL: 0.2006;
# --- Epoch [195/500] ---
# Loss -> Train: 1.551272, Val: 2.337637 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4614; CDRSB: 0.3699; LDELTOTAL: 0.5285;
#   R² (Val)   -> MMSE: -0.1634; CDRSB: -0.1275; LDELTOTAL: 0.2090;
# --- Epoch [196/500] ---
# Loss -> Train: 1.501120, Val: 2.343970 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4743; CDRSB: 0.4265; LDELTOTAL: 0.4999;
#   R² (Val)   -> MMSE: -0.1678; CDRSB: -0.1366; LDELTOTAL: 0.2042;
# --- Epoch [197/500] ---
# Loss -> Train: 1.532645, Val: 2.353198 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4422; CDRSB: 0.4362; LDELTOTAL: 0.5029;
#   R² (Val)   -> MMSE: -0.1798; CDRSB: -0.1480; LDELTOTAL: 0.1968;
# --- Epoch [198/500] ---
# Loss -> Train: 1.477603, Val: 2.382091 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.5100; CDRSB: 0.4087; LDELTOTAL: 0.5002;
#   R² (Val)   -> MMSE: -0.2153; CDRSB: -0.1810; LDELTOTAL: 0.1798;
# --- Epoch [199/500] ---
# Loss -> Train: 1.666698, Val: 2.366423 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.3784; CDRSB: 0.3428; LDELTOTAL: 0.4897;
#   R² (Val)   -> MMSE: -0.1950; CDRSB: -0.1625; LDELTOTAL: 0.1880;
# --- Epoch [200/500] ---
# Loss -> Train: 1.502190, Val: 2.367224 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4755; CDRSB: 0.4539; LDELTOTAL: 0.5114;
#   R² (Val)   -> MMSE: -0.1965; CDRSB: -0.1637; LDELTOTAL: 0.1868;
# --- Epoch [201/500] ---
# Loss -> Train: 1.521849, Val: 2.352457 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4421; CDRSB: 0.4355; LDELTOTAL: 0.5270;
#   R² (Val)   -> MMSE: -0.1784; CDRSB: -0.1454; LDELTOTAL: 0.1993;
# --- Epoch [202/500] ---
# Loss -> Train: 1.522395, Val: 2.341877 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4722; CDRSB: 0.4318; LDELTOTAL: 0.4945;
#   R² (Val)   -> MMSE: -0.1648; CDRSB: -0.1334; LDELTOTAL: 0.2047;
# --- Epoch [203/500] ---
# Loss -> Train: 1.581324, Val: 2.349483 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4460; CDRSB: 0.3826; LDELTOTAL: 0.4559;
#   R² (Val)   -> MMSE: -0.1745; CDRSB: -0.1415; LDELTOTAL: 0.2002;
# --- Epoch [204/500] ---
# Loss -> Train: 1.556748, Val: 2.336652 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4543; CDRSB: 0.4194; LDELTOTAL: 0.4670;
#   R² (Val)   -> MMSE: -0.1591; CDRSB: -0.1276; LDELTOTAL: 0.2078;
# --- Epoch [205/500] ---
# Loss -> Train: 1.556853, Val: 2.363916 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4644; CDRSB: 0.3858; LDELTOTAL: 0.5211;
#   R² (Val)   -> MMSE: -0.1919; CDRSB: -0.1615; LDELTOTAL: 0.1893;
# --- Epoch [206/500] ---
# Loss -> Train: 1.461773, Val: 2.319724 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.4940; CDRSB: 0.4247; LDELTOTAL: 0.5310;
#   R² (Val)   -> MMSE: -0.1392; CDRSB: -0.1064; LDELTOTAL: 0.2205;
# --- Epoch [207/500] ---
# Loss -> Train: 1.488596, Val: 2.351020 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4877; CDRSB: 0.4302; LDELTOTAL: 0.5243;
#   R² (Val)   -> MMSE: -0.1772; CDRSB: -0.1412; LDELTOTAL: 0.1994;
# --- Epoch [208/500] ---
# Loss -> Train: 1.546783, Val: 2.348243 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4505; CDRSB: 0.4030; LDELTOTAL: 0.5153;
#   R² (Val)   -> MMSE: -0.1739; CDRSB: -0.1413; LDELTOTAL: 0.1992;
# --- Epoch [209/500] ---
# Loss -> Train: 1.538835, Val: 2.371006 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4881; CDRSB: 0.3967; LDELTOTAL: 0.4812;
#   R² (Val)   -> MMSE: -0.2004; CDRSB: -0.1678; LDELTOTAL: 0.1871;
# --- Epoch [210/500] ---
# Loss -> Train: 1.536744, Val: 2.365662 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4574; CDRSB: 0.4098; LDELTOTAL: 0.5173;
#   R² (Val)   -> MMSE: -0.1950; CDRSB: -0.1614; LDELTOTAL: 0.1902;
# --- Epoch [211/500] ---
# Loss -> Train: 1.515750, Val: 2.348730 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4982; CDRSB: 0.3806; LDELTOTAL: 0.5145;
#   R² (Val)   -> MMSE: -0.1746; CDRSB: -0.1421; LDELTOTAL: 0.1994;
# --- Epoch [212/500] ---
# Loss -> Train: 1.580664, Val: 2.338155 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4025; CDRSB: 0.4056; LDELTOTAL: 0.5088;
#   R² (Val)   -> MMSE: -0.1624; CDRSB: -0.1276; LDELTOTAL: 0.2076;
# --- Epoch [213/500] ---
# Loss -> Train: 1.539952, Val: 2.350823 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4898; CDRSB: 0.3986; LDELTOTAL: 0.4698;
#   R² (Val)   -> MMSE: -0.1773; CDRSB: -0.1438; LDELTOTAL: 0.1982;
# --- Epoch [214/500] ---
# Loss -> Train: 1.614878, Val: 2.343956 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.3676; CDRSB: 0.4223; LDELTOTAL: 0.5255;
#   R² (Val)   -> MMSE: -0.1680; CDRSB: -0.1365; LDELTOTAL: 0.2021;
# --- Epoch [215/500] ---
# Loss -> Train: 1.558396, Val: 2.353096 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4664; CDRSB: 0.3888; LDELTOTAL: 0.4733;
#   R² (Val)   -> MMSE: -0.1801; CDRSB: -0.1485; LDELTOTAL: 0.1982;
# --- Epoch [216/500] ---
# Loss -> Train: 1.479453, Val: 2.339923 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.5038; CDRSB: 0.4299; LDELTOTAL: 0.5502;
#   R² (Val)   -> MMSE: -0.1659; CDRSB: -0.1318; LDELTOTAL: 0.2071;
# --- Epoch [217/500] ---
# Loss -> Train: 1.527647, Val: 2.353538 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4733; CDRSB: 0.4296; LDELTOTAL: 0.4739;
#   R² (Val)   -> MMSE: -0.1814; CDRSB: -0.1490; LDELTOTAL: 0.1964;
# --- Epoch [218/500] ---
# Loss -> Train: 1.618069, Val: 2.376122 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4681; CDRSB: 0.3056; LDELTOTAL: 0.4815;
#   R² (Val)   -> MMSE: -0.2064; CDRSB: -0.1750; LDELTOTAL: 0.1837;
# --- Epoch [219/500] ---
# Loss -> Train: 1.566781, Val: 2.352828 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4516; CDRSB: 0.4088; LDELTOTAL: 0.4646;
#   R² (Val)   -> MMSE: -0.1780; CDRSB: -0.1450; LDELTOTAL: 0.1975;
# --- Epoch [220/500] ---
# Loss -> Train: 1.562047, Val: 2.325619 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4882; CDRSB: 0.3921; LDELTOTAL: 0.4882;
#   R² (Val)   -> MMSE: -0.1465; CDRSB: -0.1131; LDELTOTAL: 0.2149;
# --- Epoch [221/500] ---
# Loss -> Train: 1.519583, Val: 2.341904 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4739; CDRSB: 0.4173; LDELTOTAL: 0.5075;
#   R² (Val)   -> MMSE: -0.1676; CDRSB: -0.1346; LDELTOTAL: 0.2058;
# --- Epoch [222/500] ---
# Loss -> Train: 1.521202, Val: 2.357435 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.4603; CDRSB: 0.4458; LDELTOTAL: 0.4852;
#   R² (Val)   -> MMSE: -0.1844; CDRSB: -0.1534; LDELTOTAL: 0.1953;
#
# 提前停止于周期 222.
#
# 折叠 5 完成。最佳验证损失: 2.209556
# 对应的验证集R²: {'MMSE': 0.10910248756408691, 'CDRSB': 0.03334897756576538, 'LDELTOTAL': 0.2853769063949585}
# 对应的训练集R²: {'MMSE': 0.22196418046951294, 'CDRSB': 0.15716850757598877, 'LDELTOTAL': 0.32347404956817627}
#
# ==============================
# --- 交叉验证结果总结 ---
# ==============================
# 平均最佳验证损失: 2.403787 ± 0.394117
#   - MMSE 平均 Val R²:   0.1153 ± 0.0177
#   - MMSE 平均 Train R²: 0.1981 ± 0.0723
#   - CDRSB 平均 Val R²:   0.0674 ± 0.0452
#   - CDRSB 平均 Train R²: 0.1616 ± 0.0768
#   - LDELTOTAL 平均 Val R²:   0.2813 ± 0.0325
#   - LDELTOTAL 平均 Train R²: 0.3373 ± 0.0598
