# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import copy
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# image and longitudinal outcome path
OUTCOME_CSV_PATH = '/content/drive/MyDrive/patients_742_selected.csv'
IMAGING_PKL_PATH = "/content/drive/MyDrive/x_with_coord.pkl"

PATIENT_ID_COL = 'id'
TIME_COL = 'Years_bl'
OUTCOME_COLS = ['MMSE', 'CDRSB', 'LDELTOTAL']
STATIC_TABULAR_COLS = ['AGE', 'GENDER', 'PTEDUCAT']

N_SPLITS = 5
RANDOM_STATE = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device: {DEVICE}")
print("-" * 30 + "\n")


print("--- step 2: image loading and pre-processing ---")
imaging_df = pd.read_pickle(IMAGING_PKL_PATH)

# Infer image dimensions from coordinates
coord_cols = ['x', 'y', 'z']
x_coords_all, y_coords_all, z_coords_all = imaging_df['x'].values, imaging_df['y'].values, imaging_df['z'].values
x_unique_sorted, y_unique_sorted, z_unique_sorted = np.sort(np.unique(x_coords_all)), np.sort(np.unique(y_coords_all)), np.sort(np.unique(z_coords_all))
dim_x, dim_y, dim_z = len(x_unique_sorted), len(y_unique_sorted), len(z_unique_sorted)
print(f"3d image dimension: (X: {dim_x}, Y: {dim_y}, Z: {dim_z})")

# Create coordinate-to-index maps
x_map, y_map, z_map = {val: i for i, val in enumerate(x_unique_sorted)}, {val: i for i, val in enumerate(y_unique_sorted)}, {val: i for i, val in enumerate(z_unique_sorted)}
x_indices, y_indices, z_indices = np.array([x_map[val] for val in x_coords_all]), np.array([y_map[val] for val in y_coords_all]), np.array([z_map[val] for val in z_coords_all])

# Reshape voxel data into 3D images
patient_id_cols = imaging_df.columns[3:]
num_patients = len(patient_id_cols)
all_patient_images = np.zeros((num_patients, dim_x, dim_y, dim_z), dtype=np.float32)

for i, patient_col_name in enumerate(patient_id_cols):
    all_patient_images[i, x_indices, y_indices, z_indices] = imaging_df[patient_col_name].values

# Add channel dimension for PyTorch -> (N, 1, X, Y, Z)
X_data_images = np.expand_dims(all_patient_images, axis=1)
print(f"image shape: {X_data_images.shape}")

# Create a mapping DataFrame from the image data
imaging_ids_df = pd.DataFrame({
    'imaging_patient_id': patient_id_cols,
    PATIENT_ID_COL: np.arange(1, num_patients + 1), # patient ID starting from1
    'image_idx': np.arange(num_patients)
})
print("-" * 30 + "\n")
# Out:
# device: cuda
# ------------------------------
#
# --- step 2: image loading and pre-processing ---
# 3d image dimension: (X: 152, Y: 182, Z: 148)
# image shape: (742, 1, 152, 182, 148)
# ------------------------------

# %%
print("--- step 3: merge longitudinal and image ---")
outcome_df = pd.read_csv(OUTCOME_CSV_PATH)
merged_df = pd.merge(imaging_ids_df, outcome_df, on=PATIENT_ID_COL, how='inner')
print(f" {len(merged_df)} data in total")
unique_patient_ids = merged_df[PATIENT_ID_COL].unique()
print(f"{len(unique_patient_ids)} patients in total")
print("-" * 30 + "\n")
# Out:
# --- step 3: merge longitudinal and image ---
#  3826 data in total
# 742 patients in total
# ------------------------------

# %%
merged_df
# Out:
#                  imaging_patient_id   id  image_idx  MMSE  CDRSB  LDELTOTAL  \
# 0       002_S_0729_2006-07-17_5.csv    1          0  27.0    0.5        1.0
# 1       002_S_0729_2006-07-17_5.csv    1          0  27.0    0.5        NaN
# 2       002_S_0782_2006-08-14_3.csv    2          1  29.0    0.5        8.0
# 3       002_S_0782_2006-08-14_3.csv    2          1  30.0    1.0        NaN
# 4       002_S_0782_2006-08-14_3.csv    2          1  28.0    1.0        6.0
# ...                             ...  ...        ...   ...    ...        ...
# 3821  941_S_6052_2017-07-20_825.csv  740        739  27.0    2.5        7.0
# 3822  941_S_6068_2017-08-21_831.csv  741        740  27.0    3.0        1.0
# 3823  941_S_6068_2017-08-21_831.csv  741        740  25.0    4.0        0.0
# 3824  941_S_6068_2017-08-21_831.csv  741        740  26.0    3.5        1.0
# 3825  941_S_6345_2018-05-10_839.csv  742        741  28.0    2.0        8.0
#
#       Years_bl   AGE  GENDER  PTEDUCAT  APOE4
# 0     0.000000  65.1       1        16      1
# 1     0.558522  65.1       1        16      1
# 2     0.000000  81.6       0        16      0
# 3     0.594114  81.6       0        16      0
# 4     1.078710  81.6       0        16      0
# ...        ...   ...     ...       ...    ...
# 3821  0.928131  88.1       1        16      1
# 3822  0.000000  75.7       0        12      1
# 3823  0.955510  75.7       0        12      1
# 3824  1.968510  75.7       0        12      1
# 3825  0.000000  79.3       0        12      1
#
# [3826 rows x 11 columns]

# %%
class LongitudinalPatientDataset(Dataset):
    def __init__(self, df, patient_ids, all_images, tabular_cols, outcome_cols, scalers=None):
        self.df = df
        self.patient_ids = patient_ids
        self.all_images = all_images
        self.tabular_cols = tabular_cols
        self.outcome_cols = outcome_cols
        self.scalers = scalers

    def __len__(self):
        return len(self.patient_ids)

    def __getitem__(self, idx):
        patient_id = self.patient_ids[idx]
        patient_df = self.df[self.df[PATIENT_ID_COL] == patient_id].copy()

        # image loading
        image_idx = patient_df['image_idx'].iloc[0]
        image_tensor = torch.from_numpy(self.all_images[image_idx].astype(np.float32))
        min_val, max_val = torch.min(image_tensor), torch.max(image_tensor)
        image_tensor = (image_tensor - min_val) / (max_val - min_val) if (max_val - min_val) > 1e-6 else torch.zeros_like(image_tensor)

        # linear covariates
        tabular_vals_1d = patient_df[self.tabular_cols].iloc[0].values
        tabular_vals_2d = tabular_vals_1d.reshape(1, -1)

        if self.scalers and 'tabular' in self.scalers:
            tabular_vals_2d = self.scalers['tabular'].transform(tabular_vals_2d)

        tabular_tensor = torch.tensor(tabular_vals_2d.astype(np.float32)).squeeze(0)

        # longitudinal_data
        longitudinal_data = {}
        patient_outcome_df = patient_df[[TIME_COL] + self.outcome_cols]
        for outcome in self.outcome_cols:
            times = torch.tensor(patient_outcome_df[TIME_COL].values, dtype=torch.float32)
            values = patient_outcome_df[[outcome]].values
            if self.scalers and 'outcomes' in self.scalers and outcome in self.scalers['outcomes']:
                values = self.scalers['outcomes'][outcome].transform(values)
            values = torch.tensor(values.flatten(), dtype=torch.float32)
            longitudinal_data[outcome] = (times, values)

        return {'image': image_tensor, 'tabular': tabular_tensor, 'longitudinal': longitudinal_data}



class MultiOutcomeCNN(nn.Module):
    def __init__(self, num_tabular_features, num_outcomes=3):
        super(MultiOutcomeCNN, self).__init__()
        output_dim = num_outcomes * 2

        # cnn
        self.encoder = nn.Sequential(
            nn.Conv3d(1, 32, 3, 1, 1), nn.BatchNorm3d(32), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(32, 64, 3, 1, 1), nn.BatchNorm3d(64), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(64, 128, 3, 1, 1), nn.BatchNorm3d(128), nn.ReLU(True), nn.MaxPool3d(2, 2),
            nn.Conv3d(128, 256, 3, 1, 1), nn.BatchNorm3d(256), nn.ReLU(True), nn.MaxPool3d(2, 2)
        )
        self.pooling = nn.AdaptiveAvgPool3d((1, 1, 1))
        self.flatten = nn.Flatten()

        # fc
        self.image_processor = nn.Sequential(
            nn.Linear(256, 64), nn.ReLU(True), nn.Dropout(p=0.3),
            nn.Linear(64, output_dim) # output dim 6
        )

        self.tabular_processor = nn.Linear(num_tabular_features, output_dim, bias=True)

        self.apply(self._initialize_weights)

    def _initialize_weights(self, m):
        if isinstance(m, (nn.Conv3d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm3d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

    def forward(self, x_img, x_tab):
        img_features = self.flatten(self.pooling(self.encoder(x_img)))
        params_from_image = self.image_processor(img_features)
        params_from_tabular = self.tabular_processor(x_tab)
        # add up linear and non-linear
        final_params = params_from_image + params_from_tabular
        return final_params


class LongitudinalLossUnsimplified(nn.Module):
    def __init__(self, outcome_cols):
        super().__init__()
        self.outcome_cols = outcome_cols
        self.k_dim = 2  # each outcome has 2 output

    def forward(self, f_pred_batch, y_long_batch):
        batch_loss = 0.0
        for i in range(len(y_long_batch)):
            f_pred_patient = f_pred_batch[i]
            patient_data = y_long_batch[i]['longitudinal']
            patient_loss_sum = 0.0

            for j, outcome_name in enumerate(self.outcome_cols):
                f_j = f_pred_patient[j * self.k_dim : (j + 1) * self.k_dim]
                a_j, b_j = f_j[0], f_j[1]

                times, values = patient_data[outcome_name]
                times, values = times.to(DEVICE), values.to(DEVICE)


                # 1. how many k for each ij(mij)
                num_valid_obs = (~torch.isnan(values)).sum().item()

                if num_valid_obs == 0:
                    continue

                w_ij = 1.0 / num_valid_obs


                sum_of_squared_errors = 0.0

                for k in range(len(times)):
                    y_ijk = values[k]

                    if torch.isnan(y_ijk):
                        continue

                    T_ijk = times[k]
                    predicted_value = a_j + b_j * T_ijk
                    squared_error = (y_ijk - predicted_value)**2
                    sum_of_squared_errors += squared_error

                patient_loss_sum += w_ij * sum_of_squared_errors

            batch_loss += patient_loss_sum

        return batch_loss / len(y_long_batch)

# %%
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
fold_results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(unique_patient_ids)):
    print(f"\n========== fold {fold+1}/{N_SPLITS} ==========")

    # 1. split based on subjecy
    train_ids = unique_patient_ids[train_idx]
    val_ids = unique_patient_ids[val_idx]
    # train_df 和 val_df now unscaled
    train_df = merged_df[merged_df[PATIENT_ID_COL].isin(train_ids)].copy()
    val_df = merged_df[merged_df[PATIENT_ID_COL].isin(val_ids)].copy()

    # linear covariate scaler
    tabular_scaler = StandardScaler()
    tabular_scaler.fit(train_df[STATIC_TABULAR_COLS]) # 只fit

    # y scalers
    outcome_scalers = {}
    for col in OUTCOME_COLS:
        scaler = StandardScaler()
        scaler.fit(train_df[[col]].dropna())
        outcome_scalers[col] = scaler

    # 3.create Dataset and DataLoader
    all_scalers = {'tabular': tabular_scaler, 'outcomes': outcome_scalers}
    train_dataset = LongitudinalPatientDataset(train_df, train_ids, X_data_images, STATIC_TABULAR_COLS, OUTCOME_COLS, all_scalers)
    val_dataset = LongitudinalPatientDataset(val_df, val_ids, X_data_images, STATIC_TABULAR_COLS, OUTCOME_COLS, all_scalers)

    def collate_fn(batch):
        images = torch.stack([item['image'] for item in batch])
        tabulars = torch.stack([item['tabular'] for item in batch])
        longitudinals = [item for item in batch]
        return {'image': images, 'tabular': tabulars, 'longitudinal': longitudinals}

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn, num_workers=2, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, collate_fn=collate_fn, num_workers=2, pin_memory=True)

    """model = MultiOutcomeCNN(num_tabular_features=len(STATIC_TABULAR_COLS), num_outcomes=len(OUTCOME_COLS)).to(DEVICE)
    PATH_TO_WEIGHTS = "best_model.pth" # <--- CHANGE THIS TO YOUR FILE PATH
    model.load_state_dict(torch.load(PATH_TO_WEIGHTS, map_location=DEVICE))
    # 4. Set up the criterion as before
    criterion = LongitudinalLossUnsimplified(outcome_cols=OUTCOME_COLS)
    optimizer = optim.AdamW(model.parameters(), lr=5e-6, weight_decay=1e-5)"""


    model = MultiOutcomeCNN(num_tabular_features=len(STATIC_TABULAR_COLS), num_outcomes=len(OUTCOME_COLS)).to(DEVICE)
    criterion = LongitudinalLossUnsimplified(outcome_cols=OUTCOME_COLS)
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    #optimizer = optim.Adam(model.parameters(), lr=1e-5, weight_decay=1e-4)

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=10)

    # 5.training and validation
    best_val_loss = float('inf')
    best_val_r2 = {outcome: -float('inf') for outcome in OUTCOME_COLS}
    best_train_r2 = {outcome: -float('inf') for outcome in OUTCOME_COLS}
    epochs_no_improve = 0
    num_epochs = 500
    early_stopping_patience = 50

    for epoch in range(num_epochs):
        print(f"--- Epoch [{epoch+1:03d}/{num_epochs}] ---")
        model.train()
        train_loss_sum = 0
        train_r2_data = {outcome: {'true': [], 'pred_params': [], 'times': []} for outcome in OUTCOME_COLS}

        for batch in train_loader:
            images, tabulars, longitudinals = batch['image'].to(DEVICE), batch['tabular'].to(DEVICE), batch['longitudinal']
            optimizer.zero_grad()
            f_pred = model(images, tabulars)
            loss = criterion(f_pred, longitudinals)
            loss.backward()
            optimizer.step()
            train_loss_sum += loss.item()

            for i in range(len(longitudinals)):
                f_pred_patient = f_pred[i].detach()
                for j, outcome in enumerate(OUTCOME_COLS):
                    times, values = longitudinals[i]['longitudinal'][outcome]
                    mask = ~torch.isnan(values)
                    if mask.sum() > 0:
                        train_r2_data[outcome]['true'].extend(values[mask].cpu().numpy())
                        train_r2_data[outcome]['times'].extend(times[mask].cpu().numpy())
                        params_j = f_pred_patient[j*2:(j+1)*2]
                        train_r2_data[outcome]['pred_params'].extend([params_j.cpu()] * mask.sum())

        model.eval()
        val_loss_sum = 0
        val_r2_data = {outcome: {'true': [], 'pred_params': [], 'times': []} for outcome in OUTCOME_COLS}
        with torch.no_grad():
            for batch in val_loader:
                images, tabulars, longitudinals = batch['image'].to(DEVICE), batch['tabular'].to(DEVICE), batch['longitudinal']
                f_pred = model(images, tabulars)
                loss = criterion(f_pred, longitudinals)
                val_loss_sum += loss.item()
                for i in range(len(longitudinals)):
                    f_pred_patient = f_pred[i]
                    for j, outcome in enumerate(OUTCOME_COLS):
                        times, values = longitudinals[i]['longitudinal'][outcome]
                        mask = ~torch.isnan(values)
                        if mask.sum() > 0:
                            val_r2_data[outcome]['true'].extend(values[mask].cpu().numpy())
                            val_r2_data[outcome]['times'].extend(times[mask].cpu().numpy())
                            params_j = f_pred_patient[j*2:(j+1)*2]
                            val_r2_data[outcome]['pred_params'].extend([params_j.cpu()] * mask.sum())

        avg_train_loss = train_loss_sum / len(train_loader)
        avg_val_loss = val_loss_sum / len(val_loader)
        current_lr = optimizer.param_groups[0]['lr']
        print(f"Loss -> Train: {avg_train_loss:.6f}, Val: {avg_val_loss:.6f} | LR: {current_lr:.1e}")

        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names")

            current_train_r2 = {}
            print("  R² (Train) -> ", end="")
            for outcome, data in train_r2_data.items():
                if len(data['true']) > 1:
                    y_pred = [p[0] + p[1] * t for p, t in zip(data['pred_params'], data['times'])]
                    y_true_unscaled = outcome_scalers[outcome].inverse_transform(np.array(data['true']).reshape(-1, 1))
                    y_pred_unscaled = outcome_scalers[outcome].inverse_transform(np.array(y_pred).reshape(-1, 1))
                    r2 = r2_score(y_true_unscaled, y_pred_unscaled)
                    current_train_r2[outcome] = r2
                    print(f"{outcome}: {r2:.4f}; ", end="")
            print()

            current_val_r2 = {}
            print("  R² (Val)   -> ", end="")
            for outcome, data in val_r2_data.items():
                if len(data['true']) > 1:
                    y_pred = [p[0] + p[1] * t for p, t in zip(data['pred_params'], data['times'])]
                    y_true_unscaled = outcome_scalers[outcome].inverse_transform(np.array(data['true']).reshape(-1, 1))
                    y_pred_unscaled = outcome_scalers[outcome].inverse_transform(np.array(y_pred).reshape(-1, 1))
                    r2 = r2_score(y_true_unscaled, y_pred_unscaled)
                    current_val_r2[outcome] = r2
                    print(f"{outcome}: {r2:.4f}; ", end="")
            print()

        scheduler.step(avg_val_loss)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_val_r2 = current_val_r2
            best_train_r2 = current_train_r2
            epochs_no_improve = 0
            torch.save(model.state_dict(), f"best_model_fold_{fold+1}.pth")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= early_stopping_patience:
                print(f"\n提前停止于周期 {epoch+1}.")
                break

    fold_results.append({'loss': best_val_loss, 'val_r2': best_val_r2, 'train_r2': best_train_r2})
    print(f"\n折叠 {fold+1} 完成。最佳验证损失: {best_val_loss:.6f}")
    print(f"对应的验证集R²: {best_val_r2}")
    print(f"对应的训练集R²: {best_train_r2}")

print("\n" + "="*30)
print("--- 交叉验证结果总结 ---")
print("="*30)
avg_loss = np.mean([res['loss'] for res in fold_results])
std_loss = np.std([res['loss'] for res in fold_results])
print(f"平均最佳验证损失: {avg_loss:.6f} ± {std_loss:.6f}")

for outcome in OUTCOME_COLS:
    val_r2_scores = [res['val_r2'].get(outcome, np.nan) for res in fold_results]
    train_r2_scores = [res['train_r2'].get(outcome, np.nan) for res in fold_results]
    print(f"  - {outcome} 平均 Val R²:   {np.nanmean(val_r2_scores):.4f} ± {np.nanstd(val_r2_scores):.4f}")
    print(f"  - {outcome} 平均 Train R²: {np.nanmean(train_r2_scores):.4f} ± {np.nanstd(train_r2_scores):.4f}")
# Out:
# --- 步骤 7: 开始5折交叉验证 ---
#
# ========== 折叠 1/5 ==========
# --- Epoch [001/500] ---
# Loss -> Train: 40.939997, Val: 28.477025 | LR: 1.0e-03
#   R² (Train) -> MMSE: -25.1679; CDRSB: -26.1501; LDELTOTAL: -18.3374;
#   R² (Val)   -> MMSE: -17.5300; CDRSB: -18.9397; LDELTOTAL: -9.1191;
# --- Epoch [002/500] ---
# Loss -> Train: 34.405034, Val: 24.966675 | LR: 1.0e-03
#   R² (Train) -> MMSE: -19.4016; CDRSB: -21.6765; LDELTOTAL: -14.1911;
#   R² (Val)   -> MMSE: -17.8054; CDRSB: -14.8689; LDELTOTAL: -7.0951;
# --- Epoch [003/500] ---
# Loss -> Train: 27.889563, Val: 21.935424 | LR: 1.0e-03
#   R² (Train) -> MMSE: -17.2584; CDRSB: -17.9412; LDELTOTAL: -11.1180;
#   R² (Val)   -> MMSE: -14.2346; CDRSB: -13.9220; LDELTOTAL: -6.6408;
# --- Epoch [004/500] ---
# Loss -> Train: 24.820431, Val: 20.000294 | LR: 1.0e-03
#   R² (Train) -> MMSE: -14.5461; CDRSB: -15.3791; LDELTOTAL: -10.8370;
#   R² (Val)   -> MMSE: -13.1642; CDRSB: -12.0982; LDELTOTAL: -5.8188;
# --- Epoch [005/500] ---
# Loss -> Train: 22.629258, Val: 17.956482 | LR: 1.0e-03
#   R² (Train) -> MMSE: -13.5185; CDRSB: -13.4738; LDELTOTAL: -9.3254;
#   R² (Val)   -> MMSE: -11.2894; CDRSB: -11.0422; LDELTOTAL: -4.8910;
# --- Epoch [006/500] ---
# Loss -> Train: 20.221218, Val: 16.396430 | LR: 1.0e-03
#   R² (Train) -> MMSE: -11.4338; CDRSB: -11.9773; LDELTOTAL: -8.5115;
#   R² (Val)   -> MMSE: -10.5941; CDRSB: -9.5969; LDELTOTAL: -4.3510;
# --- Epoch [007/500] ---
# Loss -> Train: 18.309933, Val: 14.749427 | LR: 1.0e-03
#   R² (Train) -> MMSE: -10.2027; CDRSB: -10.8698; LDELTOTAL: -7.3922;
#   R² (Val)   -> MMSE: -9.2512; CDRSB: -8.4820; LDELTOTAL: -3.8436;
# --- Epoch [008/500] ---
# Loss -> Train: 16.917960, Val: 13.372517 | LR: 1.0e-03
#   R² (Train) -> MMSE: -9.0375; CDRSB: -9.6688; LDELTOTAL: -6.5514;
#   R² (Val)   -> MMSE: -8.0591; CDRSB: -7.8352; LDELTOTAL: -3.1721;
# --- Epoch [009/500] ---
# Loss -> Train: 14.942375, Val: 11.788528 | LR: 1.0e-03
#   R² (Train) -> MMSE: -7.7990; CDRSB: -8.5846; LDELTOTAL: -5.6157;
#   R² (Val)   -> MMSE: -6.4962; CDRSB: -6.5082; LDELTOTAL: -2.9197;
# --- Epoch [010/500] ---
# Loss -> Train: 13.512401, Val: 10.651539 | LR: 1.0e-03
#   R² (Train) -> MMSE: -6.8614; CDRSB: -7.4624; LDELTOTAL: -4.7988;
#   R² (Val)   -> MMSE: -5.7020; CDRSB: -5.6461; LDELTOTAL: -2.4680;
# --- Epoch [011/500] ---
# Loss -> Train: 12.194966, Val: 9.879487 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.8644; CDRSB: -6.6539; LDELTOTAL: -4.2112;
#   R² (Val)   -> MMSE: -5.1532; CDRSB: -5.2035; LDELTOTAL: -2.1215;
# --- Epoch [012/500] ---
# Loss -> Train: 11.089430, Val: 9.328515 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.0690; CDRSB: -5.7864; LDELTOTAL: -3.7261;
#   R² (Val)   -> MMSE: -4.7164; CDRSB: -4.9468; LDELTOTAL: -1.7917;
# --- Epoch [013/500] ---
# Loss -> Train: 10.071044, Val: 8.335190 | LR: 1.0e-03
#   R² (Train) -> MMSE: -4.3182; CDRSB: -5.2296; LDELTOTAL: -3.2129;
#   R² (Val)   -> MMSE: -4.0660; CDRSB: -3.9795; LDELTOTAL: -1.5536;
# --- Epoch [014/500] ---
# Loss -> Train: 9.238822, Val: 7.642429 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.8601; CDRSB: -4.5021; LDELTOTAL: -2.6927;
#   R² (Val)   -> MMSE: -3.4210; CDRSB: -3.5506; LDELTOTAL: -1.4074;
# --- Epoch [015/500] ---
# Loss -> Train: 8.400433, Val: 7.136047 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.2585; CDRSB: -4.1317; LDELTOTAL: -2.3321;
#   R² (Val)   -> MMSE: -3.1460; CDRSB: -3.1635; LDELTOTAL: -1.1119;
# --- Epoch [016/500] ---
# Loss -> Train: 7.706807, Val: 6.594101 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.7804; CDRSB: -3.5429; LDELTOTAL: -1.9058;
#   R² (Val)   -> MMSE: -2.7145; CDRSB: -2.7778; LDELTOTAL: -0.9640;
# --- Epoch [017/500] ---
# Loss -> Train: 7.186930, Val: 6.105788 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.4879; CDRSB: -3.1323; LDELTOTAL: -1.7140;
#   R² (Val)   -> MMSE: -2.2975; CDRSB: -2.4048; LDELTOTAL: -0.8426;
# --- Epoch [018/500] ---
# Loss -> Train: 6.697479, Val: 5.642554 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.1069; CDRSB: -2.7787; LDELTOTAL: -1.3804;
#   R² (Val)   -> MMSE: -1.9490; CDRSB: -2.1609; LDELTOTAL: -0.6468;
# --- Epoch [019/500] ---
# Loss -> Train: 6.157670, Val: 6.652378 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.7836; CDRSB: -2.5143; LDELTOTAL: -1.2294;
#   R² (Val)   -> MMSE: -1.6077; CDRSB: -2.9682; LDELTOTAL: -1.4397;
# --- Epoch [020/500] ---
# Loss -> Train: 5.898885, Val: 5.076394 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.5223; CDRSB: -2.3368; LDELTOTAL: -1.1215;
#   R² (Val)   -> MMSE: -1.4979; CDRSB: -1.7743; LDELTOTAL: -0.4818;
# --- Epoch [021/500] ---
# Loss -> Train: 5.390255, Val: 4.646240 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.2870; CDRSB: -1.9653; LDELTOTAL: -0.8124;
#   R² (Val)   -> MMSE: -1.1423; CDRSB: -1.5177; LDELTOTAL: -0.3812;
# --- Epoch [022/500] ---
# Loss -> Train: 5.119067, Val: 4.417631 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.1102; CDRSB: -1.7169; LDELTOTAL: -0.6892;
#   R² (Val)   -> MMSE: -0.9460; CDRSB: -1.3851; LDELTOTAL: -0.3062;
# --- Epoch [023/500] ---
# Loss -> Train: 4.905654, Val: 4.325559 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.9520; CDRSB: -1.6407; LDELTOTAL: -0.6390;
#   R² (Val)   -> MMSE: -0.9626; CDRSB: -1.2338; LDELTOTAL: -0.2624;
# --- Epoch [024/500] ---
# Loss -> Train: 4.607677, Val: 4.060847 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.7869; CDRSB: -1.3706; LDELTOTAL: -0.5155;
#   R² (Val)   -> MMSE: -0.6899; CDRSB: -1.1372; LDELTOTAL: -0.2216;
# --- Epoch [025/500] ---
# Loss -> Train: 4.353645, Val: 4.128145 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.7035; CDRSB: -1.2073; LDELTOTAL: -0.3888;
#   R² (Val)   -> MMSE: -0.7694; CDRSB: -1.1289; LDELTOTAL: -0.2358;
# --- Epoch [026/500] ---
# Loss -> Train: 4.217031, Val: 3.787811 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.6156; CDRSB: -1.1158; LDELTOTAL: -0.3529;
#   R² (Val)   -> MMSE: -0.4430; CDRSB: -0.9499; LDELTOTAL: -0.2078;
# --- Epoch [027/500] ---
# Loss -> Train: 3.954267, Val: 3.794226 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.5037; CDRSB: -0.9233; LDELTOTAL: -0.2018;
#   R² (Val)   -> MMSE: -0.5873; CDRSB: -0.8597; LDELTOTAL: -0.1435;
# --- Epoch [028/500] ---
# Loss -> Train: 3.866290, Val: 3.464547 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3980; CDRSB: -0.9017; LDELTOTAL: -0.2060;
#   R² (Val)   -> MMSE: -0.3398; CDRSB: -0.6758; LDELTOTAL: -0.0888;
# --- Epoch [029/500] ---
# Loss -> Train: 3.695430, Val: 3.502151 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3925; CDRSB: -0.7442; LDELTOTAL: -0.1095;
#   R² (Val)   -> MMSE: -0.4272; CDRSB: -0.6246; LDELTOTAL: -0.0793;
# --- Epoch [030/500] ---
# Loss -> Train: 3.612359, Val: 3.773288 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3024; CDRSB: -0.6561; LDELTOTAL: -0.0901;
#   R² (Val)   -> MMSE: -0.4636; CDRSB: -1.1267; LDELTOTAL: -0.0614;
# --- Epoch [031/500] ---
# Loss -> Train: 3.508223, Val: 3.245154 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2801; CDRSB: -0.5679; LDELTOTAL: -0.0565;
#   R² (Val)   -> MMSE: -0.2955; CDRSB: -0.4615; LDELTOTAL: 0.0052;
# --- Epoch [032/500] ---
# Loss -> Train: 3.336374, Val: 4.048090 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2088; CDRSB: -0.4919; LDELTOTAL: -0.0080;
#   R² (Val)   -> MMSE: -0.2956; CDRSB: -1.2295; LDELTOTAL: -0.4561;
# --- Epoch [033/500] ---
# Loss -> Train: 3.344919, Val: 3.142344 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1750; CDRSB: -0.5110; LDELTOTAL: -0.0150;
#   R² (Val)   -> MMSE: -0.2313; CDRSB: -0.4105; LDELTOTAL: 0.0037;
# --- Epoch [034/500] ---
# Loss -> Train: 3.206988, Val: 3.021371 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1560; CDRSB: -0.4206; LDELTOTAL: 0.0405;
#   R² (Val)   -> MMSE: -0.1759; CDRSB: -0.3168; LDELTOTAL: 0.0235;
# --- Epoch [035/500] ---
# Loss -> Train: 3.243056, Val: 3.040235 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1268; CDRSB: -0.4073; LDELTOTAL: 0.0829;
#   R² (Val)   -> MMSE: -0.1753; CDRSB: -0.3484; LDELTOTAL: 0.0458;
# --- Epoch [036/500] ---
# Loss -> Train: 3.049954, Val: 3.011941 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1191; CDRSB: -0.3143; LDELTOTAL: 0.0833;
#   R² (Val)   -> MMSE: -0.1476; CDRSB: -0.3675; LDELTOTAL: 0.0359;
# --- Epoch [037/500] ---
# Loss -> Train: 2.982552, Val: 2.930101 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0649; CDRSB: -0.2609; LDELTOTAL: 0.0922;
#   R² (Val)   -> MMSE: -0.0624; CDRSB: -0.3254; LDELTOTAL: 0.0012;
# --- Epoch [038/500] ---
# Loss -> Train: 2.929401, Val: 4.084613 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0448; CDRSB: -0.2531; LDELTOTAL: 0.1197;
#   R² (Val)   -> MMSE: -0.3540; CDRSB: -0.8784; LDELTOTAL: -0.6287;
# --- Epoch [039/500] ---
# Loss -> Train: 2.987465, Val: 2.743276 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0559; CDRSB: -0.2224; LDELTOTAL: 0.1279;
#   R² (Val)   -> MMSE: -0.0537; CDRSB: -0.1604; LDELTOTAL: 0.0944;
# --- Epoch [040/500] ---
# Loss -> Train: 2.885092, Val: 2.868477 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0327; CDRSB: -0.1689; LDELTOTAL: 0.1350;
#   R² (Val)   -> MMSE: -0.0715; CDRSB: -0.2800; LDELTOTAL: 0.0831;
# --- Epoch [041/500] ---
# Loss -> Train: 2.790869, Val: 2.798807 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0012; CDRSB: -0.1617; LDELTOTAL: 0.1654;
#   R² (Val)   -> MMSE: -0.0591; CDRSB: -0.2126; LDELTOTAL: 0.0523;
# --- Epoch [042/500] ---
# Loss -> Train: 2.784324, Val: 3.522842 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0011; CDRSB: -0.1365; LDELTOTAL: 0.1799;
#   R² (Val)   -> MMSE: -0.2500; CDRSB: -0.5335; LDELTOTAL: -0.3693;
# --- Epoch [043/500] ---
# Loss -> Train: 2.765990, Val: 2.639777 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0106; CDRSB: -0.1193; LDELTOTAL: 0.1755;
#   R² (Val)   -> MMSE: -0.0039; CDRSB: -0.1131; LDELTOTAL: 0.1005;
# --- Epoch [044/500] ---
# Loss -> Train: 2.754627, Val: 2.692064 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0008; CDRSB: -0.1089; LDELTOTAL: 0.1900;
#   R² (Val)   -> MMSE: 0.0035; CDRSB: -0.1512; LDELTOTAL: 0.0590;
# --- Epoch [045/500] ---
# Loss -> Train: 2.690640, Val: 2.572842 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0299; CDRSB: -0.0826; LDELTOTAL: 0.1900;
#   R² (Val)   -> MMSE: 0.0340; CDRSB: -0.0908; LDELTOTAL: 0.1203;
# --- Epoch [046/500] ---
# Loss -> Train: 2.691748, Val: 2.590923 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0332; CDRSB: -0.0531; LDELTOTAL: 0.1927;
#   R² (Val)   -> MMSE: 0.0339; CDRSB: -0.0977; LDELTOTAL: 0.0992;
# --- Epoch [047/500] ---
# Loss -> Train: 2.700277, Val: 2.565335 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0137; CDRSB: -0.0553; LDELTOTAL: 0.1921;
#   R² (Val)   -> MMSE: 0.0351; CDRSB: -0.0838; LDELTOTAL: 0.1002;
# --- Epoch [048/500] ---
# Loss -> Train: 2.610292, Val: 3.700085 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0482; CDRSB: -0.0241; LDELTOTAL: 0.2228;
#   R² (Val)   -> MMSE: -0.2345; CDRSB: -1.1786; LDELTOTAL: -0.3737;
# --- Epoch [049/500] ---
# Loss -> Train: 2.627365, Val: 3.258443 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0505; CDRSB: -0.0124; LDELTOTAL: 0.2019;
#   R² (Val)   -> MMSE: -0.1225; CDRSB: -0.7164; LDELTOTAL: -0.2201;
# --- Epoch [050/500] ---
# Loss -> Train: 2.615226, Val: 3.025012 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0522; CDRSB: -0.0073; LDELTOTAL: 0.2136;
#   R² (Val)   -> MMSE: -0.1362; CDRSB: -0.2875; LDELTOTAL: -0.1284;
# --- Epoch [051/500] ---
# Loss -> Train: 2.650765, Val: 2.610348 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0389; CDRSB: -0.0167; LDELTOTAL: 0.2111;
#   R² (Val)   -> MMSE: 0.0283; CDRSB: -0.0993; LDELTOTAL: 0.0688;
# --- Epoch [052/500] ---
# Loss -> Train: 2.585455, Val: 3.145918 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0524; CDRSB: 0.0025; LDELTOTAL: 0.2225;
#   R² (Val)   -> MMSE: -0.0699; CDRSB: -0.6277; LDELTOTAL: -0.0891;
# --- Epoch [053/500] ---
# Loss -> Train: 2.603236, Val: 2.502768 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0447; CDRSB: 0.0068; LDELTOTAL: 0.2075;
#   R² (Val)   -> MMSE: 0.0544; CDRSB: -0.0485; LDELTOTAL: 0.1293;
# --- Epoch [054/500] ---
# Loss -> Train: 2.521908, Val: 4.386752 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0676; CDRSB: 0.0300; LDELTOTAL: 0.2456;
#   R² (Val)   -> MMSE: -0.5462; CDRSB: -0.8182; LDELTOTAL: -0.9200;
# --- Epoch [055/500] ---
# Loss -> Train: 2.577857, Val: 2.732900 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0513; CDRSB: -0.0108; LDELTOTAL: 0.2363;
#   R² (Val)   -> MMSE: -0.0060; CDRSB: -0.1328; LDELTOTAL: -0.0172;
# --- Epoch [056/500] ---
# Loss -> Train: 2.575311, Val: 2.475144 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0660; CDRSB: 0.0315; LDELTOTAL: 0.2342;
#   R² (Val)   -> MMSE: 0.0586; CDRSB: -0.0160; LDELTOTAL: 0.1359;
# --- Epoch [057/500] ---
# Loss -> Train: 2.526466, Val: 3.012796 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0640; CDRSB: 0.0158; LDELTOTAL: 0.2404;
#   R² (Val)   -> MMSE: -0.1242; CDRSB: -0.2136; LDELTOTAL: -0.1649;
# --- Epoch [058/500] ---
# Loss -> Train: 2.580856, Val: 2.589316 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0612; CDRSB: 0.0224; LDELTOTAL: 0.2361;
#   R² (Val)   -> MMSE: 0.0250; CDRSB: -0.0703; LDELTOTAL: 0.0692;
# --- Epoch [059/500] ---
# Loss -> Train: 2.562597, Val: 2.482830 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0551; CDRSB: 0.0136; LDELTOTAL: 0.2322;
#   R² (Val)   -> MMSE: 0.0494; CDRSB: -0.0208; LDELTOTAL: 0.1372;
# --- Epoch [060/500] ---
# Loss -> Train: 2.528338, Val: 3.802213 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0760; CDRSB: 0.0430; LDELTOTAL: 0.2394;
#   R² (Val)   -> MMSE: -0.3750; CDRSB: -0.3570; LDELTOTAL: -0.7065;
# --- Epoch [061/500] ---
# Loss -> Train: 2.551880, Val: 2.786962 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0753; CDRSB: 0.0175; LDELTOTAL: 0.2384;
#   R² (Val)   -> MMSE: 0.0043; CDRSB: -0.1579; LDELTOTAL: -0.0349;
# --- Epoch [062/500] ---
# Loss -> Train: 2.499271, Val: 2.464885 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0785; CDRSB: 0.0318; LDELTOTAL: 0.2656;
#   R² (Val)   -> MMSE: 0.0591; CDRSB: -0.0303; LDELTOTAL: 0.1491;
# --- Epoch [063/500] ---
# Loss -> Train: 2.574781, Val: 2.939381 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0562; CDRSB: 0.0260; LDELTOTAL: 0.2360;
#   R² (Val)   -> MMSE: -0.0508; CDRSB: -0.2410; LDELTOTAL: -0.2312;
# --- Epoch [064/500] ---
# Loss -> Train: 2.543758, Val: 2.508989 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0692; CDRSB: 0.0465; LDELTOTAL: 0.2437;
#   R² (Val)   -> MMSE: 0.0544; CDRSB: -0.0370; LDELTOTAL: 0.1110;
# --- Epoch [065/500] ---
# Loss -> Train: 2.628540, Val: 3.198966 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0629; CDRSB: 0.0180; LDELTOTAL: 0.2311;
#   R² (Val)   -> MMSE: -0.1669; CDRSB: -0.2478; LDELTOTAL: -0.3539;
# --- Epoch [066/500] ---
# Loss -> Train: 2.569782, Val: 2.547343 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0538; CDRSB: 0.0153; LDELTOTAL: 0.2280;
#   R² (Val)   -> MMSE: 0.0621; CDRSB: -0.0662; LDELTOTAL: 0.0849;
# --- Epoch [067/500] ---
# Loss -> Train: 2.524071, Val: 5.569391 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0788; CDRSB: 0.0362; LDELTOTAL: 0.2364;
#   R² (Val)   -> MMSE: -1.1492; CDRSB: -0.6618; LDELTOTAL: -2.6942;
# --- Epoch [068/500] ---
# Loss -> Train: 2.527860, Val: 2.506210 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0717; CDRSB: 0.0314; LDELTOTAL: 0.2434;
#   R² (Val)   -> MMSE: 0.0817; CDRSB: -0.0486; LDELTOTAL: 0.0771;
# --- Epoch [069/500] ---
# Loss -> Train: 2.536547, Val: 2.883404 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0566; CDRSB: 0.0423; LDELTOTAL: 0.2407;
#   R² (Val)   -> MMSE: -0.0254; CDRSB: -0.1120; LDELTOTAL: -0.1587;
# --- Epoch [070/500] ---
# Loss -> Train: 2.533076, Val: 2.891094 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0748; CDRSB: 0.0447; LDELTOTAL: 0.2249;
#   R² (Val)   -> MMSE: -0.1032; CDRSB: -0.1089; LDELTOTAL: -0.1183;
# --- Epoch [071/500] ---
# Loss -> Train: 2.592607, Val: 2.533028 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0598; CDRSB: 0.0344; LDELTOTAL: 0.2468;
#   R² (Val)   -> MMSE: 0.0419; CDRSB: -0.0309; LDELTOTAL: 0.0924;
# --- Epoch [072/500] ---
# Loss -> Train: 2.540571, Val: 2.469821 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0613; CDRSB: 0.0352; LDELTOTAL: 0.2395;
#   R² (Val)   -> MMSE: 0.0605; CDRSB: -0.0305; LDELTOTAL: 0.1370;
# --- Epoch [073/500] ---
# Loss -> Train: 2.524262, Val: 2.481920 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0752; CDRSB: 0.0344; LDELTOTAL: 0.2386;
#   R² (Val)   -> MMSE: 0.0596; CDRSB: -0.0277; LDELTOTAL: 0.1237;
# --- Epoch [074/500] ---
# Loss -> Train: 2.544170, Val: 2.436675 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0823; CDRSB: 0.0468; LDELTOTAL: 0.2613;
#   R² (Val)   -> MMSE: 0.0888; CDRSB: -0.0164; LDELTOTAL: 0.1378;
# --- Epoch [075/500] ---
# Loss -> Train: 2.452819, Val: 2.410367 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0921; CDRSB: 0.0518; LDELTOTAL: 0.2591;
#   R² (Val)   -> MMSE: 0.0906; CDRSB: -0.0102; LDELTOTAL: 0.1630;
# --- Epoch [076/500] ---
# Loss -> Train: 2.502010, Val: 2.454757 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0674; CDRSB: 0.0556; LDELTOTAL: 0.2901;
#   R² (Val)   -> MMSE: 0.0864; CDRSB: -0.0266; LDELTOTAL: 0.1303;
# --- Epoch [077/500] ---
# Loss -> Train: 2.491562, Val: 2.411047 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0724; CDRSB: 0.0388; LDELTOTAL: 0.2664;
#   R² (Val)   -> MMSE: 0.0930; CDRSB: -0.0165; LDELTOTAL: 0.1689;
# --- Epoch [078/500] ---
# Loss -> Train: 2.499273, Val: 2.449986 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0829; CDRSB: 0.0489; LDELTOTAL: 0.2765;
#   R² (Val)   -> MMSE: 0.0862; CDRSB: -0.0292; LDELTOTAL: 0.1390;
# --- Epoch [079/500] ---
# Loss -> Train: 2.463085, Val: 2.444568 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0970; CDRSB: 0.0715; LDELTOTAL: 0.2826;
#   R² (Val)   -> MMSE: 0.0863; CDRSB: -0.0230; LDELTOTAL: 0.1456;
# --- Epoch [080/500] ---
# Loss -> Train: 2.491960, Val: 2.410475 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0777; CDRSB: 0.0529; LDELTOTAL: 0.2505;
#   R² (Val)   -> MMSE: 0.0931; CDRSB: -0.0152; LDELTOTAL: 0.1694;
# --- Epoch [081/500] ---
# Loss -> Train: 2.504623, Val: 2.455871 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0680; CDRSB: 0.0559; LDELTOTAL: 0.2566;
#   R² (Val)   -> MMSE: 0.0692; CDRSB: -0.0280; LDELTOTAL: 0.1518;
# --- Epoch [082/500] ---
# Loss -> Train: 2.476740, Val: 2.464020 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0763; CDRSB: 0.0456; LDELTOTAL: 0.2797;
#   R² (Val)   -> MMSE: 0.0817; CDRSB: -0.0272; LDELTOTAL: 0.1302;
# --- Epoch [083/500] ---
# Loss -> Train: 2.468089, Val: 2.435997 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0975; CDRSB: 0.0593; LDELTOTAL: 0.2722;
#   R² (Val)   -> MMSE: 0.0806; CDRSB: -0.0237; LDELTOTAL: 0.1657;
# --- Epoch [084/500] ---
# Loss -> Train: 2.437910, Val: 2.412520 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0920; CDRSB: 0.0624; LDELTOTAL: 0.3064;
#   R² (Val)   -> MMSE: 0.0939; CDRSB: -0.0187; LDELTOTAL: 0.1679;
# --- Epoch [085/500] ---
# Loss -> Train: 2.432446, Val: 2.423998 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0830; CDRSB: 0.0620; LDELTOTAL: 0.2895;
#   R² (Val)   -> MMSE: 0.0807; CDRSB: -0.0199; LDELTOTAL: 0.1655;
# --- Epoch [086/500] ---
# Loss -> Train: 2.508592, Val: 2.402422 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0627; CDRSB: 0.0522; LDELTOTAL: 0.2609;
#   R² (Val)   -> MMSE: 0.0894; CDRSB: -0.0113; LDELTOTAL: 0.1739;
# --- Epoch [087/500] ---
# Loss -> Train: 2.499266, Val: 2.402381 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0760; CDRSB: 0.0425; LDELTOTAL: 0.2791;
#   R² (Val)   -> MMSE: 0.0910; CDRSB: -0.0100; LDELTOTAL: 0.1723;
# --- Epoch [088/500] ---
# Loss -> Train: 2.454231, Val: 2.507078 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0936; CDRSB: 0.0625; LDELTOTAL: 0.2805;
#   R² (Val)   -> MMSE: 0.0736; CDRSB: -0.0380; LDELTOTAL: 0.0898;
# --- Epoch [089/500] ---
# Loss -> Train: 2.487291, Val: 2.405929 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0771; CDRSB: 0.0548; LDELTOTAL: 0.2515;
#   R² (Val)   -> MMSE: 0.0904; CDRSB: -0.0142; LDELTOTAL: 0.1716;
# --- Epoch [090/500] ---
# Loss -> Train: 2.482483, Val: 2.416001 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0877; CDRSB: 0.0645; LDELTOTAL: 0.2571;
#   R² (Val)   -> MMSE: 0.0885; CDRSB: -0.0142; LDELTOTAL: 0.1544;
# --- Epoch [091/500] ---
# Loss -> Train: 2.453925, Val: 2.426832 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0796; CDRSB: 0.0595; LDELTOTAL: 0.2822;
#   R² (Val)   -> MMSE: 0.0765; CDRSB: -0.0176; LDELTOTAL: 0.1656;
# --- Epoch [092/500] ---
# Loss -> Train: 2.491131, Val: 2.491818 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0810; CDRSB: 0.0523; LDELTOTAL: 0.2485;
#   R² (Val)   -> MMSE: 0.0528; CDRSB: -0.0390; LDELTOTAL: 0.1311;
# --- Epoch [093/500] ---
# Loss -> Train: 2.513863, Val: 2.408419 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0899; CDRSB: 0.0559; LDELTOTAL: 0.2543;
#   R² (Val)   -> MMSE: 0.0861; CDRSB: -0.0114; LDELTOTAL: 0.1640;
# --- Epoch [094/500] ---
# Loss -> Train: 2.452924, Val: 2.436655 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0837; CDRSB: 0.0490; LDELTOTAL: 0.2812;
#   R² (Val)   -> MMSE: 0.0749; CDRSB: -0.0234; LDELTOTAL: 0.1613;
# --- Epoch [095/500] ---
# Loss -> Train: 2.474623, Val: 2.412481 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0771; CDRSB: 0.0397; LDELTOTAL: 0.2702;
#   R² (Val)   -> MMSE: 0.0880; CDRSB: -0.0170; LDELTOTAL: 0.1668;
# --- Epoch [096/500] ---
# Loss -> Train: 2.444184, Val: 2.441876 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0991; CDRSB: 0.0703; LDELTOTAL: 0.2743;
#   R² (Val)   -> MMSE: 0.0864; CDRSB: -0.0226; LDELTOTAL: 0.1462;
# --- Epoch [097/500] ---
# Loss -> Train: 2.439563, Val: 2.408594 | LR: 1.0e-04
#   R² (Train) -> MMSE: 0.0957; CDRSB: 0.0719; LDELTOTAL: 0.2882;
#   R² (Val)   -> MMSE: 0.0866; CDRSB: -0.0167; LDELTOTAL: 0.1718;
# --- Epoch [098/500] ---
# Loss -> Train: 2.443794, Val: 2.421576 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0882; CDRSB: 0.0477; LDELTOTAL: 0.2915;
#   R² (Val)   -> MMSE: 0.0896; CDRSB: -0.0226; LDELTOTAL: 0.1558;
# --- Epoch [099/500] ---
# Loss -> Train: 2.501490, Val: 2.434033 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0846; CDRSB: 0.0401; LDELTOTAL: 0.2791;
#   R² (Val)   -> MMSE: 0.0882; CDRSB: -0.0259; LDELTOTAL: 0.1483;
# --- Epoch [100/500] ---
# Loss -> Train: 2.483447, Val: 2.406900 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0832; CDRSB: 0.0581; LDELTOTAL: 0.2806;
#   R² (Val)   -> MMSE: 0.0910; CDRSB: -0.0136; LDELTOTAL: 0.1630;
# --- Epoch [101/500] ---
# Loss -> Train: 2.436139, Val: 2.426574 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.1037; CDRSB: 0.0574; LDELTOTAL: 0.2824;
#   R² (Val)   -> MMSE: 0.0885; CDRSB: -0.0224; LDELTOTAL: 0.1600;
# --- Epoch [102/500] ---
# Loss -> Train: 2.478248, Val: 2.444988 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0864; CDRSB: 0.0490; LDELTOTAL: 0.2654;
#   R² (Val)   -> MMSE: 0.0868; CDRSB: -0.0313; LDELTOTAL: 0.1473;
# --- Epoch [103/500] ---
# Loss -> Train: 2.447145, Val: 2.442122 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0968; CDRSB: 0.0608; LDELTOTAL: 0.2879;
#   R² (Val)   -> MMSE: 0.0860; CDRSB: -0.0267; LDELTOTAL: 0.1424;
# --- Epoch [104/500] ---
# Loss -> Train: 2.487407, Val: 2.426387 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0806; CDRSB: 0.0495; LDELTOTAL: 0.2678;
#   R² (Val)   -> MMSE: 0.0886; CDRSB: -0.0196; LDELTOTAL: 0.1490;
# --- Epoch [105/500] ---
# Loss -> Train: 2.458002, Val: 2.433443 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0922; CDRSB: 0.0657; LDELTOTAL: 0.2854;
#   R² (Val)   -> MMSE: 0.0870; CDRSB: -0.0242; LDELTOTAL: 0.1509;
# --- Epoch [106/500] ---
# Loss -> Train: 2.434853, Val: 2.424082 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0847; CDRSB: 0.0581; LDELTOTAL: 0.2771;
#   R² (Val)   -> MMSE: 0.0876; CDRSB: -0.0208; LDELTOTAL: 0.1552;
# --- Epoch [107/500] ---
# Loss -> Train: 2.447547, Val: 2.409714 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0870; CDRSB: 0.0614; LDELTOTAL: 0.2666;
#   R² (Val)   -> MMSE: 0.0887; CDRSB: -0.0156; LDELTOTAL: 0.1622;
# --- Epoch [108/500] ---
# Loss -> Train: 2.454119, Val: 2.408328 | LR: 1.0e-05
#   R² (Train) -> MMSE: 0.0807; CDRSB: 0.0601; LDELTOTAL: 0.2809;
#   R² (Val)   -> MMSE: 0.0914; CDRSB: -0.0190; LDELTOTAL: 0.1706;
# --- Epoch [109/500] ---
# Loss -> Train: 2.437295, Val: 2.405767 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0879; CDRSB: 0.0739; LDELTOTAL: 0.2793;
#   R² (Val)   -> MMSE: 0.0909; CDRSB: -0.0169; LDELTOTAL: 0.1747;
# --- Epoch [110/500] ---
# Loss -> Train: 2.492478, Val: 2.411798 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0865; CDRSB: 0.0518; LDELTOTAL: 0.2830;
#   R² (Val)   -> MMSE: 0.0901; CDRSB: -0.0186; LDELTOTAL: 0.1668;
# --- Epoch [111/500] ---
# Loss -> Train: 2.438305, Val: 2.418690 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0844; CDRSB: 0.0561; LDELTOTAL: 0.2806;
#   R² (Val)   -> MMSE: 0.0895; CDRSB: -0.0194; LDELTOTAL: 0.1607;
# --- Epoch [112/500] ---
# Loss -> Train: 2.435089, Val: 2.420528 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.1025; CDRSB: 0.0544; LDELTOTAL: 0.2810;
#   R² (Val)   -> MMSE: 0.0886; CDRSB: -0.0209; LDELTOTAL: 0.1616;
# --- Epoch [113/500] ---
# Loss -> Train: 2.463167, Val: 2.411042 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0813; CDRSB: 0.0634; LDELTOTAL: 0.2842;
#   R² (Val)   -> MMSE: 0.0898; CDRSB: -0.0131; LDELTOTAL: 0.1584;
# --- Epoch [114/500] ---
# Loss -> Train: 2.452831, Val: 2.414154 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0904; CDRSB: 0.0546; LDELTOTAL: 0.2883;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: -0.0195; LDELTOTAL: 0.1662;
# --- Epoch [115/500] ---
# Loss -> Train: 2.450157, Val: 2.419279 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0932; CDRSB: 0.0731; LDELTOTAL: 0.2877;
#   R² (Val)   -> MMSE: 0.0879; CDRSB: -0.0178; LDELTOTAL: 0.1552;
# --- Epoch [116/500] ---
# Loss -> Train: 2.480801, Val: 2.434172 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0761; CDRSB: 0.0463; LDELTOTAL: 0.2729;
#   R² (Val)   -> MMSE: 0.0865; CDRSB: -0.0231; LDELTOTAL: 0.1484;
# --- Epoch [117/500] ---
# Loss -> Train: 2.460633, Val: 2.411809 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0754; CDRSB: 0.0478; LDELTOTAL: 0.2765;
#   R² (Val)   -> MMSE: 0.0906; CDRSB: -0.0189; LDELTOTAL: 0.1680;
# --- Epoch [118/500] ---
# Loss -> Train: 2.474884, Val: 2.413030 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0753; CDRSB: 0.0601; LDELTOTAL: 0.2684;
#   R² (Val)   -> MMSE: 0.0895; CDRSB: -0.0182; LDELTOTAL: 0.1643;
# --- Epoch [119/500] ---
# Loss -> Train: 2.454084, Val: 2.432100 | LR: 1.0e-06
#   R² (Train) -> MMSE: 0.0850; CDRSB: 0.0579; LDELTOTAL: 0.2888;
#   R² (Val)   -> MMSE: 0.0867; CDRSB: -0.0212; LDELTOTAL: 0.1459;
# --- Epoch [120/500] ---
# Loss -> Train: 2.492453, Val: 2.416888 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0754; CDRSB: 0.0455; LDELTOTAL: 0.2602;
#   R² (Val)   -> MMSE: 0.0893; CDRSB: -0.0204; LDELTOTAL: 0.1669;
# --- Epoch [121/500] ---
# Loss -> Train: 2.532650, Val: 2.414427 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0945; CDRSB: 0.0534; LDELTOTAL: 0.2791;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: -0.0171; LDELTOTAL: 0.1682;
# --- Epoch [122/500] ---
# Loss -> Train: 2.468797, Val: 2.408484 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0730; CDRSB: 0.0607; LDELTOTAL: 0.2651;
#   R² (Val)   -> MMSE: 0.0900; CDRSB: -0.0171; LDELTOTAL: 0.1664;
# --- Epoch [123/500] ---
# Loss -> Train: 2.471833, Val: 2.415181 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0907; CDRSB: 0.0438; LDELTOTAL: 0.2880;
#   R² (Val)   -> MMSE: 0.0893; CDRSB: -0.0193; LDELTOTAL: 0.1640;
# --- Epoch [124/500] ---
# Loss -> Train: 2.451760, Val: 2.410514 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0856; CDRSB: 0.0688; LDELTOTAL: 0.2866;
#   R² (Val)   -> MMSE: 0.0906; CDRSB: -0.0189; LDELTOTAL: 0.1667;
# --- Epoch [125/500] ---
# Loss -> Train: 2.452435, Val: 2.411442 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0942; CDRSB: 0.0540; LDELTOTAL: 0.2832;
#   R² (Val)   -> MMSE: 0.0906; CDRSB: -0.0167; LDELTOTAL: 0.1636;
# --- Epoch [126/500] ---
# Loss -> Train: 2.452060, Val: 2.421435 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0952; CDRSB: 0.0634; LDELTOTAL: 0.2739;
#   R² (Val)   -> MMSE: 0.0881; CDRSB: -0.0187; LDELTOTAL: 0.1630;
# --- Epoch [127/500] ---
# Loss -> Train: 2.431036, Val: 2.410228 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0979; CDRSB: 0.0673; LDELTOTAL: 0.2968;
#   R² (Val)   -> MMSE: 0.0905; CDRSB: -0.0169; LDELTOTAL: 0.1646;
# --- Epoch [128/500] ---
# Loss -> Train: 2.481465, Val: 2.420025 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0877; CDRSB: 0.0588; LDELTOTAL: 0.2680;
#   R² (Val)   -> MMSE: 0.0887; CDRSB: -0.0202; LDELTOTAL: 0.1609;
# --- Epoch [129/500] ---
# Loss -> Train: 2.471822, Val: 2.418871 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0757; CDRSB: 0.0589; LDELTOTAL: 0.2840;
#   R² (Val)   -> MMSE: 0.0892; CDRSB: -0.0208; LDELTOTAL: 0.1631;
# --- Epoch [130/500] ---
# Loss -> Train: 2.439848, Val: 2.412894 | LR: 1.0e-07
#   R² (Train) -> MMSE: 0.0886; CDRSB: 0.0663; LDELTOTAL: 0.2780;
#   R² (Val)   -> MMSE: 0.0901; CDRSB: -0.0200; LDELTOTAL: 0.1665;
# --- Epoch [131/500] ---
# Loss -> Train: 2.486469, Val: 2.419866 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0847; CDRSB: 0.0557; LDELTOTAL: 0.2699;
#   R² (Val)   -> MMSE: 0.0887; CDRSB: -0.0195; LDELTOTAL: 0.1579;
# --- Epoch [132/500] ---
# Loss -> Train: 2.452629, Val: 2.434446 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0920; CDRSB: 0.0630; LDELTOTAL: 0.2772;
#   R² (Val)   -> MMSE: 0.0854; CDRSB: -0.0233; LDELTOTAL: 0.1498;
# --- Epoch [133/500] ---
# Loss -> Train: 2.470659, Val: 2.411692 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0858; CDRSB: 0.0543; LDELTOTAL: 0.2693;
#   R² (Val)   -> MMSE: 0.0915; CDRSB: -0.0200; LDELTOTAL: 0.1699;
# --- Epoch [134/500] ---
# Loss -> Train: 2.448118, Val: 2.416264 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0972; CDRSB: 0.0487; LDELTOTAL: 0.2844;
#   R² (Val)   -> MMSE: 0.0890; CDRSB: -0.0175; LDELTOTAL: 0.1589;
# --- Epoch [135/500] ---
# Loss -> Train: 2.427148, Val: 2.416347 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0853; CDRSB: 0.0698; LDELTOTAL: 0.2880;
#   R² (Val)   -> MMSE: 0.0893; CDRSB: -0.0203; LDELTOTAL: 0.1659;
# --- Epoch [136/500] ---
# Loss -> Train: 2.476774, Val: 2.413078 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0813; CDRSB: 0.0383; LDELTOTAL: 0.2835;
#   R² (Val)   -> MMSE: 0.0900; CDRSB: -0.0183; LDELTOTAL: 0.1681;
# --- Epoch [137/500] ---
# Loss -> Train: 2.424967, Val: 2.418211 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0880; CDRSB: 0.0616; LDELTOTAL: 0.2763;
#   R² (Val)   -> MMSE: 0.0880; CDRSB: -0.0192; LDELTOTAL: 0.1613;
#
# 提前停止于周期 137.
#
# 折叠 1 完成。最佳验证损失: 2.402381
# 对应的验证集R²: {'MMSE': 0.09098643064498901, 'CDRSB': -0.009952664375305176, 'LDELTOTAL': 0.17230874300003052}
# 对应的训练集R²: {'MMSE': 0.07597476243972778, 'CDRSB': 0.04250919818878174, 'LDELTOTAL': 0.2790513038635254}
#
# ========== 折叠 2/5 ==========
# --- Epoch [001/500] ---
# Loss -> Train: 71.593700, Val: 72.607992 | LR: 1.0e-03
#   R² (Train) -> MMSE: -11.3767; CDRSB: -57.2183; LDELTOTAL: -65.8324;
#   R² (Val)   -> MMSE: -4.2630; CDRSB: -36.7862; LDELTOTAL: -63.2555;
# --- Epoch [002/500] ---
# Loss -> Train: 55.652753, Val: 60.200953 | LR: 1.0e-03
#   R² (Train) -> MMSE: -7.7361; CDRSB: -43.4259; LDELTOTAL: -53.0741;
#   R² (Val)   -> MMSE: -3.9536; CDRSB: -31.4758; LDELTOTAL: -48.8183;
# --- Epoch [003/500] ---
# Loss -> Train: 50.518074, Val: 68.413367 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.7664; CDRSB: -39.2157; LDELTOTAL: -47.5043;
#   R² (Val)   -> MMSE: -3.0919; CDRSB: -36.3993; LDELTOTAL: -58.4876;
# --- Epoch [004/500] ---
# Loss -> Train: 46.540566, Val: 51.671491 | LR: 1.0e-03
#   R² (Train) -> MMSE: -5.1451; CDRSB: -36.8853; LDELTOTAL: -46.1418;
#   R² (Val)   -> MMSE: -2.6493; CDRSB: -26.5378; LDELTOTAL: -43.0924;
# --- Epoch [005/500] ---
# Loss -> Train: 41.344277, Val: 45.383130 | LR: 1.0e-03
#   R² (Train) -> MMSE: -4.3363; CDRSB: -31.7248; LDELTOTAL: -39.2842;
#   R² (Val)   -> MMSE: -2.0924; CDRSB: -23.6621; LDELTOTAL: -36.7196;
# --- Epoch [006/500] ---
# Loss -> Train: 37.054830, Val: 40.393572 | LR: 1.0e-03
#   R² (Train) -> MMSE: -3.7182; CDRSB: -28.7108; LDELTOTAL: -35.0215;
#   R² (Val)   -> MMSE: -1.6794; CDRSB: -21.3068; LDELTOTAL: -31.9841;
# --- Epoch [007/500] ---
# Loss -> Train: 34.308022, Val: 37.922721 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.6973; CDRSB: -26.6898; LDELTOTAL: -33.5031;
#   R² (Val)   -> MMSE: -1.3265; CDRSB: -19.8122; LDELTOTAL: -30.3986;
# --- Epoch [008/500] ---
# Loss -> Train: 30.883964, Val: 33.965065 | LR: 1.0e-03
#   R² (Train) -> MMSE: -2.3974; CDRSB: -24.4044; LDELTOTAL: -29.4892;
#   R² (Val)   -> MMSE: -1.1592; CDRSB: -17.7333; LDELTOTAL: -26.5636;
# --- Epoch [009/500] ---
# Loss -> Train: 27.608738, Val: 30.677193 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.8647; CDRSB: -21.3681; LDELTOTAL: -26.2782;
#   R² (Val)   -> MMSE: -1.0007; CDRSB: -15.5634; LDELTOTAL: -24.1094;
# --- Epoch [010/500] ---
# Loss -> Train: 24.678979, Val: 29.759222 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.4911; CDRSB: -18.4546; LDELTOTAL: -23.3733;
#   R² (Val)   -> MMSE: -0.7916; CDRSB: -15.2203; LDELTOTAL: -23.2241;
# --- Epoch [011/500] ---
# Loss -> Train: 22.927156, Val: 26.369828 | LR: 1.0e-03
#   R² (Train) -> MMSE: -1.1446; CDRSB: -17.8930; LDELTOTAL: -21.5466;
#   R² (Val)   -> MMSE: -0.6497; CDRSB: -12.9889; LDELTOTAL: -20.6803;
# --- Epoch [012/500] ---
# Loss -> Train: 20.073893, Val: 23.317760 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.9593; CDRSB: -14.5926; LDELTOTAL: -18.0720;
#   R² (Val)   -> MMSE: -0.5106; CDRSB: -11.4107; LDELTOTAL: -17.4977;
# --- Epoch [013/500] ---
# Loss -> Train: 18.899997, Val: 21.422466 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.7857; CDRSB: -14.1919; LDELTOTAL: -16.8613;
#   R² (Val)   -> MMSE: -0.4273; CDRSB: -10.4716; LDELTOTAL: -15.7392;
# --- Epoch [014/500] ---
# Loss -> Train: 17.781435, Val: 19.532430 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.7165; CDRSB: -13.0207; LDELTOTAL: -16.4815;
#   R² (Val)   -> MMSE: -0.3277; CDRSB: -9.2449; LDELTOTAL: -14.0731;
# --- Epoch [015/500] ---
# Loss -> Train: 15.690905, Val: 17.586969 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.4922; CDRSB: -11.6701; LDELTOTAL: -13.3311;
#   R² (Val)   -> MMSE: -0.2919; CDRSB: -8.2822; LDELTOTAL: -12.0705;
# --- Epoch [016/500] ---
# Loss -> Train: 15.540047, Val: 16.288814 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.4610; CDRSB: -10.5361; LDELTOTAL: -12.2433;
#   R² (Val)   -> MMSE: -0.2699; CDRSB: -7.3797; LDELTOTAL: -10.9717;
# --- Epoch [017/500] ---
# Loss -> Train: 13.396903, Val: 15.201957 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.3504; CDRSB: -9.7729; LDELTOTAL: -10.9457;
#   R² (Val)   -> MMSE: -0.2385; CDRSB: -6.8481; LDELTOTAL: -9.9452;
# --- Epoch [018/500] ---
# Loss -> Train: 11.835183, Val: 13.857403 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2746; CDRSB: -8.0474; LDELTOTAL: -9.3482;
#   R² (Val)   -> MMSE: -0.1909; CDRSB: -5.8732; LDELTOTAL: -8.9290;
# --- Epoch [019/500] ---
# Loss -> Train: 10.887866, Val: 12.309530 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.2336; CDRSB: -7.0361; LDELTOTAL: -8.4841;
#   R² (Val)   -> MMSE: -0.1736; CDRSB: -5.0915; LDELTOTAL: -7.2747;
# --- Epoch [020/500] ---
# Loss -> Train: 10.048927, Val: 11.214579 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1910; CDRSB: -6.5923; LDELTOTAL: -7.4428;
#   R² (Val)   -> MMSE: -0.1522; CDRSB: -4.4871; LDELTOTAL: -6.1692;
# --- Epoch [021/500] ---
# Loss -> Train: 9.444534, Val: 10.395352 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1653; CDRSB: -5.8975; LDELTOTAL: -6.6246;
#   R² (Val)   -> MMSE: -0.1272; CDRSB: -4.0004; LDELTOTAL: -5.4640;
# --- Epoch [022/500] ---
# Loss -> Train: 8.665725, Val: 9.853266 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.1249; CDRSB: -5.2358; LDELTOTAL: -5.9529;
#   R² (Val)   -> MMSE: -0.0987; CDRSB: -3.7143; LDELTOTAL: -5.1352;
# --- Epoch [023/500] ---
# Loss -> Train: 8.159940, Val: 8.712397 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0956; CDRSB: -4.7865; LDELTOTAL: -5.0453;
#   R² (Val)   -> MMSE: -0.0947; CDRSB: -3.1268; LDELTOTAL: -3.7864;
# --- Epoch [024/500] ---
# Loss -> Train: 7.454866, Val: 8.322696 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0664; CDRSB: -4.2576; LDELTOTAL: -4.3453;
#   R² (Val)   -> MMSE: -0.0808; CDRSB: -2.8450; LDELTOTAL: -3.4401;
# --- Epoch [025/500] ---
# Loss -> Train: 6.862927, Val: 7.879169 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0546; CDRSB: -3.7610; LDELTOTAL: -3.8669;
#   R² (Val)   -> MMSE: -0.0620; CDRSB: -2.5803; LDELTOTAL: -3.0821;
# --- Epoch [026/500] ---
# Loss -> Train: 6.607878, Val: 7.770310 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0432; CDRSB: -3.4367; LDELTOTAL: -3.3316;
#   R² (Val)   -> MMSE: -0.0788; CDRSB: -2.4332; LDELTOTAL: -3.2466;
# --- Epoch [027/500] ---
# Loss -> Train: 6.101821, Val: 6.983409 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0109; CDRSB: -3.0906; LDELTOTAL: -2.9641;
#   R² (Val)   -> MMSE: -0.0562; CDRSB: -2.0451; LDELTOTAL: -2.3522;
# --- Epoch [028/500] ---
# Loss -> Train: 5.684637, Val: 6.900745 | LR: 1.0e-03
#   R² (Train) -> MMSE: -0.0170; CDRSB: -2.6848; LDELTOTAL: -2.4620;
#   R² (Val)   -> MMSE: -0.0436; CDRSB: -1.8867; LDELTOTAL: -2.3533;
# --- Epoch [029/500] ---
# Loss -> Train: 5.559095, Val: 6.281018 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0117; CDRSB: -2.4549; LDELTOTAL: -2.2495;
#   R² (Val)   -> MMSE: -0.0308; CDRSB: -1.6340; LDELTOTAL: -1.8179;
# --- Epoch [030/500] ---
# Loss -> Train: 5.125009, Val: 6.155267 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0120; CDRSB: -2.1803; LDELTOTAL: -1.9031;
#   R² (Val)   -> MMSE: -0.0322; CDRSB: -1.5747; LDELTOTAL: -1.8193;
# --- Epoch [031/500] ---
# Loss -> Train: 4.940311, Val: 5.599244 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0291; CDRSB: -1.9844; LDELTOTAL: -1.7703;
#   R² (Val)   -> MMSE: -0.0122; CDRSB: -1.2892; LDELTOTAL: -1.1811;
# --- Epoch [032/500] ---
# Loss -> Train: 4.751285, Val: 5.586882 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0272; CDRSB: -1.8070; LDELTOTAL: -1.4995;
#   R² (Val)   -> MMSE: -0.0116; CDRSB: -1.2186; LDELTOTAL: -1.1818;
# --- Epoch [033/500] ---
# Loss -> Train: 4.482517, Val: 5.260413 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0355; CDRSB: -1.5663; LDELTOTAL: -1.2258;
#   R² (Val)   -> MMSE: 0.0041; CDRSB: -1.1097; LDELTOTAL: -0.9477;
# --- Epoch [034/500] ---
# Loss -> Train: 4.242787, Val: 5.227202 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0536; CDRSB: -1.4988; LDELTOTAL: -0.9956;
#   R² (Val)   -> MMSE: -0.0036; CDRSB: -0.9926; LDELTOTAL: -0.9316;
# --- Epoch [035/500] ---
# Loss -> Train: 4.179399, Val: 4.907117 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0444; CDRSB: -1.3668; LDELTOTAL: -0.8895;
#   R² (Val)   -> MMSE: 0.0067; CDRSB: -0.8710; LDELTOTAL: -0.6973;
# --- Epoch [036/500] ---
# Loss -> Train: 3.947784, Val: 4.707347 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0633; CDRSB: -1.1770; LDELTOTAL: -0.7481;
#   R² (Val)   -> MMSE: -0.0078; CDRSB: -0.7777; LDELTOTAL: -0.5299;
# --- Epoch [037/500] ---
# Loss -> Train: 3.787482, Val: 4.536453 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0625; CDRSB: -1.0746; LDELTOTAL: -0.5493;
#   R² (Val)   -> MMSE: 0.0163; CDRSB: -0.6935; LDELTOTAL: -0.4287;
# --- Epoch [038/500] ---
# Loss -> Train: 3.623389, Val: 4.622731 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0583; CDRSB: -0.9622; LDELTOTAL: -0.4189;
#   R² (Val)   -> MMSE: 0.0207; CDRSB: -0.6616; LDELTOTAL: -0.5131;
# --- Epoch [039/500] ---
# Loss -> Train: 3.558615, Val: 4.420357 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0622; CDRSB: -0.8920; LDELTOTAL: -0.3742;
#   R² (Val)   -> MMSE: -0.0078; CDRSB: -0.5711; LDELTOTAL: -0.3087;
# --- Epoch [040/500] ---
# Loss -> Train: 3.482513, Val: 4.433038 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0666; CDRSB: -0.7821; LDELTOTAL: -0.2857;
#   R² (Val)   -> MMSE: 0.0100; CDRSB: -0.5333; LDELTOTAL: -0.3776;
# --- Epoch [041/500] ---
# Loss -> Train: 3.383000, Val: 4.319436 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0773; CDRSB: -0.6633; LDELTOTAL: -0.2098;
#   R² (Val)   -> MMSE: -0.0285; CDRSB: -0.5491; LDELTOTAL: -0.4387;
# --- Epoch [042/500] ---
# Loss -> Train: 3.281939, Val: 3.994808 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0740; CDRSB: -0.6349; LDELTOTAL: -0.1360;
#   R² (Val)   -> MMSE: 0.0200; CDRSB: -0.4198; LDELTOTAL: -0.0610;
# --- Epoch [043/500] ---
# Loss -> Train: 3.189132, Val: 3.975752 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0681; CDRSB: -0.5978; LDELTOTAL: -0.1276;
#   R² (Val)   -> MMSE: 0.0129; CDRSB: -0.3878; LDELTOTAL: -0.0751;
# --- Epoch [044/500] ---
# Loss -> Train: 3.135174, Val: 3.898620 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0811; CDRSB: -0.4974; LDELTOTAL: -0.1166;
#   R² (Val)   -> MMSE: 0.0277; CDRSB: -0.3476; LDELTOTAL: -0.0647;
# --- Epoch [045/500] ---
# Loss -> Train: 3.070171, Val: 3.946681 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0690; CDRSB: -0.4369; LDELTOTAL: -0.0394;
#   R² (Val)   -> MMSE: 0.0178; CDRSB: -0.2898; LDELTOTAL: -0.0635;
# --- Epoch [046/500] ---
# Loss -> Train: 3.043672, Val: 3.773204 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0844; CDRSB: -0.3999; LDELTOTAL: 0.0423;
#   R² (Val)   -> MMSE: 0.0168; CDRSB: -0.2971; LDELTOTAL: -0.0038;
# --- Epoch [047/500] ---
# Loss -> Train: 2.963938, Val: 3.957230 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0717; CDRSB: -0.3186; LDELTOTAL: -0.0094;
#   R² (Val)   -> MMSE: -0.0433; CDRSB: -0.3314; LDELTOTAL: -0.2031;
# --- Epoch [048/500] ---
# Loss -> Train: 2.915762, Val: 3.696525 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0818; CDRSB: -0.3133; LDELTOTAL: 0.0490;
#   R² (Val)   -> MMSE: 0.0066; CDRSB: -0.2512; LDELTOTAL: 0.0444;
# --- Epoch [049/500] ---
# Loss -> Train: 2.846309, Val: 3.720692 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0802; CDRSB: -0.2563; LDELTOTAL: 0.1003;
#   R² (Val)   -> MMSE: -0.0265; CDRSB: -0.2387; LDELTOTAL: 0.0246;
# --- Epoch [050/500] ---
# Loss -> Train: 2.814419, Val: 3.681464 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0749; CDRSB: -0.2153; LDELTOTAL: 0.1181;
#   R² (Val)   -> MMSE: 0.0129; CDRSB: -0.1686; LDELTOTAL: 0.1000;
# --- Epoch [051/500] ---
# Loss -> Train: 2.833297, Val: 3.597316 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0786; CDRSB: -0.2004; LDELTOTAL: 0.1096;
#   R² (Val)   -> MMSE: -0.0054; CDRSB: -0.1957; LDELTOTAL: 0.0959;
# --- Epoch [052/500] ---
# Loss -> Train: 2.826836, Val: 3.660148 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0676; CDRSB: -0.1697; LDELTOTAL: 0.1346;
#   R² (Val)   -> MMSE: 0.0171; CDRSB: -0.1118; LDELTOTAL: 0.1067;
# --- Epoch [053/500] ---
# Loss -> Train: 2.714323, Val: 3.735573 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0835; CDRSB: -0.1313; LDELTOTAL: 0.1559;
#   R² (Val)   -> MMSE: -0.0264; CDRSB: -0.2228; LDELTOTAL: -0.0634;
# --- Epoch [054/500] ---
# Loss -> Train: 2.690513, Val: 3.598505 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0883; CDRSB: -0.1249; LDELTOTAL: 0.1778;
#   R² (Val)   -> MMSE: 0.0043; CDRSB: -0.1729; LDELTOTAL: 0.0400;
# --- Epoch [055/500] ---
# Loss -> Train: 2.734514, Val: 3.448026 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0803; CDRSB: -0.1040; LDELTOTAL: 0.1680;
#   R² (Val)   -> MMSE: 0.0284; CDRSB: -0.0884; LDELTOTAL: 0.1883;
# --- Epoch [056/500] ---
# Loss -> Train: 2.656857, Val: 3.434252 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0863; CDRSB: -0.0780; LDELTOTAL: 0.1932;
#   R² (Val)   -> MMSE: 0.0420; CDRSB: -0.0623; LDELTOTAL: 0.2000;
# --- Epoch [057/500] ---
# Loss -> Train: 2.742873, Val: 3.381218 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0822; CDRSB: -0.0673; LDELTOTAL: 0.1937;
#   R² (Val)   -> MMSE: 0.0540; CDRSB: -0.0710; LDELTOTAL: 0.2269;
# --- Epoch [058/500] ---
# Loss -> Train: 2.603752, Val: 3.804308 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0882; CDRSB: -0.0501; LDELTOTAL: 0.2227;
#   R² (Val)   -> MMSE: 0.0224; CDRSB: -0.0369; LDELTOTAL: -0.2147;
# --- Epoch [059/500] ---
# Loss -> Train: 2.610359, Val: 3.574832 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0947; CDRSB: -0.0391; LDELTOTAL: 0.2223;
#   R² (Val)   -> MMSE: -0.0267; CDRSB: -0.1388; LDELTOTAL: 0.0407;
# --- Epoch [060/500] ---
# Loss -> Train: 2.606979, Val: 4.035160 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0888; CDRSB: -0.0279; LDELTOTAL: 0.1941;
#   R² (Val)   -> MMSE: 0.0211; CDRSB: -0.0299; LDELTOTAL: -0.5882;
# --- Epoch [061/500] ---
# Loss -> Train: 2.625828, Val: 3.395923 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0805; CDRSB: -0.0165; LDELTOTAL: 0.2190;
#   R² (Val)   -> MMSE: 0.0155; CDRSB: -0.0937; LDELTOTAL: 0.1642;
# --- Epoch [062/500] ---
# Loss -> Train: 2.608692, Val: 3.497480 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0793; CDRSB: -0.0209; LDELTOTAL: 0.2107;
#   R² (Val)   -> MMSE: -0.0034; CDRSB: -0.1183; LDELTOTAL: 0.0784;
# --- Epoch [063/500] ---
# Loss -> Train: 2.604604, Val: 3.508544 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1028; CDRSB: -0.0144; LDELTOTAL: 0.2050;
#   R² (Val)   -> MMSE: 0.0139; CDRSB: -0.0150; LDELTOTAL: 0.1078;
# --- Epoch [064/500] ---
# Loss -> Train: 2.612020, Val: 3.357180 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0713; CDRSB: -0.0160; LDELTOTAL: 0.1849;
#   R² (Val)   -> MMSE: 0.0334; CDRSB: -0.0342; LDELTOTAL: 0.2361;
# --- Epoch [065/500] ---
# Loss -> Train: 2.549585, Val: 3.320464 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0950; CDRSB: 0.0034; LDELTOTAL: 0.2269;
#   R² (Val)   -> MMSE: 0.0466; CDRSB: -0.0323; LDELTOTAL: 0.2408;
# --- Epoch [066/500] ---
# Loss -> Train: 2.600326, Val: 3.410192 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0780; CDRSB: 0.0037; LDELTOTAL: 0.2299;
#   R² (Val)   -> MMSE: 0.0177; CDRSB: -0.0127; LDELTOTAL: 0.2090;
# --- Epoch [067/500] ---
# Loss -> Train: 2.542426, Val: 3.424214 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0906; CDRSB: -0.0013; LDELTOTAL: 0.2173;
#   R² (Val)   -> MMSE: 0.0279; CDRSB: -0.0085; LDELTOTAL: 0.2246;
# --- Epoch [068/500] ---
# Loss -> Train: 2.587893, Val: 3.288262 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0791; CDRSB: 0.0025; LDELTOTAL: 0.2204;
#   R² (Val)   -> MMSE: 0.0311; CDRSB: -0.0298; LDELTOTAL: 0.2378;
# --- Epoch [069/500] ---
# Loss -> Train: 2.525757, Val: 3.369162 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0945; CDRSB: 0.0333; LDELTOTAL: 0.2389;
#   R² (Val)   -> MMSE: -0.0051; CDRSB: -0.0689; LDELTOTAL: 0.1636;
# --- Epoch [070/500] ---
# Loss -> Train: 2.549484, Val: 3.528023 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0880; CDRSB: 0.0189; LDELTOTAL: 0.2183;
#   R² (Val)   -> MMSE: 0.0395; CDRSB: 0.0040; LDELTOTAL: 0.0974;
# --- Epoch [071/500] ---
# Loss -> Train: 2.564801, Val: 3.319996 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0891; CDRSB: 0.0398; LDELTOTAL: 0.2274;
#   R² (Val)   -> MMSE: 0.0430; CDRSB: -0.0345; LDELTOTAL: 0.2247;
# --- Epoch [072/500] ---
# Loss -> Train: 2.591777, Val: 4.220297 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0850; CDRSB: 0.0247; LDELTOTAL: 0.2224;
#   R² (Val)   -> MMSE: -0.2132; CDRSB: -0.2893; LDELTOTAL: -0.4072;
# --- Epoch [073/500] ---
# Loss -> Train: 2.562519, Val: 3.616475 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0789; CDRSB: 0.0198; LDELTOTAL: 0.2151;
#   R² (Val)   -> MMSE: 0.0251; CDRSB: 0.0041; LDELTOTAL: 0.0124;
# --- Epoch [074/500] ---
# Loss -> Train: 2.615556, Val: 3.354317 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0836; CDRSB: 0.0280; LDELTOTAL: 0.2137;
#   R² (Val)   -> MMSE: -0.0004; CDRSB: -0.0272; LDELTOTAL: 0.2251;
# --- Epoch [075/500] ---
# Loss -> Train: 2.519430, Val: 3.364798 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0886; CDRSB: 0.0323; LDELTOTAL: 0.2392;
#   R² (Val)   -> MMSE: -0.0008; CDRSB: -0.0365; LDELTOTAL: 0.1913;
# --- Epoch [076/500] ---
# Loss -> Train: 2.631978, Val: 3.308100 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0817; CDRSB: 0.0097; LDELTOTAL: 0.2158;
#   R² (Val)   -> MMSE: 0.0394; CDRSB: 0.0079; LDELTOTAL: 0.2538;
# --- Epoch [077/500] ---
# Loss -> Train: 2.532879, Val: 3.631493 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0845; CDRSB: 0.0386; LDELTOTAL: 0.2158;
#   R² (Val)   -> MMSE: 0.0361; CDRSB: 0.0002; LDELTOTAL: 0.0055;
# --- Epoch [078/500] ---
# Loss -> Train: 2.531048, Val: 3.335658 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0786; CDRSB: 0.0454; LDELTOTAL: 0.2070;
#   R² (Val)   -> MMSE: 0.0303; CDRSB: -0.0006; LDELTOTAL: 0.2509;
# --- Epoch [079/500] ---
# Loss -> Train: 2.526133, Val: 3.262250 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0864; CDRSB: 0.0252; LDELTOTAL: 0.2231;
#   R² (Val)   -> MMSE: 0.0719; CDRSB: 0.0040; LDELTOTAL: 0.2575;
# --- Epoch [080/500] ---
# Loss -> Train: 2.567443, Val: 3.270924 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0825; CDRSB: 0.0358; LDELTOTAL: 0.2048;
#   R² (Val)   -> MMSE: 0.0398; CDRSB: -0.0097; LDELTOTAL: 0.2390;
# --- Epoch [081/500] ---
# Loss -> Train: 2.537331, Val: 3.666405 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0980; CDRSB: 0.0439; LDELTOTAL: 0.2148;
#   R² (Val)   -> MMSE: -0.1701; CDRSB: -0.1670; LDELTOTAL: -0.0190;
# --- Epoch [082/500] ---
# Loss -> Train: 2.524343, Val: 3.474399 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0729; CDRSB: 0.0480; LDELTOTAL: 0.2364;
#   R² (Val)   -> MMSE: 0.0311; CDRSB: 0.0131; LDELTOTAL: 0.1409;
# --- Epoch [083/500] ---
# Loss -> Train: 2.517732, Val: 3.371409 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1113; CDRSB: 0.0550; LDELTOTAL: 0.2355;
#   R² (Val)   -> MMSE: -0.0387; CDRSB: -0.0318; LDELTOTAL: 0.1775;
# --- Epoch [084/500] ---
# Loss -> Train: 2.527721, Val: 4.658950 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0761; CDRSB: 0.0321; LDELTOTAL: 0.2166;
#   R² (Val)   -> MMSE: -0.0836; CDRSB: -0.2120; LDELTOTAL: -0.6361;
# --- Epoch [085/500] ---
# Loss -> Train: 2.550463, Val: 3.577120 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0946; CDRSB: 0.0414; LDELTOTAL: 0.2200;
#   R² (Val)   -> MMSE: -0.0503; CDRSB: -0.1283; LDELTOTAL: 0.0320;
# --- Epoch [086/500] ---
# Loss -> Train: 2.533595, Val: 3.407560 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0853; CDRSB: 0.0367; LDELTOTAL: 0.2334;
#   R² (Val)   -> MMSE: -0.0056; CDRSB: -0.0957; LDELTOTAL: 0.1252;
# --- Epoch [087/500] ---
# Loss -> Train: 2.523204, Val: 3.878812 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.1036; CDRSB: 0.0384; LDELTOTAL: 0.2302;
#   R² (Val)   -> MMSE: -0.2087; CDRSB: -0.2721; LDELTOTAL: -0.1294;
# --- Epoch [088/500] ---
# Loss -> Train: 2.608513, Val: 3.372638 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0764; CDRSB: 0.0367; LDELTOTAL: 0.2262;
#   R² (Val)   -> MMSE: -0.0384; CDRSB: -0.0733; LDELTOTAL: 0.1622;
# --- Epoch [089/500] ---
# Loss -> Train: 2.583308, Val: 3.297623 | LR: 1.0e-03
#   R² (Train) -> MMSE: 0.0909; CDRSB: 0.0442; LDELTOTAL: 0.2254;
#   R² (Val)   -> MMSE: 0.0342; CDRSB: -0.0382; LDELTOTAL: 0.1825;
# --- Epoch [090/500] ---
# ...
#   R² (Val)   -> MMSE: 0.0847; CDRSB: 0.0512; LDELTOTAL: 0.2784;
# --- Epoch [216/500] ---
# Loss -> Train: 2.371304, Val: 2.165325 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1415; CDRSB: 0.0563; LDELTOTAL: 0.2842;
#   R² (Val)   -> MMSE: 0.0957; CDRSB: 0.0550; LDELTOTAL: 0.2827;
# --- Epoch [217/500] ---
# Loss -> Train: 2.379766, Val: 2.167647 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0912; CDRSB: 0.0548; LDELTOTAL: 0.2727;
#   R² (Val)   -> MMSE: 0.0838; CDRSB: 0.0489; LDELTOTAL: 0.2764;
# --- Epoch [218/500] ---
# Loss -> Train: 2.420373, Val: 2.163925 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0858; CDRSB: 0.0524; LDELTOTAL: 0.2525;
#   R² (Val)   -> MMSE: 0.0908; CDRSB: 0.0516; LDELTOTAL: 0.2809;
# --- Epoch [219/500] ---
# Loss -> Train: 2.404388, Val: 2.158497 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1099; CDRSB: 0.0445; LDELTOTAL: 0.2790;
#   R² (Val)   -> MMSE: 0.0982; CDRSB: 0.0584; LDELTOTAL: 0.2890;
# --- Epoch [220/500] ---
# Loss -> Train: 2.369462, Val: 2.166423 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1240; CDRSB: 0.0479; LDELTOTAL: 0.2737;
#   R² (Val)   -> MMSE: 0.0870; CDRSB: 0.0511; LDELTOTAL: 0.2781;
# --- Epoch [221/500] ---
# Loss -> Train: 2.408320, Val: 2.164272 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1081; CDRSB: 0.0593; LDELTOTAL: 0.2528;
#   R² (Val)   -> MMSE: 0.1040; CDRSB: 0.0588; LDELTOTAL: 0.2881;
# --- Epoch [222/500] ---
# Loss -> Train: 2.407176, Val: 2.168889 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1230; CDRSB: 0.0547; LDELTOTAL: 0.2683;
#   R² (Val)   -> MMSE: 0.0839; CDRSB: 0.0493; LDELTOTAL: 0.2753;
# --- Epoch [223/500] ---
# Loss -> Train: 2.399216, Val: 2.164004 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1211; CDRSB: 0.0573; LDELTOTAL: 0.2640;
#   R² (Val)   -> MMSE: 0.0953; CDRSB: 0.0558; LDELTOTAL: 0.2836;
# --- Epoch [224/500] ---
# Loss -> Train: 2.417226, Val: 2.160627 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1104; CDRSB: 0.0381; LDELTOTAL: 0.2603;
#   R² (Val)   -> MMSE: 0.0952; CDRSB: 0.0540; LDELTOTAL: 0.2851;
# --- Epoch [225/500] ---
# Loss -> Train: 2.396698, Val: 2.164427 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1183; CDRSB: 0.0515; LDELTOTAL: 0.2594;
#   R² (Val)   -> MMSE: 0.1019; CDRSB: 0.0593; LDELTOTAL: 0.2878;
# --- Epoch [226/500] ---
# Loss -> Train: 2.399921, Val: 2.159533 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1085; CDRSB: 0.0502; LDELTOTAL: 0.2706;
#   R² (Val)   -> MMSE: 0.1010; CDRSB: 0.0581; LDELTOTAL: 0.2893;
# --- Epoch [227/500] ---
# Loss -> Train: 2.386968, Val: 2.158783 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1200; CDRSB: 0.0436; LDELTOTAL: 0.2789;
#   R² (Val)   -> MMSE: 0.0963; CDRSB: 0.0579; LDELTOTAL: 0.2871;
# --- Epoch [228/500] ---
# Loss -> Train: 2.419095, Val: 2.157056 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1163; CDRSB: 0.0592; LDELTOTAL: 0.2560;
#   R² (Val)   -> MMSE: 0.1041; CDRSB: 0.0593; LDELTOTAL: 0.2915;
# --- Epoch [229/500] ---
# Loss -> Train: 2.374912, Val: 2.164976 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1140; CDRSB: 0.0615; LDELTOTAL: 0.2828;
#   R² (Val)   -> MMSE: 0.0951; CDRSB: 0.0539; LDELTOTAL: 0.2824;
# --- Epoch [230/500] ---
# Loss -> Train: 2.396595, Val: 2.162305 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1225; CDRSB: 0.0616; LDELTOTAL: 0.2739;
#   R² (Val)   -> MMSE: 0.0957; CDRSB: 0.0542; LDELTOTAL: 0.2848;
# --- Epoch [231/500] ---
# Loss -> Train: 2.383467, Val: 2.161425 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1161; CDRSB: 0.0543; LDELTOTAL: 0.2598;
#   R² (Val)   -> MMSE: 0.1030; CDRSB: 0.0577; LDELTOTAL: 0.2883;
# --- Epoch [232/500] ---
# Loss -> Train: 2.421467, Val: 2.161659 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1023; CDRSB: 0.0387; LDELTOTAL: 0.2651;
#   R² (Val)   -> MMSE: 0.0998; CDRSB: 0.0582; LDELTOTAL: 0.2877;
# --- Epoch [233/500] ---
# Loss -> Train: 2.421673, Val: 2.162145 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0859; CDRSB: 0.0480; LDELTOTAL: 0.2508;
#   R² (Val)   -> MMSE: 0.0953; CDRSB: 0.0553; LDELTOTAL: 0.2843;
# --- Epoch [234/500] ---
# Loss -> Train: 2.386329, Val: 2.160288 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1081; CDRSB: 0.0579; LDELTOTAL: 0.2578;
#   R² (Val)   -> MMSE: 0.1007; CDRSB: 0.0596; LDELTOTAL: 0.2894;
# --- Epoch [235/500] ---
# Loss -> Train: 2.397150, Val: 2.164436 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0978; CDRSB: 0.0571; LDELTOTAL: 0.2724;
#   R² (Val)   -> MMSE: 0.0887; CDRSB: 0.0520; LDELTOTAL: 0.2806;
# --- Epoch [236/500] ---
# Loss -> Train: 2.386368, Val: 2.169771 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1242; CDRSB: 0.0639; LDELTOTAL: 0.2667;
#   R² (Val)   -> MMSE: 0.0824; CDRSB: 0.0509; LDELTOTAL: 0.2750;
# --- Epoch [237/500] ---
# Loss -> Train: 2.449452, Val: 2.155867 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0936; CDRSB: 0.0431; LDELTOTAL: 0.2705;
#   R² (Val)   -> MMSE: 0.0998; CDRSB: 0.0577; LDELTOTAL: 0.2900;
# --- Epoch [238/500] ---
# Loss -> Train: 2.423448, Val: 2.155593 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1222; CDRSB: 0.0667; LDELTOTAL: 0.2581;
#   R² (Val)   -> MMSE: 0.1060; CDRSB: 0.0619; LDELTOTAL: 0.2941;
# --- Epoch [239/500] ---
# Loss -> Train: 2.420190, Val: 2.152468 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1063; CDRSB: 0.0377; LDELTOTAL: 0.2607;
#   R² (Val)   -> MMSE: 0.1033; CDRSB: 0.0630; LDELTOTAL: 0.2947;
# --- Epoch [240/500] ---
# Loss -> Train: 2.400969, Val: 2.166703 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1174; CDRSB: 0.0515; LDELTOTAL: 0.2969;
#   R² (Val)   -> MMSE: 0.0973; CDRSB: 0.0548; LDELTOTAL: 0.2835;
# --- Epoch [241/500] ---
# Loss -> Train: 2.399304, Val: 2.159486 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1160; CDRSB: 0.0530; LDELTOTAL: 0.2744;
#   R² (Val)   -> MMSE: 0.0924; CDRSB: 0.0539; LDELTOTAL: 0.2845;
# --- Epoch [242/500] ---
# Loss -> Train: 2.404886, Val: 2.157287 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1020; CDRSB: 0.0477; LDELTOTAL: 0.2623;
#   R² (Val)   -> MMSE: 0.1047; CDRSB: 0.0595; LDELTOTAL: 0.2917;
# --- Epoch [243/500] ---
# Loss -> Train: 2.566572, Val: 2.158040 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0841; CDRSB: 0.0508; LDELTOTAL: 0.2724;
#   R² (Val)   -> MMSE: 0.1063; CDRSB: 0.0614; LDELTOTAL: 0.2931;
# --- Epoch [244/500] ---
# Loss -> Train: 2.364141, Val: 2.158451 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1121; CDRSB: 0.0712; LDELTOTAL: 0.2912;
#   R² (Val)   -> MMSE: 0.0945; CDRSB: 0.0584; LDELTOTAL: 0.2872;
# --- Epoch [245/500] ---
# Loss -> Train: 2.392223, Val: 2.160508 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1149; CDRSB: 0.0539; LDELTOTAL: 0.2672;
#   R² (Val)   -> MMSE: 0.0976; CDRSB: 0.0559; LDELTOTAL: 0.2864;
# --- Epoch [246/500] ---
# Loss -> Train: 2.367782, Val: 2.163404 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1278; CDRSB: 0.0666; LDELTOTAL: 0.2911;
#   R² (Val)   -> MMSE: 0.0899; CDRSB: 0.0525; LDELTOTAL: 0.2810;
# --- Epoch [247/500] ---
# Loss -> Train: 2.400772, Val: 2.160189 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1099; CDRSB: 0.0550; LDELTOTAL: 0.2802;
#   R² (Val)   -> MMSE: 0.1038; CDRSB: 0.0589; LDELTOTAL: 0.2906;
# --- Epoch [248/500] ---
# Loss -> Train: 2.389039, Val: 2.164221 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1101; CDRSB: 0.0582; LDELTOTAL: 0.2721;
#   R² (Val)   -> MMSE: 0.0893; CDRSB: 0.0524; LDELTOTAL: 0.2811;
# --- Epoch [249/500] ---
# Loss -> Train: 2.411489, Val: 2.156305 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0952; CDRSB: 0.0521; LDELTOTAL: 0.2654;
#   R² (Val)   -> MMSE: 0.1016; CDRSB: 0.0603; LDELTOTAL: 0.2916;
# --- Epoch [250/500] ---
# Loss -> Train: 2.403805, Val: 2.159479 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1170; CDRSB: 0.0554; LDELTOTAL: 0.2725;
#   R² (Val)   -> MMSE: 0.0999; CDRSB: 0.0567; LDELTOTAL: 0.2877;
# --- Epoch [251/500] ---
# Loss -> Train: 2.380159, Val: 2.159494 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1221; CDRSB: 0.0542; LDELTOTAL: 0.2773;
#   R² (Val)   -> MMSE: 0.0929; CDRSB: 0.0551; LDELTOTAL: 0.2850;
# --- Epoch [252/500] ---
# Loss -> Train: 2.453105, Val: 2.162863 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0921; CDRSB: 0.0512; LDELTOTAL: 0.2578;
#   R² (Val)   -> MMSE: 0.1008; CDRSB: 0.0586; LDELTOTAL: 0.2870;
# --- Epoch [253/500] ---
# Loss -> Train: 2.406645, Val: 2.161505 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1083; CDRSB: 0.0531; LDELTOTAL: 0.2649;
#   R² (Val)   -> MMSE: 0.0921; CDRSB: 0.0539; LDELTOTAL: 0.2833;
# --- Epoch [254/500] ---
# Loss -> Train: 2.445002, Val: 2.162372 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0802; CDRSB: 0.0496; LDELTOTAL: 0.2748;
#   R² (Val)   -> MMSE: 0.0977; CDRSB: 0.0572; LDELTOTAL: 0.2861;
# --- Epoch [255/500] ---
# Loss -> Train: 2.436283, Val: 2.161144 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0895; CDRSB: 0.0408; LDELTOTAL: 0.2491;
#   R² (Val)   -> MMSE: 0.0941; CDRSB: 0.0560; LDELTOTAL: 0.2852;
# --- Epoch [256/500] ---
# Loss -> Train: 2.372499, Val: 2.158578 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1242; CDRSB: 0.0611; LDELTOTAL: 0.2880;
#   R² (Val)   -> MMSE: 0.1066; CDRSB: 0.0630; LDELTOTAL: 0.2940;
# --- Epoch [257/500] ---
# Loss -> Train: 2.389119, Val: 2.164600 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1264; CDRSB: 0.0663; LDELTOTAL: 0.2897;
#   R² (Val)   -> MMSE: 0.0929; CDRSB: 0.0544; LDELTOTAL: 0.2821;
# --- Epoch [258/500] ---
# Loss -> Train: 2.394428, Val: 2.171125 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1275; CDRSB: 0.0440; LDELTOTAL: 0.2698;
#   R² (Val)   -> MMSE: 0.0857; CDRSB: 0.0484; LDELTOTAL: 0.2745;
# --- Epoch [259/500] ---
# Loss -> Train: 2.398820, Val: 2.154410 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1090; CDRSB: 0.0571; LDELTOTAL: 0.2761;
#   R² (Val)   -> MMSE: 0.1025; CDRSB: 0.0606; LDELTOTAL: 0.2929;
# --- Epoch [260/500] ---
# Loss -> Train: 2.392733, Val: 2.163079 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1223; CDRSB: 0.0567; LDELTOTAL: 0.2718;
#   R² (Val)   -> MMSE: 0.0930; CDRSB: 0.0534; LDELTOTAL: 0.2826;
# --- Epoch [261/500] ---
# Loss -> Train: 2.354458, Val: 2.158107 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1310; CDRSB: 0.0551; LDELTOTAL: 0.2854;
#   R² (Val)   -> MMSE: 0.0982; CDRSB: 0.0572; LDELTOTAL: 0.2879;
# --- Epoch [262/500] ---
# Loss -> Train: 2.413596, Val: 2.159710 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0941; CDRSB: 0.0392; LDELTOTAL: 0.2518;
#   R² (Val)   -> MMSE: 0.1033; CDRSB: 0.0603; LDELTOTAL: 0.2914;
# --- Epoch [263/500] ---
# Loss -> Train: 2.394484, Val: 2.157842 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1060; CDRSB: 0.0426; LDELTOTAL: 0.2501;
#   R² (Val)   -> MMSE: 0.1054; CDRSB: 0.0605; LDELTOTAL: 0.2928;
# --- Epoch [264/500] ---
# Loss -> Train: 2.393349, Val: 2.164064 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1245; CDRSB: 0.0679; LDELTOTAL: 0.2876;
#   R² (Val)   -> MMSE: 0.1030; CDRSB: 0.0607; LDELTOTAL: 0.2892;
# --- Epoch [265/500] ---
# Loss -> Train: 2.345946, Val: 2.163011 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1250; CDRSB: 0.0568; LDELTOTAL: 0.2754;
#   R² (Val)   -> MMSE: 0.0961; CDRSB: 0.0567; LDELTOTAL: 0.2848;
# --- Epoch [266/500] ---
# Loss -> Train: 2.407305, Val: 2.162984 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1138; CDRSB: 0.0547; LDELTOTAL: 0.2540;
#   R² (Val)   -> MMSE: 0.0890; CDRSB: 0.0533; LDELTOTAL: 0.2809;
# --- Epoch [267/500] ---
# Loss -> Train: 2.382041, Val: 2.157224 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1298; CDRSB: 0.0604; LDELTOTAL: 0.2781;
#   R² (Val)   -> MMSE: 0.1057; CDRSB: 0.0627; LDELTOTAL: 0.2938;
# --- Epoch [268/500] ---
# Loss -> Train: 2.404286, Val: 2.163250 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1050; CDRSB: 0.0459; LDELTOTAL: 0.2680;
#   R² (Val)   -> MMSE: 0.0946; CDRSB: 0.0552; LDELTOTAL: 0.2836;
# --- Epoch [269/500] ---
# Loss -> Train: 2.432934, Val: 2.161795 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0951; CDRSB: 0.0519; LDELTOTAL: 0.2702;
#   R² (Val)   -> MMSE: 0.0976; CDRSB: 0.0543; LDELTOTAL: 0.2856;
# --- Epoch [270/500] ---
# Loss -> Train: 2.436398, Val: 2.160259 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0977; CDRSB: 0.0363; LDELTOTAL: 0.2498;
#   R² (Val)   -> MMSE: 0.0988; CDRSB: 0.0558; LDELTOTAL: 0.2871;
# --- Epoch [271/500] ---
# Loss -> Train: 2.412030, Val: 2.158852 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1011; CDRSB: 0.0523; LDELTOTAL: 0.2486;
#   R² (Val)   -> MMSE: 0.1039; CDRSB: 0.0577; LDELTOTAL: 0.2902;
# --- Epoch [272/500] ---
# Loss -> Train: 2.370067, Val: 2.166573 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1230; CDRSB: 0.0563; LDELTOTAL: 0.2750;
#   R² (Val)   -> MMSE: 0.0990; CDRSB: 0.0570; LDELTOTAL: 0.2853;
# --- Epoch [273/500] ---
# Loss -> Train: 2.391815, Val: 2.160359 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1247; CDRSB: 0.0471; LDELTOTAL: 0.2624;
#   R² (Val)   -> MMSE: 0.0951; CDRSB: 0.0556; LDELTOTAL: 0.2855;
# --- Epoch [274/500] ---
# Loss -> Train: 2.402110, Val: 2.169688 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1144; CDRSB: 0.0554; LDELTOTAL: 0.2625;
#   R² (Val)   -> MMSE: 0.0834; CDRSB: 0.0501; LDELTOTAL: 0.2750;
# --- Epoch [275/500] ---
# Loss -> Train: 2.385673, Val: 2.164929 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1166; CDRSB: 0.0521; LDELTOTAL: 0.2738;
#   R² (Val)   -> MMSE: 0.0890; CDRSB: 0.0516; LDELTOTAL: 0.2808;
# --- Epoch [276/500] ---
# Loss -> Train: 2.381550, Val: 2.161499 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1207; CDRSB: 0.0505; LDELTOTAL: 0.2794;
#   R² (Val)   -> MMSE: 0.0945; CDRSB: 0.0545; LDELTOTAL: 0.2843;
# --- Epoch [277/500] ---
# Loss -> Train: 2.438741, Val: 2.163406 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0857; CDRSB: 0.0474; LDELTOTAL: 0.2646;
#   R² (Val)   -> MMSE: 0.0951; CDRSB: 0.0557; LDELTOTAL: 0.2837;
# --- Epoch [278/500] ---
# Loss -> Train: 2.417757, Val: 2.158767 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1036; CDRSB: 0.0494; LDELTOTAL: 0.2712;
#   R² (Val)   -> MMSE: 0.0924; CDRSB: 0.0551; LDELTOTAL: 0.2846;
# --- Epoch [279/500] ---
# Loss -> Train: 2.379290, Val: 2.162080 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1252; CDRSB: 0.0545; LDELTOTAL: 0.2569;
#   R² (Val)   -> MMSE: 0.1024; CDRSB: 0.0585; LDELTOTAL: 0.2879;
# --- Epoch [280/500] ---
# Loss -> Train: 2.380894, Val: 2.162462 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1174; CDRSB: 0.0622; LDELTOTAL: 0.2987;
#   R² (Val)   -> MMSE: 0.0979; CDRSB: 0.0545; LDELTOTAL: 0.2852;
# --- Epoch [281/500] ---
# Loss -> Train: 2.424476, Val: 2.158549 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1131; CDRSB: 0.0568; LDELTOTAL: 0.2584;
#   R² (Val)   -> MMSE: 0.1059; CDRSB: 0.0606; LDELTOTAL: 0.2922;
# --- Epoch [282/500] ---
# Loss -> Train: 2.389918, Val: 2.162142 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1033; CDRSB: 0.0480; LDELTOTAL: 0.2588;
#   R² (Val)   -> MMSE: 0.0882; CDRSB: 0.0526; LDELTOTAL: 0.2814;
# --- Epoch [283/500] ---
# Loss -> Train: 2.387545, Val: 2.161711 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1070; CDRSB: 0.0540; LDELTOTAL: 0.2698;
#   R² (Val)   -> MMSE: 0.1024; CDRSB: 0.0577; LDELTOTAL: 0.2887;
# --- Epoch [284/500] ---
# Loss -> Train: 2.382507, Val: 2.160167 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1111; CDRSB: 0.0684; LDELTOTAL: 0.2777;
#   R² (Val)   -> MMSE: 0.0902; CDRSB: 0.0548; LDELTOTAL: 0.2835;
# --- Epoch [285/500] ---
# Loss -> Train: 2.435060, Val: 2.156535 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.0849; CDRSB: 0.0441; LDELTOTAL: 0.2529;
#   R² (Val)   -> MMSE: 0.1062; CDRSB: 0.0617; LDELTOTAL: 0.2937;
# --- Epoch [286/500] ---
# Loss -> Train: 2.415607, Val: 2.158624 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1100; CDRSB: 0.0582; LDELTOTAL: 0.2830;
#   R² (Val)   -> MMSE: 0.0964; CDRSB: 0.0582; LDELTOTAL: 0.2877;
# --- Epoch [287/500] ---
# Loss -> Train: 2.385460, Val: 2.159847 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1141; CDRSB: 0.0417; LDELTOTAL: 0.2631;
#   R² (Val)   -> MMSE: 0.0953; CDRSB: 0.0556; LDELTOTAL: 0.2857;
# --- Epoch [288/500] ---
# Loss -> Train: 2.372703, Val: 2.164013 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1260; CDRSB: 0.0620; LDELTOTAL: 0.2714;
#   R² (Val)   -> MMSE: 0.0923; CDRSB: 0.0542; LDELTOTAL: 0.2824;
# --- Epoch [289/500] ---
# Loss -> Train: 2.386384, Val: 2.160765 | LR: 1.0e-08
#   R² (Train) -> MMSE: 0.1145; CDRSB: 0.0597; LDELTOTAL: 0.2765;
#   R² (Val)   -> MMSE: 0.0963; CDRSB: 0.0565; LDELTOTAL: 0.2859;
#
# 提前停止于周期 289.
#
# 折叠 5 完成。最佳验证损失: 2.152468
# 对应的验证集R²: {'MMSE': 0.10330694913864136, 'CDRSB': 0.06296586990356445, 'LDELTOTAL': 0.29469263553619385}
# 对应的训练集R²: {'MMSE': 0.10631203651428223, 'CDRSB': 0.03765743970870972, 'LDELTOTAL': 0.26071876287460327}
#
# ==============================
# --- 交叉验证结果总结 ---
# ==============================
# 平均最佳验证损失: 2.455388 ± 0.379789
#   - MMSE 平均 Val R²:   0.0817 ± 0.0209
#   - MMSE 平均 Train R²: 0.0929 ± 0.0172
#   - CDRSB 平均 Val R²:   0.0400 ± 0.0324
#   - CDRSB 平均 Train R²: 0.0481 ± 0.0154
#   - LDELTOTAL 平均 Val R²:   0.2537 ± 0.0579
#   - LDELTOTAL 平均 Train R²: 0.2693 ± 0.0220
